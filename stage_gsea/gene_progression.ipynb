# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from upsetplot import UpSet, from_contents
import seaborn as sns
import numpy as np

# %%
# Import miRNAs from each of the classification categories
ctl_s1 = pd.read_csv('./ctl_s1/ctl_s1_genes.csv')
s1_s2 = pd.read_csv('./s1_s2/s1_s2_genes.csv')
s2_s3 = pd.read_csv('./s2_s3/s2_s3_genes.csv')
s3_s4 = pd.read_csv('./s3_s4/s3_s4_genes.csv')

# %%
print(f'ctl_s1 shape: {ctl_s1.shape}')
print(f's1_s2 shape: {s1_s2.shape}')
print(f's2_s3 shape: {s2_s3.shape}')
print(f's3_s4 shape: {s3_s4.shape}\n')

print(f'ctl_s1 columns: {ctl_s1.columns}')
print(f's1_s2 columns: {s1_s2.columns}')
print(f's2_s3 columns: {s2_s3.columns}')
print(f's3_s4 columns: {s3_s4.columns}')
# Out:
# ctl_s1 shape: (1215, 16)
# s1_s2 shape: (209, 10)
# s2_s3 shape: (877, 12)
# s3_s4 shape: (659, 12)
#
# ctl_s1 columns: Index(['Gene Symbol', 'p-value', 'FDR', 'Odd ratio', 'Number of interactions',
#        'microRNA 1', 'microRNA 2', 'microRNA 3', 'microRNA 4', 'microRNA 5',
#        'microRNA 6', 'microRNA 7', 'microRNA 8', 'microRNA 9', 'microRNA 10',
#        'microRNA 11'],
#       dtype='object')
# s1_s2 columns: Index(['Gene Symbol', 'p-value', 'FDR', 'Odd ratio', 'Number of interactions',
#        'microRNA 1', 'microRNA 2', 'microRNA 3', 'microRNA 4', 'microRNA 5'],
#       dtype='object')
# s2_s3 columns: Index(['Gene Symbol', 'p-value', 'FDR', 'Odd ratio', 'Number of interactions',
#        'microRNA 1', 'microRNA 2', 'microRNA 3', 'microRNA 4', 'microRNA 5',
#        'microRNA 6', 'microRNA 7'],
#       dtype='object')
# s3_s4 columns: Index(['Gene Symbol', 'p-value', 'FDR', 'Odd ratio', 'Number of interactions',
# ...

# %%
ctl_s1_set = set(ctl_s1['Gene Symbol'])
s1_s2_set = set(s1_s2['Gene Symbol'])
s2_s3_set = set(s2_s3['Gene Symbol'])
s3_s4_set = set(s3_s4['Gene Symbol'])

print(f'ctl_s1 genes: {ctl_s1_set}')
print(f's1_s2 genes: {s1_s2_set}')
print(f's2_s3 genes: {s2_s3_set}')
print(f's3_s4 genes: {s3_s4_set}')
# Out:
# ctl_s1 genes: {'C1D', 'ARHGEF18', 'NDUFB11', 'RAB4A', 'EIF5AL1', 'ZBTB8B', 'ZNF107', 'CFL1', 'MICAL2', 'ATG2A', 'NOL10', 'DUSP14', 'PPM1F', 'C10orf55', 'GCFC2', 'MRPS23', 'NCMAP', 'TMTC1', 'TRIM44', 'ZNF641', 'FOLR1', 'INTS7', 'PDRG1', 'RCE1', 'VOPP1', 'FOXP4', 'KIAA1551', 'MTSS1L', 'SEC22C', 'SAR1A', 'SERPINA1', 'PRICKLE1', 'CD44', 'NUP62', 'C12orf49', 'MED28', 'TOMM20', 'NKIRAS2', 'CBWD5', 'PKM', 'GPATCH3', 'SETD3', 'RGS5', 'ZNF445', 'RREB1', 'ZNF70', 'CDK4', 'S100A16', 'NPW', 'SNRPD1', 'PDGFRA', 'WNK2', 'COL5A1', 'TFAP4', 'HIST1H3B', 'VPS37B', 'CCNT1', 'H2AFX', 'GK5', 'CEP97', 'PURB', 'PDE4C', 'IMP4', 'CHRNE', 'HIST1H2AD', 'MCFD2', 'ATG14', 'ARHGDIA', 'HIST1H2BF', 'SPECC1L', 'PSMB2', 'TBXA2R', 'RTL10', 'MAPK1IP1L', 'USP22', 'RAB15', 'TM6SF2', 'IP6K1', 'RNASEH2B', 'SNU13', 'ERGIC2', 'FEM1A', 'JARID2', 'C8orf82', 'LYRM7', 'SOX12', 'GTPBP2', 'FTSJ3', 'PLEKHG2', 'NCKIPSD', 'FAM83H', 'AGO2', 'MAT1A', 'NEK9', 'CSNK1E', 'PIEZO1', 'PTPA', 'KLC2', 'BAZ2B', 'SUSD6', 'SPATA2', 'FAM83F', 'ONE
# ...

# %% [markdown]
# #### Venn Diagrams for Visualization

# %%
# Create Venn diagrams for consecutive stages
plt.figure(figsize=(15,5))

# Venn Diagram 1: ctl_s1 vs s1_s2
plt.subplot(1,3,1)
venn2([ctl_s1_set, s1_s2_set], set_labels=('ctl_s1', 's1_s2'))
plt.title('ctl_s1 vs s1_s2')

plt.subplot(1,3,2)
venn2([s1_s2_set, s2_s3_set], set_labels=('s1_s2', 's2_s3'))
plt.title('s1_s2 vs s2_s3')

plt.subplot(1,3,3)
venn2([s2_s3_set, s3_s4_set], set_labels=('s2_s3', 's3_s4'))
plt.title('s2_s3 vs s3_s4')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### UpSet Plot for Visualization

# %%
contents = {
    'ctl_s1': ctl_s1_set,
    's1_s2': s1_s2_set,
    's2_s3': s2_s3_set,
    's3_s4': s3_s4_set
}

# Convert the dictionary of sets to a format suitable for UpSet plot
upset_data = from_contents(contents)

# Plot UpSet plot
upset = UpSet(upset_data, subset_size='count', show_counts=True)
upset.plot()
plt.suptitle('UpSet Plot of miRNA Progression through Stages')
plt.show()
# Out:
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
small_intersections = [
    ('ctl_s1', 's3_s4'),
    ('ctl_s1', 's2_s3'),
    ('s1_s2', 's3_s4'),
    ('s1_s2', 's2_s3', 's3_s4'),
    ('ctl_s1', 's1_s2', 's3_s4'),
    ('ctl_s1', 's1_s2', 's2_s3', 's3_s4')
]

# Print the genes, separated by a space in the intersection separated by a space
for intersection in small_intersections:
    genes = set.intersection(*[contents[stage] for stage in intersection])
    print(f"genes in intersection of: {intersection}: {' '.join(genes)} \n")
# Out:
# genes in intersection of: ('ctl_s1', 's3_s4'): SLC2A5 DDA1 NDUFB11 ZBTB8B EIF5AL1 UNC5B CRKL CYP4A22 PPM1F GPRC5A SBNO1 ZNF641 FOLR1 RPRD2 CBX5 MLLT1 HIST3H3 THY1 ZBTB46 ARPP19 CBX6 TNRC6A NLRP6 MDFI SCAMP4 HSD17B12 WBP2 PHYKPL SLC6A4 RAB5B NFIC UBXN2A DNLZ RPL7L1 ACVR2B SUMO1 NUP62 PLEKHM1 ABI2 MAPK1 LRIG2 NKIRAS2 TUBD1 CLPB DSTYK MFRP PKM CCSAP GDI1 S100A16 ANP32B NAV1 NDUFAF3 SETD1B COL5A1 TFAP4 SFN CCNT1 ASNA1 RBM23 AP2M1 FAM129B CEP97 FBXO45 LGSN SLC7A1 HOOK3 MTHFD2 MCFD2 TXNIP TMEM167A NUFIP2 GPRC5B CYP20A1 HAUS3 GLO1 PURB ERGIC2 FEM1A RAB15 CAPS CDKN1A MARK2 SP1 ATP5A1 CRCP DNAL1 ZNF451 FTSJ3 DESI1 GATA6 CASKIN2 AGO2 FAM83H PTGES3L BCL2L1 MAFK C10orf76 SLC35C2 METTL14 TCF3 LRTOMT FAM83F KMT2A RNF40 IGF1R HIST1H1E WASF2 PLAGL2 POTEG SENP2 VEGFA PRRG4 ZNF708 ULK1 FZD6 HNRNPUL1 TRAPPC2 ABCG8 POTEM EMC3 BZW1 DNAH10OS MIDN CYP2W1 DAB2IP EIF2S3 G3BP1 ELFN2 KHSRP TOB2 TXLNA RHOF TMEM127 FAM212B LLGL1 SLC12A7 LARP1 POLR2E HIST1H2AG GIGYF1 PARP1 HDGF UBE2Q1 COX6B1 TERF2 NUDT3 LIMK1 NUC
# ...
