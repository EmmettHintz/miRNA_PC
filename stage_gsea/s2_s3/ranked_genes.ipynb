# %%
import pandas as pd

# %%
ranked_features = pd.read_csv('./miRNA_disease_ranked.csv')
gene_targets = pd.read_csv('./s2_s3_genes.csv')

# %%
ranked_features['miRNA_rank'] = ranked_features['Importance'].rank()
miRNA_ranks = ranked_features['miRNA_rank'].to_dict()

# %%
total_miRNA = len(ranked_features)

# %% [markdown]
# *Formula*:
# score_gene= 1/t∑_{i=1}^{t}(1−rank_{miRNA}^{i}/total_{miRNA})
#
# *Explanation*
# - t: the number of miRNAs that target the gene
# - rank_{miRNA}^{i}: the rank of miRNA i that targets the gene
# - total_{miRNA}: the total number of miRNAs that target the gene
#
# ***High Gene Score***:
# - Indicates that the gene interacts with miRNAs that are highly ranked (i.e., have a low padj value).
# - A high score suggests that the gene is likely to be regulated by miRNAs that are significant in the context of differential expression analysis.
# - Thus, genes with high scores are potentially more important or relevant to the biological conditions being studied.
#
# ***Low Gene Score***:
# - Indicates that the gene interacts with miRNAs that are lower ranked (i.e., have a higher padj value).
# - A low score suggests that the gene is less likely to be regulated by significant miRNAs.
# - Such genes may be of lower priority for further investigation.

# %%
def calculate_gene_score(row, miRNA_ranks, total_miRNA):
    total_interactions = 0
    score = 0
    for miRNA in row.index[4:]:  # Assuming the miRNAs start from the 5th column
        if pd.notna(row[miRNA]) and row[miRNA] in miRNA_ranks:
            rank = miRNA_ranks[row[miRNA]]
            score += (1 - (rank / total_miRNA))
            total_interactions += 1
    if total_interactions > 0:
        return score / total_interactions
    else:
        return 0

# %%
gene_targets['gene_score'] = gene_targets.apply(calculate_gene_score, axis=1, miRNA_ranks=miRNA_ranks, total_miRNA=total_miRNA)

# Sort genes based on their scores in descending order
ranked_genes = gene_targets.sort_values(by='gene_score', ascending=False)

# Reorder columns so that 'gene_score' is the second column
columns = ['Gene Symbol', 'gene_score'] + [col for col in ranked_genes.columns if col not in ['Gene Symbol', 'gene_score']]
ranked_genes = ranked_genes[columns]


# Save ranked genes to a CSV file
ranked_genes.to_csv('ranked_genes.csv', index=False)

print(ranked_genes.shape)
# Display top ranked genes
print(ranked_genes.head(10))
# Out:
# (877, 13)
#     Gene Symbol  gene_score   p-value    FDR  Odd ratio  \
# 121       CELF1    0.125000  0.005260  0.592      0.320
# 363       MED28    0.125000  0.004590  0.592      0.312
# 0        OTUD7B    0.107143  0.000970  0.539      0.201
# 2          PIGO    0.107143  0.000653  0.539      0.187
# 418       NUDT3    0.107143  0.012400  0.592      0.334
# 9        KDELR1    0.107143  0.001660  0.585      0.223
# 570         SKI    0.107143  0.021600  0.592      0.377
# 504       RAD51    0.107143  0.003950  0.592      0.264
# 560      SETD1B    0.089286  0.015600  0.592      0.304
# 225       FOXK1    0.089286  0.140000  0.592      0.558
#
#      Number of interactions        microRNA 1       microRNA 2  \
# 121                       7   hsa-miR-1229-3p   hsa-miR-412-3p
# 363                       7   hsa-miR-6829-3p  hsa-miR-4722-3p
# 0                         6   hsa-miR-1229-3p  hsa-miR-371b-5p
# 2                         6   hsa-miR-371b-5p  hsa-miR-6829-3p
# 418                       6      hsa-miR-7703  hsa-miR-5587-5p
# 9                         6   hsa-miR-1227-5p  hsa-miR-3130-3p
# 570                       6  hsa-miR-4524b-5p  hsa-miR-6722-3p
# 504                       6   hsa-miR-7854-3p  hsa-miR-4722-3p
# 560                       5  hsa-miR-4524b-5p   hsa-miR-412-3p
# 225                       5   hsa-miR-1229-3p  hsa-miR-548h-5p
#
#            microRNA 3       microRNA 4        microRNA 5        microRNA 6  \
# 121   hsa-miR-6847-3p  hsa-miR-5587-5p      hsa-miR-4741   hsa-miR-6722-3p
# 363   hsa-miR-6847-3p   hsa-miR-660-5p      hsa-miR-4741      hsa-miR-7703
# 0        hsa-miR-4282     hsa-miR-7703   hsa-miR-6847-3p   hsa-miR-7854-3p
# 2     hsa-miR-4722-3p  hsa-miR-1227-5p   hsa-miR-6802-3p    hsa-miR-412-3p
# 418      hsa-miR-4282  hsa-miR-371b-5p      hsa-miR-1253  hsa-miR-6769b-5p
# 9     hsa-miR-5585-3p  hsa-miR-6829-3p   hsa-miR-4722-3p   hsa-miR-6802-3p
# 570      hsa-miR-4282  hsa-miR-371b-5p   hsa-miR-1227-5p      hsa-miR-4741
# 504   hsa-miR-371b-5p  hsa-miR-6847-3p      hsa-miR-7703   hsa-miR-6722-3p
# 560   hsa-miR-5591-5p     hsa-miR-1253  hsa-miR-6769b-5p               NaN
# 225  hsa-miR-4524b-5p   hsa-miR-134-3p      hsa-miR-4741               NaN
#
#            microRNA 7
# 121   hsa-miR-7854-3p
# 363  hsa-miR-6769b-5p
# 0                 NaN
# 2                 NaN
# 418               NaN
# 9                 NaN
# 570               NaN
# 504               NaN
# 560               NaN
# 225               NaN

# %%
# get top 50 genes
top_genes = ranked_genes.iloc[:,1].tolist()
# print the row and the score as a string on a new line
for i in range(len(ranked_genes)):
    if str(top_genes[i]) != 'nan':
        # print(ranked_genes.iloc[i,0], ranked_genes.iloc[i,1], sep = '\t')
        print(ranked_genes.iloc[i,0])
# Out:
# CELF1
# MED28
# OTUD7B
# PIGO
# NUDT3
# KDELR1
# SKI
# RAD51
# SETD1B
# FOXK1
# HNRNPA1
# KMT2D
# OCIAD2
# PEX26
# BMPR1A
# WIPF2
# TIMM8A
# ZNF460
# KLHL36
# SAMD8
# FOSL2
# HMGN2
# HMGA1
# GIGYF1
# GATA6
# ZNF264
# DCAF7
# FEM1A
# IKZF3
# CYP20A1
# COX6B1
# CALR
# C12orf49
# YOD1
# KIF3A
# IPP
# RNF40
# KLHL11
# LRIG2
# LRRC3C
# MAFK
# TOR4A
# MIDN
# BCL2L1
# TMEM154
# ORC6
# PARD6B
# PARP15
# PKD1
# SFT2D2
# MMAB
# PAICS
# MAPKAPK2
# SCOC
# ZNF445
# PAK4
# SRARP
# MAPK8
# TNPO2
# WDR12
# ZNF195
# ZMAT3
# ZFP69B
# HNRNPUL1
# ZBTB3
# YTHDF1
# AKAP11
# IMP4
# INAFM1
# TMOD3
# MAP3K2
# ITGA2
# KCNK5
# ACVR2B
# KCNMB1
# KIAA1456
# GTF2H5
# KIF5B
# KLF2
# UTP6
# KNSTRN
# LAX1
# LLGL1
# TRAPPC2
# TRAF7
# TRAF3IP1
# VHL
# HSPE1-MOB4
# GSR
# ZNRF3
# CNBP
# ETNK1
# EXTL3
# FAM151B
# FAM153B
# SLC4A4
# FAM229B
# FAM241A
# FBXL18
# TUBB2A
# FBXO47
# FGF19
# FHL2
# ZSWIM4
# ALDH6A1
# MBOAT2
# FOXJ3
# ZNF860
# FSCN1
# ZNF8
# GAPVD1
# ZNF641
# GJD3
# GK5
# GLG1
# ZNF556
# GPC4
# ZNF417
# ZNF347
# GRB2
# TMEM44
# TMEM151A
# KCNJ12
# EIF5AL1
# PARP2
# PCBD2
# PCLAF
# PDE12
# PDLIM5
# PDP2
# SHMT1
# PHAX
# PHB2
# SETBP1
# PLAGL2
# SELENON
# POC1A
# SEC22C
# POLR2E
# SCAMP4
# RRP36
# PRKCA
# RPL7L1
# RPL41
# PTMA
# PTPA
# RPL37
# PXMP4
# RABGAP1L
# RNF19B
# RNF149
# RNF11
# RILPL1
# ABCG8
# SLC1A5
# P2RY2
# SSBP2
# TLN1
# MEX3A
# TFDP2
# MKI67
# TEF
# MOB4
# MPLKIP
# TAF8
# MRPL17
# SYAP1
# MTHFD1
# SULT1B1
# MYOZ3
# NAA50
# PAFAH1B2
# SRF
# SPRYD4
# NF2
# SP2
# NFATC2IP
# SORD
# SON
# SMYD1
# ACBD7
# NUP50
# SLC7A11
# NUPL2
# OTUB1
# ENPP5
# RHOA
# CAPZA2
# CHERP
# CES2
# C11orf54
# DNAL1
# YWHAZ
# SLC7A5
# CLUAP1
# BCL7B
# CLPB
# NACC1
# ATP5A1
# CLIC5
# KLHL15
# DEFB105B
# CAPZA1
# CANX
# ANGPT4
# DEFB105A
# ALG14
# AVL9
# DDX3X
# DDX19B
# DCTN4
# CSE1L
# ASB16
# ARL10
# ORAI2
# CDKN1A
# CCND1
# E2F2
# COL1A1
# CCS
# GDE1
# CRISPLD2
# AGO2
# CCPG1
# DOT1L
# TAOK1
# CDC27
# SLC43A2
# SLC4A2
# SLC38A9
# SLC47A1
# DCTN5
# G3BP1
# TSC22D2
# SP110
# SLC6A17
# IFNLR1
# MSANTD4
# PRRG4
# ZBTB37
# SLC7A14
# SNRNP48
# RBM23
# SMU1
# SLCO3A1
# SP4
# SMS
# SLIT1
# BZW1
# PHLDA3
# SPIRE2
# MYPN
# TANGO2
# TARDBP
# TBC1D15
# SAR1A
# TERF2
# FAM71F2
# TES
# TET3
# TGIF1
# UBE2V1
# TGOLN2
# TIMM29
# TIMM8B
# TIRAP
# TLCD2
# SUGT1
# TAF13
# TMEM189-UBE2V1
# STPG1
# SPTY2D1
# SRSF10
# SLC35E1
# STAT2
# STMP1
# STOML1
# STX4
# TACR2
# TMEM189
# SUSD5
# SBNO1
# SVOP
# CDKN1B
# TACO1
# SLC35E2
# SLC24A4
# SLC2A3
# CRCP
# RPRM
# RRAGC
# CDK6
# RRAGD
# RXRB
# S1PR2
# ABI2
# SBF1
# SBK1
# KHSRP
# SCARF1
# SCN2B
# YIPF4
# SDE2
# SEC23IP
# ALDOA
# LRRC58
# SLC28A1
# RPL14
# SOD2
# RNF103-CHMP3
# IGF1R
# RNF14
# XIAP
# RNF157
# RNF185
# RNF187
# RNF219
# RNF38
# MDM2
# RNF4
# ZSCAN21
# RNF44
# RPL12
# WEE1
# SEC24A
# SEC61A1
# RAB5B
# HMGB1
# MLLT1
# CACNG8
# SLAMF1
# SLC10A6
# SLC10A7
# CASTOR2
# TMED8
# SLC25A22
# SYNJ2BP
# STK4
# SLC25A33
# SLC25A45
# GABPB1
# SLC26A2
# SIT1
# SIK2
# SIGLEC9
# SETD7
# SEMA6B
# SEMA7A
# SERF1A
# MAPK1
# SERF1B
# HOOK3
# MARCH7
# NACC2
# SH3D19
# SHE
# ARPP19
# AGO3
# SHISA9
# SCD
# SNRPD1
# CNKSR3
# TMEM145
# ZNF662
# ZNF551
# ZNF554
# MRNIP
# ZNF561
# ZNF562
# ZNF567
# ZNF623
# ZNF677
# ZNF573
# ZNF682
# ZNF711
# ZNF716
# ZNF749
# ZNF764
# ZNF785
# ZNF786
# ZNF487
# SIX4
# ZNF383
# ZNF207
# ZDHHC22
# ZFP14
# AKR7A2
# ZNF106
# ZNF117
# ZNF157
# ZNF208
# VEGFA
# SESN3
# ZNF268
# ZNF292
# HSD17B12
# ZNF317
# ZNF329
# FRK
# MAP3K9
# ZNF844
# FAM126B
# WASF2
# UGGT1
# CEP104
# TBC1D13
# DNAJC28
# EIF1AX
# SPPL2A
# SPRED1
# RNF115
# ZNF394
# ABHD2
# C5orf51
# RAB32
# KPNA6
# PLEKHA1
# NPR1
# PABPN1
# ARSK
# CDCP1
# DAZAP2
# TXNDC16
# ZNF91
# ZNRF2
# TMED4
# TIAL1
# RAB3IP
# ZSWIM1
# ZWINT
# FAHD1
# FAXC
# FEM1C
# KLHL21
# FAM83F
# GINM1
# HIST1H2BD
# DHODH
# ZDHHC15
# ZC3HAV1L
# ZBTB8A
# TRIR
# TPGS1
# TRA2B
# TRAF3IP2
# TRAF6
# HAUS3
# CYCS
# TRIM35
# TRMT2B
# ZNF566
# TSPEAR-AS2
# TTC9C
# TTLL12
# TTPAL
# TUBB
# TWISTNB
# TXNL1
# TPD52L2
# EBF4
# TOR1B
# SPRY4
# TMEM170A
# TMEM184C
# TMEM192
# TMEM233
# TMEM239
# TMEM33
# XKR4
# PGM2L1
# TMEM65
# TMEM81
# SMG1
# NFAT5
# TNFAIP8L1
# TNFRSF13C
# TOP3A
# TXNRD3NB
# SRCAP
# UBBP4
# WDR26
# WDR31
# WDR81
# CFHR3
# WNK3
# WT1
# XKR7
# RBMS2
# NFIX
# AMD1
# SETD5
# RHEBP1
# YTHDF3
# ZBTB43
# ZBTB46
# ZBTB5
# CCDC80
# VTA1
# UBL3
# VPS8
# SMCR8
# UGGT2
# UGT2B4
# UNKL
# UQCR11
# USP53
# PTP4A1
# MEF2D
# VEZT
# VGLL4
# VHLL
# VLDLR
# LZIC
# GAN
# VPS37A
# ANP32B
# PIWIL1
# RGS17
# FADS6
# FAM136A
# FAM199X
# FAM20B
# FBXO28
# FBXO45
# ALDH7A1
# FEN1
# FIBCD1
# FIGN
# FKBP14
# FKTN
# FLYWCH2
# FNDC3B
# FOLR1
# ALDH5A1
# FOXO1
# FOXRED2
# FRMD8
# FUT11
# FAM129B
# EXT1
# RGP1
# ETFDH
# DNASE2
# DNTTIP2
# DOCK7
# DPY19L1
# DSEL
# DTX3L
# DUSP3
# DYNLL2
# EDEM3
# EEF2
# EFNA5
# EHD4
# EIF5A2
# ELFN2
# EMC7
# ENAH
# ENSA
# ERC1
# ERCC6L2
# FUT9
# GABPB2
# GALNT4
# GALNT7
# HBP1
# HCFC1
# HEATR5A
# HIST1H2BK
# HIST1H3E
# HMBOX1
# AKIRIN1
# AKAP5
# HNRNPA0
# AKAP2
# HNRNPA1L2
# HNRNPA3
# HOXA13
# HOXA7
# HPRT1
# HPSE
# HRK
# HSP90AB1
# INCENP
# GTF3C6
# GTDC1
# GSTO2
# GLRX2
# AKT3
# GCLM
# GFPT1
# GGPS1
# AKT1S1
# GIMAP4
# GIPC1
# GJC1
# GMPR
# GRK3
# GOLGA2
# GOLGA3
# GOSR1
# GPR137C
# GPR173
# GPR27
# GPRC5B
# GREB1
# DMRT2
# DLC1
# DIO2
# CASP16P
# ANKRD42
# ANKFY1
# BRIX1
# BUB1
# ANGPTL3
# C14orf119
# C16orf72
# C17orf105
# C1orf229
# C1orf56
# C3orf36
# C3orf62
# C5AR2
# C8orf37
# C9orf3
# CABP4
# CACNA1A
# CACUL1
# CALCOCO2
# BARHL1
# BAP1
# BAK1
# ARIH2
# AP1S3
# AP2B1
# AP2M1
# APH1A
# APTX
# ARFGEF1
# ARHGEF39
# ARID5B
# ARL8A
# BAIAP2L1
# ARMCX6
# ASH2L
# ATL2
# ATP13A4
# ATP5G3
# ATXN2
# ATXN7L3
# BACE2
# CALM3
# CBX3
# DHTKD1
# CC2D1B
# CNNM1
# COL4A3BP
# COMMD2
# COPS8
# AMOTL1
# CPE
# CPM
# CRTAP
# CSDE1
# CTC1
# CTNS
# CTTN
# ALG9
# DARS2
# DCAF10
# DCAF17
# DCP1A
# DENND5B
# DFFA
# CNDP1
# CLDN16
# CLASP1
# CDT1
# CCDC171
# CCNB1
# CDC14B
# CDC25A
# CDC37L1
# CDC42EP4
# CDCA4
# CDK5R1
# ANAPC16
# CHST6
# CELSR3
# CENPI
# CENPL
# CENPM
# CERS4
# CHAF1B
# CHEK1
# CHMP3
# INO80
# INSIG1
# INTS7
# PISD
# OPA3
# ORC1
# ABL2
# OSBPL10
# OTUD4
# OXA1L
# PAK2
# PALD1
# PALM2
# PALM2-AKAP2
# PANK3
# PAQR5
# ABL1
# PCCB
# PCMTD1
# PDE4C
# PER1
# ABCF3
# PIAS2
# OLFML2A
# OLA1
# OGFOD1
# NOVA2
# NDUFB5
# NDUFV3
# NECAB3
# NEK9
# NFASC
# NIF3L1
# NKX2-2
# NMNAT1
# NQO2
# ACAD8
# NR3C1
# NRIP3
# NT5C2
# NUP155
# NUP35
# NUP62
# NUP93
# NUP98
# PIP4P2
# PITPNM3
# NCKIPSD
# AP1G1
# PRRT2
# PTBP3
# PTCHD3
# PXDC1
# PYCR1
# QKI
# QPCT
# RAB3C
# RAB5C
# AAED1
# RALY
# RAPGEF1
# RASSF9
# RBM41
# RBM43
# RDH13
# RECK
# REXO2
# RFC2
# PRKX
# PPTC7
# PPP6R1
# POC1B-GALNT4
# ABCC5
# PLA2G2C
# PLEKHA3
# PLEKHG3
# PLEKHM3
# PLXND1
# PNPLA3
# PNRC2
# POFUT2
# PPP2R5C
# POLQ
# POLR3K
# POU2F3
# POU5F1B
# PPIC
# PPIL4
# PPIL6
# PPL
# NDUFB11
# MZT1
# INTU
# MAP2K3
# LETMD1
# LIMA1
# LINC00346
# LMAN2L
# LMNB1
# LNPK
# LRIF1
# ADM
# LRP10
# LRPAP1
# ADH5
# LRTOMT
# LSM14A
# LURAP1L
# LY6K
# LYRM2
# LYRM7
# LYZ
# MACC1
# LETM2
# LEPROT
# LARS
# KIAA0408
# IPO7
# AGTPBP1
# ITGB8
# ITM2C
# JMY
# JRKL
# KANSL1
# KDSR
# KIAA1586
# LANCL3
# KIF1C
# AGMO
# KLF3
# KLHDC8A
# AEN
# KLLN
# KMT2A
# ADM2
# MAGI3
# MAP2K4
# MYLK3
# MARCH6
# ACO1
# MIGA1
# ACIN1
# MOB3A
# MOCS3
# MPP2
# MRE11
# MRM3
# MRO
# MRPL44
# MRPL51
# MRPS16
# MTAP
# MTRF1L
# MTRNR2L3
# MTRNR2L5
# MTRNR2L7
# MTX3
# MYDGF
# MGLL
# MFSD6
# METTL8
# MCTS1
# MARCKS
# MARK2
# MBD3
# MC2R
# MCFD2
# MCL1
# MCM4
# MCM8
# MDK
# METTL2B
# MECP2
# MED13
# MED19
# ACTB
# MED29
# MELK
# METTL14
# METTL21A
# NUFIP2

# %%
# Save genes and gene score columns to csv
ranked_genes[['Gene Symbol', 'gene_score']].to_csv('final_ranked_genes.csv', index=False)
