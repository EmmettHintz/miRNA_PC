# %%
import pandas as pd

# %%
ranked_features = pd.read_csv('./miRNA_disease_ranked.csv')
gene_targets = pd.read_csv('./s3_s4_genes.csv')

# %%
ranked_features['miRNA_rank'] = ranked_features['Importance'].rank()
miRNA_ranks = ranked_features['miRNA_rank'].to_dict()

# %%
total_miRNA = len(ranked_features)

# %% [markdown]
# *Formula*:
# score_gene= 1/t∑_{i=1}^{t}(1−rank_{miRNA}^{i}/total_{miRNA})
#
# *Explanation*
# - t: the number of miRNAs that target the gene
# - rank_{miRNA}^{i}: the rank of miRNA i that targets the gene
# - total_{miRNA}: the total number of miRNAs that target the gene
#
# ***High Gene Score***:
# - Indicates that the gene interacts with miRNAs that are highly ranked (i.e., have a low padj value).
# - A high score suggests that the gene is likely to be regulated by miRNAs that are significant in the context of differential expression analysis.
# - Thus, genes with high scores are potentially more important or relevant to the biological conditions being studied.
#
# ***Low Gene Score***:
# - Indicates that the gene interacts with miRNAs that are lower ranked (i.e., have a higher padj value).
# - A low score suggests that the gene is less likely to be regulated by significant miRNAs.
# - Such genes may be of lower priority for further investigation.

# %%
def calculate_gene_score(row, miRNA_ranks, total_miRNA):
    total_interactions = 0
    score = 0
    for miRNA in row.index[4:]:  # Assuming the miRNAs start from the 5th column
        if pd.notna(row[miRNA]) and row[miRNA] in miRNA_ranks:
            rank = miRNA_ranks[row[miRNA]]
            score += (1 - (rank / total_miRNA))
            total_interactions += 1
    if total_interactions > 0:
        return score / total_interactions
    else:
        return 0

# %%
gene_targets['gene_score'] = gene_targets.apply(calculate_gene_score, axis=1, miRNA_ranks=miRNA_ranks, total_miRNA=total_miRNA)

# Sort genes based on their scores in descending order
ranked_genes = gene_targets.sort_values(by='gene_score', ascending=False)

# Reorder columns so that 'gene_score' is the second column
columns = ['Gene Symbol', 'gene_score'] + [col for col in ranked_genes.columns if col not in ['Gene Symbol', 'gene_score']]
ranked_genes = ranked_genes[columns]


# Save ranked genes to a CSV file
ranked_genes.to_csv('ranked_genes.csv', index=False)

print(ranked_genes.shape)
# Display top ranked genes
print(ranked_genes.head(10))
# Out:
# (659, 13)
#     Gene Symbol  gene_score  p-value   FDR  Odd ratio  Number of interactions  \
# 189      GIGYF1    0.134615  0.00950  0.61      0.359                       7
# 517      TNRC6B    0.115385  0.01230  0.61      0.335                       6
# 263       LMNB2    0.115385  0.02330  0.61      0.385                       6
# 532       TXNIP    0.115385  0.02200  0.61      0.380                       6
# 315        NFIC    0.115385  0.04310  0.61      0.444                       6
# 172       FOXK1    0.096154  0.11000  0.61      0.518                       5
# 551       YWHAZ    0.096154  0.05520  0.61      0.424                       5
# 287        MIDN    0.096154  0.06090  0.61      0.436                       5
# 193        GLO1    0.096154  0.00897  0.61      0.266                       5
# 266      LRRC58    0.096154  0.04380  0.61      0.398                       5
#
#            microRNA 1        microRNA 2        microRNA 3        microRNA 4  \
# 189   hsa-miR-6734-3p      hsa-miR-4516   hsa-miR-6735-5p  hsa-miR-6769b-5p
# 517  hsa-miR-29b-1-5p  hsa-miR-6715b-5p   hsa-miR-6756-5p   hsa-miR-520d-3p
# 263   hsa-miR-6735-5p   hsa-miR-5582-5p      hsa-miR-1205      hsa-miR-378c
# 532   hsa-miR-520d-3p      hsa-miR-3975   hsa-miR-6735-5p  hsa-miR-29b-1-5p
# 315   hsa-miR-4727-5p   hsa-miR-6756-5p      hsa-miR-1205      hsa-miR-3975
# 172   hsa-miR-548h-5p   hsa-miR-520d-3p    hsa-miR-134-3p  hsa-miR-548ah-5p
# 551  hsa-miR-6769b-5p   hsa-miR-6756-5p  hsa-miR-548ah-5p    hsa-miR-134-3p
# 287  hsa-miR-548ah-5p   hsa-miR-6735-5p  hsa-miR-6715b-5p   hsa-miR-6756-5p
# 193   hsa-miR-6734-3p   hsa-miR-6815-5p      hsa-miR-4803  hsa-miR-548ah-5p
# 266      hsa-miR-4516      hsa-miR-1205   hsa-miR-5582-5p  hsa-miR-6715b-5p
#
#            microRNA 5        microRNA 6       microRNA 7
# 189  hsa-miR-548ah-5p   hsa-miR-520d-3p  hsa-miR-6756-5p
# 517      hsa-miR-4511   hsa-miR-6734-3p              NaN
# 263      hsa-miR-3975   hsa-miR-6756-5p              NaN
# 532      hsa-miR-4511  hsa-miR-548ah-5p              NaN
# 315      hsa-miR-4516   hsa-miR-6815-5p              NaN
# 172  hsa-miR-6715b-5p               NaN              NaN
# 551      hsa-miR-4516               NaN              NaN
# 287  hsa-miR-6769b-5p               NaN              NaN
# 193   hsa-miR-520d-3p               NaN              NaN
# 266   hsa-miR-520d-3p               NaN              NaN

# %%
# get top 50 genes
top_genes = ranked_genes.iloc[:,1].tolist()
# print the row and the score as a string on a new line
for i in range(len(ranked_genes)):
    if str(top_genes[i]) != 'nan':
        # print(ranked_genes.iloc[i,0], ranked_genes.iloc[i,1], sep = '\t')
        print(ranked_genes.iloc[i,0])
# Out:
# GIGYF1
# TNRC6B
# LMNB2
# TXNIP
# NFIC
# FOXK1
# YWHAZ
# MIDN
# GLO1
# LRRC58
# SBNO1
# FEM1A
# KIAA1191
# MAP3K2
# MAFK
# DNAJC10
# KIAA0513
# FGFR1OP
# IGF1R
# HMGN2
# NFIX
# ELFN2
# DGAT2
# PABPN1
# NUDT3
# C16orf58
# CDKN1A
# ZBTB33
# YIPF4
# UNC5B
# ULK1
# UBE2H
# TRAF6
# TAOK1
# SF3B3
# SELENON
# RUFY2
# REST
# RAB5B
# PTBP1
# PAFAH1B2
# CRY2
# ORAI2
# ABI2
# AGO2
# ACOX1
# ATP5A1
# ZNF394
# FAM83F
# FAM83H
# ZNF641
# ZNF585B
# ZNF451
# FEM1C
# ZNF385A
# FAM212B
# FOLR1
# FOXC1
# ZBTB7A
# ZBTB46
# SLC6A4
# FZD9
# FZR1
# ZBTB37
# NACC2
# RBMS2
# GATA6
# SH3GLB1
# BCL2L1
# NUP62
# NUMBL
# SGPL1
# NUCB1
# DSN1
# DUSP2
# SHISA9
# F2RL3
# SHOC2
# SIK1
# NFIB
# ENPP5
# KIAA1456
# ZWINT
# SLC12A7
# FAM102B
# MNT
# SETD1B
# HIST2H2BE
# LZIC
# LSM14A
# HOOK3
# LRTOMT
# TMEM241
# TMEM214
# TMEM184A
# AVL9
# STAT3
# INO80D
# SYT7
# TAF1D
# KREMEN1
# KMT2A
# KDELR1
# ATP1B3
# RDH11
# MLLT1
# SPRY4
# MKNK2
# WSB1
# MINK1
# ACACA
# MEX3A
# UBXN2A
# METTL8
# UBE2G1
# METTL14
# MDM2
# TSR1
# TRIOBP
# MDFI
# MCFD2
# TP53
# AHCYL2
# NEK7
# NACC1
# CAPZA2
# PLCE1
# SBF1
# PLEKHM1
# C2orf48
# POLR1B
# SOD2
# CLPB
# RLIM
# SAMD8
# PPARGC1B
# RNF11
# PPM1F
# PRIM1
# CHEK2
# C18orf32
# CEP97
# PVR
# PRRC2B
# CCDC198
# CDH6
# PRRG4
# RPL17-C18orf32
# CCDC80
# PTGES3L
# PTMA
# PTP4A1
# RPRD2
# CCNT1
# AKR7A2
# C6orf223
# C11orf54
# SCOC
# RBM23
# ANP32B
# DCAF7
# RBM12B
# ALDOA
# ZNF460
# C10orf76
# PEA15
# RFC2
# RGMB
# CUL3
# PTPN14
# XIAP
# SCAMP4
# CRK
# CSNK2A1
# RHOG
# RPL14
# RPL41
# SPATA5
# TBC1D13
# SSU72
# SOWAHA
# AHCY
# TBL1XR1
# TCF3
# RHOC
# SRSF1
# SOCS5
# SRSF2
# RNASEH1
# SVOP
# SPATA6
# RPA1
# SPOPL
# STK10
# RHOF
# SPRYD3
# SRRD
# RNF40
# RNF149
# RNF115
# SRRM4
# SETD7
# SNRNP27
# SECISBP2L
# SCAMP3
# SLC25A36
# SLC25A33
# SLC22A23
# SLC16A9
# SDE2
# SEC61A1
# SIGLEC10
# SIAH3
# SELENOI
# SND1
# SH3BP2
# SGPP2
# AKAP11
# SEM1
# SENP2
# SERF1A
# SERF1B
# SGMS2
# SFN
# SLC2A1
# SLC2A5
# SATB2
# SAR1B
# SNAP47
# SMAD5
# SLIT3
# RRP36
# SLIT1
# SESN2
# SLC7A14
# AKT3
# SLC7A1
# S100A16
# SAA1
# SAMD12
# SLC5A3
# SLC4A2
# SLC39A9
# SLC39A13
# SLC39A11
# SLC35F5
# SLC35C2
# TEDC1
# BHMT2
# TERF2
# MYPN
# GGCX
# SMG1
# SP1
# ABCC6
# CDKN1B
# HIC2
# BZW1
# CBX5
# CREBRF
# DCTN5
# MSANTD4
# POU2F1
# PKM
# SLC35F6
# DSTYK
# BACH1
# VEGFA
# GAN
# CRKL
# MPLKIP
# ZBTB34
# SETD5
# GJD3
# ANKRD52
# LARP1
# HAUS3
# PHB2
# RCC2
# SRCAP
# ZBTB8B
# ZNF708
# ABCG8
# ZBTB18
# CBX6
# G3BP1
# SFT2D2
# CDK6
# KHSRP
# TNRC6A
# PLAGL2
# CRCP
# YOD1
# CELF1
# SYNJ2BP
# LINC00598
# HDGF
# ZNF264
# BTG2
# CCND1
# KLHL15
# COX6B1
# UBN2
# MAPK1
# ARPP19
# AGO3
# CYP20A1
# SCD
# ASB16
# CCND2
# RPL7L1
# PURB
# PPP1R15B
# FAM241A
# DNAL1
# SOX4
# CACNG8
# YY1
# ZNF207
# SUMO1
# TEX261
# TPRG1L
# TNFRSF10B
# TNFRSF21
# TNKS2
# TOLLIP
# TOR2A
# TOR4A
# ADM
# TMUB1
# TRAPPC2
# TSKU
# TTYH3
# TUBD1
# TXLNA
# ADH5
# TNFAIP1
# TMEM246
# POTEM
# TMED10
# TFAP4
# THBS1
# THEM4
# THY1
# TIPIN
# TM9SF3
# TMED4
# TMEM239
# TMEM120B
# TMEM127
# TMEM134
# TMEM167A
# TMEM170A
# TMEM19
# ACVR2B
# UBE2Q1
# UHMK1
# ZNF805
# ZNF317
# ZNF623
# ZNF678
# ZNF711
# ZNF724
# ZNF774
# ZNF84
# VSIR
# ZNFX1
# DR1
# FRK
# GRPEL2
# HSD17B12
# POTEG
# ZNF154
# ZNF12
# ZMIZ2
# ZFYVE26
# ZDHHC5
# ZCCHC2
# ZBTB40
# ABHD17B
# YWHAB
# YTHDF3
# ABL1
# YARS
# XRCC6
# WNK1
# WDR13
# WBP2
# WASF2
# TOB2
# PMPCA
# RBPJ
# EXTL3
# FLVCR1
# FLCN
# BBC3
# FGF7
# FGF5
# BBS5
# FBXO45
# FBRS
# FAM9C
# FAM83C
# FAM53C
# FAM19A3
# FAM129B
# FAM109A
# ETNK1
# BAZ2A
# ERGIC2
# EPS15L1
# EN2
# EMC3
# BCAS4
# ELAVL2
# EIF5AL1
# EIF4H
# EIF3H
# EIF2S3
# EGF
# DPP9
# DOT1L
# DNTTIP2
# FOXJ2
# FOXK2
# RASSF4
# B4GALNT4
# GRB10
# GPRC5B
# GPRC5A
# GPR75
# GPR37L1
# GPR27
# GPR173
# GPR155
# GPR137B
# GOLGA8J
# GOLGA2
# GMEB2
# GMDS
# GLP2R
# GLIS3
# FOXRED2
# GJB1
# GINS4
# B4GALT1
# GDPD5
# GDI1
# GDF5OS
# GDF15
# GDF11
# GCC1
# GALNT17
# G3BP2
# FZD6
# FYCO1
# FTSJ3
# DNLZ
# DNAJC28
# DNAH9
# CASKIN2
# CFAP73
# CENPN
# CELSR3
# CDC42SE1
# CDC25A
# CDC14B
# CD276
# CCSAP
# CCNY
# CCNL1
# CCL16
# CCDC71L
# CCDC59
# CAVIN1
# CAPZA1
# DNAH10OS
# CAPS
# CAPRIN2
# CAPN15
# CALR
# C9orf40
# C3orf33
# C17orf51
# BCL7A
# C15orf40
# C11orf58
# BTG3
# BRIX1
# BRI3BP
# BMP2
# CHAC1
# CHSY1
# CKS2
# CLASP1
# DESI1
# DDI2
# DDA1
# DCTN6
# DCP2
# DAZAP2
# DARS
# DAB2IP
# CYP4A22
# CYP4A11
# CYP2W1
# CYP11A1
# CXorf38
# CTNNB1
# CTDNEP1
# BCL2L2
# CRTAP
# CREBZF
# CPS1
# COX6C
# COX19
# COL5A1
# COL4A3BP
# COL1A1
# CMTM4
# CLPX
# CLIP4
# CLIC4
# CLDN12
# GSTO2
# HAS2
# HAUS8
# NOC2L
# PDE12
# PCGF3
# PARP1
# PAK4
# PAK2
# AP2M1
# OSTM1
# OSBPL10
# ABCC12
# OR7D2
# OCLN
# APH1A
# NR3C1
# NOVA2
# NNT
# MTMR1
# NLRP6
# NKIRAS2
# APOH
# ARIH1
# NDUFB11
# NDUFAF6
# NDUFAF3
# NCLN
# NAV1
# NAP1L4
# MYO1F
# MYLIP
# MVB12B
# MTRF1L
# PDE4DIP
# PER1
# PFKP
# PGM2L1
# RAP1B
# RANGAP1
# RAC3
# ALOX15
# RAB42
# RAB3IP
# RAB15
# RAB11FIP1
# R3HDM2
# QSOX1
# PYCARD
# PXDC1
# PTPN9
# PTPN4
# PTPN1
# PTPDC1
# ANKRD33B
# PRR14L
# PRKD3
# PRKCB
# PPP6R1
# POLR2E
# PNRC1
# BLCAP
# PLEKHG3
# PLA2G4D
# PLA2G16
# PHYKPL
# PHLPP2
# MTPAP
# MTHFD2
# HIPK3
# HSPA4
# KCNK5
# KCNJ6
# KCNH2
# KCNH1
# KBTBD6
# ITGA3
# ITGA2
# ISCA2
# IRAK2
# IPP
# INMT
# IDH3A
# ICA1L
# HSPA8
# HSP90B1
# MTHFD1
# HOXB3
# HOXA7
# HOXA3
# HOXA13
# HNRNPUL1
# HNRNPC
# B2M
# HMBOX1
# HIST3H3
# HIST1H2BD
# HIST1H2AH
# HIST1H2AG
# HIST1H2AE
# HIST1H1E
# ATXN7L3B
# ATXN2
# KIF6
# KLF7
# MSANTD2
# MRPS16
# MPP2
# MKI67
# MIER1
# MIEF2
# ARL5A
# MFRP
# METTL21A
# MEMO1
# MED17
# MDK
# MBD4
# MAT2A
# MARK2
# ASNA1
# LTBP2
# LRRC3C
# LRIG2
# ATP5G3
# LLPH
# LLGL1
# LIPC
# LIMK1
# LIMA1
# LIAS
# LGSN
# KPNA6
# KLHL21
# NUFIP2

# %%
# Save genes and gene score columns to csv
ranked_genes[['Gene Symbol', 'gene_score']].to_csv('final_ranked_genes.csv', index=False)
