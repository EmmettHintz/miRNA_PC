# %%
import pandas as pd

# %%
miEAA = pd.read_csv('./s3_s4_miEAA.csv')
print(miEAA.columns)
# Out:
# Index(['Category', 'Subcategory', 'Enrichment', 'P-value', 'P-adjusted',
#        'Q-value', 'Observed', 'miRNAs/precursors'],
#       dtype='object')

# %%
# Print unique categories
print(miEAA['Category'].unique())
# Out:
# ['Interactions (NPInter)'
#  'Annotations derived over miRTarBase (Gene Ontology)'
#  'Target genes (miRTarBase)' 'Diseases (MNDR)' 'Published Diseases'
#  'Pathways (KEGG)' 'KEGG (miRPathDB)' 'Tissue specific (isomiRdb)'
#  'Expressed in tissue (Tissue Atlas)']

# %%
gc = pd.read_csv('./s3_s4_gc.csv')
gc.columns
# Out:
# Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')

# %%
miEAA.head()
# Out:
#                                             Category  \
# 0                             Interactions (NPInter)
# 1  Annotations derived over miRTarBase (Gene Onto...
# 2  Annotations derived over miRTarBase (Gene Onto...
# 3  Annotations derived over miRTarBase (Gene Onto...
# 4  Annotations derived over miRTarBase (Gene Onto...
#
#                                          Subcategory Enrichment   P-value  \
# 0                                              MAT2A   enriched  0.000385
# 1  potassium ion export across plasma membrane GO...   enriched  0.001003
# 2  regulation of small GTPase mediated signal tra...   enriched  0.001207
# 3       central nervous system development GO0007417   enriched  0.001536
# 4  negative regulation of CD8-positive, alpha-bet...   enriched  0.001538
#
#    P-adjusted   Q-value  Observed  \
# 0    0.000385  0.327302         3
# 1    0.001003  0.510639         4
# 2    0.001207  0.510639         8
# 3    0.001536  0.510639         9
# 4    0.001538  0.510639         3
#
#                                    miRNAs/precursors
# 0    hsa-miR-1205; hsa-miR-29b-1-5p; hsa-miR-1250-5p
# 1  hsa-miR-1205; hsa-miR-29b-1-5p; hsa-miR-4516; ...
# 2  hsa-miR-1205; hsa-miR-29b-1-5p; hsa-miR-6769b-...
# 3  hsa-miR-1205; hsa-miR-1250-5p; hsa-miR-4516; h...
# 4       hsa-miR-1205; hsa-miR-29b-1-5p; hsa-miR-4516

# %%
gc.head()
# Out:
#    Score                                     SuperPath Name  \
# 0  166.1                                Signal Transduction
# 1  166.1                                 Infectious Disease
# 2  166.1                    Gene Expression (Transcription)
# 3   53.0  Regulation of Activated PAK-2p34 By Proteasome...
# 4   53.0                      Cellular Responses to Stimuli
#
#    # SuperPath Total Genes  # SuperPath Matched Genes  \
# 0                     2597                        453
# 1                     1818                        339
# 2                     1543                        320
# 3                      943                        193
# 4                      819                        175
#
#                              Matched Genes (Symbols)  \
# 0  MAP2K1, ARL4C, NHS, CARM1, ADM, ADM2, NCKAP1, ...
# 1  CANX, CAPN1, RPS2, MAP2K1, MAP2K3, RPL12, MUC4...
# 2  LRPPRC, MAP2K6, ZNF317, CARM1, ZNF154, HAND2, ...
# 3  CANX, EIF2S1, EIF2S3, MAP2K4, ABCA12, FBXL7, T...
# 4  EIF2S1, RPS2, MAP2K3, RPL12, EIF2S3, CAPZA1, C...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/signal_tr...
# 1  https://pathcards.genecards.org/card/infectiou...
# 2  https://pathcards.genecards.org/card/gene_expr...
# 3  https://pathcards.genecards.org/card/regulatio...
# 4  https://pathcards.genecards.org/card/cellular_...

# %%
# print the categories from Reactome
print(miEAA['Category'].unique())
print(miEAA['Category'].value_counts())
# Out:
# ['Interactions (NPInter)'
#  'Annotations derived over miRTarBase (Gene Ontology)'
#  'Target genes (miRTarBase)' 'Diseases (MNDR)' 'Published Diseases'
#  'Pathways (KEGG)' 'KEGG (miRPathDB)' 'Tissue specific (isomiRdb)'
#  'Expressed in tissue (Tissue Atlas)']
# Category
# Annotations derived over miRTarBase (Gene Ontology)    354
# Interactions (NPInter)                                 122
# Target genes (miRTarBase)                               47
# Expressed in tissue (Tissue Atlas)                      15
# Diseases (MNDR)                                         12
# Pathways (KEGG)                                         11
# Published Diseases                                       5
# KEGG (miRPathDB)                                         1
# Tissue specific (isomiRdb)                               1
# Name: count, dtype: int64

# %%
# find the overlap of the overlap of supepath name and subcategory
for i in miEAA['Category'].unique():
    print(i)
    print(miEAA[miEAA['Category'] == i]['Subcategory'].unique())
# Out:
# Interactions (NPInter)
# ['MAT2A' 'C18orf8' 'CHD4' 'GPX3' 'IP6K3' 'SERPING1' 'USP9Y' 'ENPP2'
#  'KIAA1109' 'PRNP' 'CRIM1' 'CTSB' 'PNMA1' 'RBM3' 'CIRBP' 'DISC1' 'EDIL3'
#  'ERBB2' 'FMR1' 'G3BP1' 'GNAI1' 'HES1' 'HPRT1' 'MBIP' 'NPTN' 'PHYHIPL'
#  'PTEN' 'REEP3' 'REEP5' 'SUZ12' 'UBE2B' 'USO1' 'VEZT' 'ALKBH5' 'ACPL2'
#  'ACTA1' 'ACVR2A' 'ADAMTS9' 'ANKRD26' 'ARF6' 'ARGLU1' 'ARRDC3' 'ATP13A3'
#  'ATP1A1' 'ATXN1' 'BDP1' 'BOD1' 'BTAF1' 'C14orf37' 'CAB39' 'CAPN2' 'CBLN2'
#  'CDK2AP1' 'CEBPD' 'CENPQ' 'CFLAR' 'COL4A2' 'COPS8' 'DNAJB9' 'DOCK5'
#  'EIF1' 'FAM13C' 'FBXL3' 'FBXW11' 'FGB' 'FOS' 'FOXC1' 'GATA6' 'GINS1'
#  'GJA1' 'GOLGA4' 'GPR37' 'GREM1' 'IBTK' 'IDH3G' 'JPH1' 'KCNMB4' 'KIF5C'
#  'LHFPL2' 'LIMCH1' 'LRP12' 'MBNL3' 'MINK1' 'MOG' 'MTUS1' 'NEFL' 'NEK9'
#  'NIPSNAP3A' 'OGG1' 'PCSK6' 'PIP4K2A' 'PISD' 'PMP22' 'PPP1R15B' 'PPP1R1C'
#  'PRDM2' 'PTPLAD1' 'RAB12' 'RALGPS2' 'RANBP9' 'RBM12B' 'RBM23' 'RBM24'
#  'ROBO1' 'RRBP1' 'SLC3A1' 'SNRNP70' 'SORL1' 'SPAST' 'SUSD1' 'TMEM165'
#  'TMEM184B' 'TNRC18' 'UBQLN1' 'UXS1' 'WHSC1' 'YTHDF2' 'YWHAH' 'ZCCHC3'
#  'ZEB2' 'ZNF512' 'ZZZ3']
# Annotations derived over miRTarBase (Gene Ontology)
# ['potassium ion export across plasma membrane GO0097623'
#  'regulation of small GTPase mediated signal transduction GO0051056'
#  'central nervous system development GO0007417'
#  'negative regulation of CD8-positive, alpha-beta T cell differentiation GO0043377'
#  'axonogenesis GO0007409' 'kinetochore GO0000776'
#  'membrane repolarization during cardiac muscle cell action potential GO0086013'
#  'microtubule nucleation GO0007020'
#  'cellular response to interleukin-1 GO0071347'
#  'N-acetylneuraminate catabolic process GO0019262'
#  'antigen processing and presentation of endogenous peptide antigen via MHC class I GO0019885'
#  'cellular response to hepatocyte growth factor stimulus GO0035729'
#  'cellular response to nicotine GO0071316'
#  'hepatocyte growth factor receptor signaling pathway GO0048012'
#  'mitochondrial fission GO0000266'
#  'negative regulation of forebrain neuron differentiation GO2000978'
#  'regulation of neuron apoptotic process GO0043523'
#  'structural constituent of skin epidermis GO0030280'
#  'tRNA-splicing ligase complex GO0072669'
#  'tRNA splicing, via endonucleolytic cleavage and ligation GO0006388'
#  'transmembrane receptor protein serinethreonine kinase activity GO0004675'
#  'tricuspid valve morphogenesis GO0003186'
#  'cellular response to growth factor stimulus GO0071363'
#  'Cul4-RING E3 ubiquitin ligase complex GO0080008' 'U5 snRNP GO0005682'
#  'nuclear matrix GO0016363' 'tau protein binding GO0048156'
#  'vesicle fusion with Golgi apparatus GO0048280'
#  'potassium ion transmembrane transport GO0071805'
#  'endoplasmic reticulum tubular network GO0071782'
#  'peroxisomal matrix GO0005782' 'CCR chemokine receptor binding GO0048020'
#  'cellular response to organic cyclic compound GO0071407'
#  'eosinophil chemotaxis GO0048245'
#  'membrane repolarization during ventricular cardiac muscle cell action potential GO0098915'
#  'monocyte chemotaxis GO0002548'
#  'voltage-gated potassium channel activity involved in cardiac muscle cell action potential repolarization GO0086008'
#  'protein autophosphorylation GO0046777'
#  'cellular response to lipopolysaccharide GO0071222'
#  'NLS-bearing protein import into nucleus GO0006607'
#  'apical junction complex GO0043296'
#  'membrane protein intracellular domain proteolysis GO0031293'
#  'eukaryotic translation initiation factor 4F complex GO0016281'
#  'monoatomic ion homeostasis GO0050801'
#  'positive regulation of protein import into nucleus GO0042307'
#  'positive regulation of sodium ion transmembrane transporter activity GO2000651'
#  'positive regulation of interleukin-1 beta production GO0032731'
#  'stimulatory C-type lectin receptor signaling pathway GO0002223'
#  'p53 binding GO0002039' 'dynein complex binding GO0070840'
#  'positive regulation of Rho protein signal transduction GO0035025'
#  'Fc-epsilon receptor signaling pathway GO0038095'
#  'cortical actin cytoskeleton GO0030864'
#  'hematopoietic progenitor cell differentiation GO0002244'
#  'spliceosomal complex assembly GO0000245'
#  'regulation of translation GO0006417' 'cell differentiation GO0030154'
#  'U2-type precatalytic spliceosome GO0071005'
#  'dystroglycan binding GO0002162' 'endothelial cell activation GO0042118'
#  'establishment of epithelial cell polarity GO0090162'
#  'learning GO0007612'
#  'positive regulation of innate immune response GO0045089'
#  'positive regulation of type I interferon-mediated signaling pathway GO0060340'
#  'RSC-type complex GO0016586' 'apical plasma membrane GO0016324'
#  'gamma-secretase complex GO0070765'
#  'barbed-end actin filament capping GO0051016'
#  'killing of cells of another organism GO0031640'
#  'negative regulation of BMP signaling pathway GO0030514'
#  'positive regulation of natural killer cell mediated cytotoxicity GO0045954'
#  'precatalytic spliceosome GO0071011'
#  'triglyceride catabolic process GO0019433'
#  'androgen receptor signaling pathway GO0030521'
#  'lymphocyte chemotaxis GO0048247'
#  'negative regulation of cell-matrix adhesion GO0001953'
#  'ovarian follicle development GO0001541'
#  'positive regulation of cytoplasmic translation GO2000767'
#  'positive regulation of interleukin-1 production GO0032732'
#  'prostaglandin metabolic process GO0006693'
#  'SCF ubiquitin ligase complex GO0019005'
#  'antimicrobial humoral immune response mediated by antimicrobial peptide GO0061844'
#  'condensed chromosome GO0000793' 'angiostatin binding GO0043532'
#  'chloride channel inhibitor activity GO0019869'
#  'mitochondrial proton-transporting ATP synthase, catalytic core GO0005754'
#  'positive regulation of smoothened signaling pathway GO0045880'
#  'proteoglycan binding GO0043394'
#  'proton-transporting ATP synthase complex, catalytic core F1 GO0045261'
#  'proton-transporting ATP synthase complex GO0045259'
#  '7-methylguanosine cap hypermethylation GO0036261'
#  'CD8-positive, alpha-beta T cell activation GO0036037'
#  'N-acetylgalactosaminyl-proteoglycan 3-beta-glucuronosyltransferase activity GO0050510'
#  'T cell receptor binding GO0042608' 'U1 snRNP GO0005685'
#  'cell fate specification GO0001708'
#  'cellular response to dexamethasone stimulus GO0071549'
#  'collagen type V trimer GO0005588' 'collagen type XI trimer GO0005592'
#  'commitment complex GO0000243'
#  'eukaryotic translation initiation factor 3 complex GO0005852'
#  'eye morphogenesis GO0048592'
#  'formation of cytoplasmic translation initiation complex GO0001732'
#  'glucose-1,6-bisphosphate synthase activity GO0047933'
#  'glucuronosyl-N-acetylgalactosaminyl-proteoglycan 4-beta-N-acetylgalactosaminyltransferase activity GO0047238'
#  'histone H4K20 methyltransferase activity GO0042799'
#  'integrin biosynthetic process GO0045112'
#  'inward rectifier potassium channel complex GO1902937'
#  'membrane depolarization during action potential GO0086010'
#  'membrane repolarization during action potential GO0086011'
#  'monoatomic anion transmembrane transporter activity GO0008509'
#  'negative regulation of endodermal cell differentiation GO1903225'
#  'negative regulation of potassium ion export across plasma membrane GO1903765'
#  'negative regulation of transcription by RNA polymerase III GO0016480'
#  'negative regulation of tyrosine phosphorylation of STAT protein GO0042532'
#  'neuron remodeling GO0016322' 'pICln-Sm protein complex GO0034715'
#  'positive regulation of CD8-positive, alpha-beta T cell activation GO2001187'
#  'positive regulation of CD8-positive, alpha-beta T cell proliferation GO2000566'
#  'positive regulation of enamel mineralization GO0070175'
#  'positive regulation of interleukin-17 production GO0032740'
#  'positive regulation of potassium ion transmembrane transport GO1901381'
#  'protein complex oligomerization GO0051259'
#  'regulation of bone resorption GO0045124'
#  'regulation of potassium ion transmembrane transport GO1901379'
#  'regulation of protein localization to plasma membrane GO1903076'
#  'regulation of resting membrane potential GO0060075'
#  'spliceosomal tri-snRNP complex GO0097526'
#  'transport vesicle membrane GO0030658'
#  'ventricular cardiac muscle cell action potential GO0086005'
#  'membrane repolarization GO0086009'
#  'nuclear androgen receptor binding GO0050681' 'amelogenesis GO0097186'
#  'base-excision repair, gap-filling GO0006287' 'ciliary base GO0097546'
#  'dorsalventral pattern formation GO0009953'
#  'establishment of mitotic spindle localization GO0040001'
#  'locomotory behavior GO0007626'
#  'negative regulation of amyloid-beta clearance GO1900222'
#  'positive regulation of viral life cycle GO1903902'
#  'regulation of mitochondrial translation GO0070129'
#  'regulation of membrane potential GO0042391'
#  'positive regulation of peptidyl-tyrosine phosphorylation GO0050731'
#  'activation of NF-kappaB-inducing kinase activity GO0007250'
#  'positive regulation of interleukin-10 production GO0032733'
#  'positive regulation of phagocytosis GO0050766'
#  'protein targeting GO0006605'
#  'endoplasmic reticulum organization GO0007029'
#  'protein N-linked glycosylation GO0006487'
#  'embryonic organ development GO0048568'
#  'extracellular matrix assembly GO0085029'
#  'transmembrane transporter activity GO0022857'
#  'execution phase of apoptosis GO0097194'
#  'glycerophospholipid catabolic process GO0046475'
#  'interleukin-17A-mediated signaling pathway GO0038173'
#  'mRNA regulatory element binding translation repressor activity GO0000900'
#  'peptidyl-tyrosine dephosphorylation GO0035335'
#  'positive regulation of execution phase of apoptosis GO1900119'
#  'positive regulation of phosphorylation GO0042327'
#  'post-Golgi vesicle-mediated transport GO0006892'
#  'protein-lysine N-methyltransferase activity GO0016279'
#  'ubiquitin-ubiquitin ligase activity GO0034450'
#  'voltage-gated potassium channel activity GO0005249'
#  'neuron projection GO0043005' 'receptor complex GO0043235'
#  'maturation of SSU-rRNA from tricistronic rRNA transcript SSU-rRNA, 5.8S rRNA, LSU-rRNA GO0000462'
#  'regulation of G protein-coupled receptor signaling pathway GO0008277'
#  'cellular response to reactive oxygen species GO0034614'
#  'nuclear localization sequence binding GO0008139'
#  '3-5 DNA helicase activity GO0043138'
#  'GDP-mannose 4,6-dehydratase activity GO0008446'
#  'GDP-mannose metabolic process GO0019673' 'NADP+ binding GO0070401'
#  'axonemal outer doublet GO0097545'
#  'centriolar subdistal appendage GO0120103'
#  'cholesterol transport GO0030301'
#  'de novo GDP-L-fucose biosynthetic process GO0042351'
#  'four-way junction helicase activity GO0009378'
#  'inner dynein arm assembly GO0036159'
#  'marginal zone B cell differentiation GO0002315'
#  'microtubule-based process GO0007017'
#  'neurotransmitter biosynthetic process GO0042136'
#  'nitric oxide mediated signal transduction GO0007263'
#  'platelet dense tubular network GO0031094'
#  'regulation of endocytic recycling GO2001135'
#  'regulation of heme biosynthetic process GO0070453'
#  'regulation of protein metabolic process GO0051246'
#  'insulin receptor signaling pathway GO0008286'
#  'transcription factor TFTC complex GO0033276'
#  'AMP-activated protein kinase activity GO0004679'
#  'DNA-dependent protein kinase complex GO0070418'
#  'DNA end binding GO0045027' 'Ku70Ku80 complex GO0043564'
#  'NLS-dependent protein nuclear import complex GO0042564'
#  'actin filament reorganization GO0090527'
#  'cell junction assembly GO0034329' 'cyclin D2-CDK4 complex GO0097129'
#  'ether lipid metabolic process GO0046485'
#  'heterochromatin organization GO0070828'
#  'monoatomic anion transport GO0006820'
#  'nonhomologous end joining complex GO0070419'
#  'nuclear import signal receptor activity GO0061608'
#  'nucleobase-containing compound metabolic process GO0006139'
#  'nucleotide-activated protein kinase complex GO0031588'
#  'peptidyl-lysine dimethylation GO0018027'
#  'peptidyl-lysine monomethylation GO0018026'
#  'positive regulation of interferon-beta production GO0032728'
#  'positive regulation of natural killer cell mediated cytotoxicity directed against tumor cell target GO0002860'
#  'recombinational repair GO0000725'
#  'regulation of heart rate by hormone GO0003064'
#  'regulation of membrane repolarization GO0060306'
#  'response to heat GO0009408'
#  'susceptibility to T cell mediated cytotoxicity GO0060370'
#  'susceptibility to natural killer cell mediated cytotoxicity GO0042271'
#  'MHC class I protein binding GO0042288'
#  'regulation of glycolytic process GO0006110'
#  'SCF-dependent proteasomal ubiquitin-dependent protein catabolic process GO0031146'
#  'delayed rectifier potassium channel activity GO0005251'
#  'positive regulation of chemotaxis GO0050921'
#  'potassium ion homeostasis GO0055075'
#  'antigen processing and presentation GO0019882'
#  'central nervous system neuron development GO0021954'
#  'positive regulation of T cell proliferation GO0042102'
#  'trans-Golgi network GO0005802'
#  'cyclin-dependent protein serinethreonine kinase activator activity GO0061575'
#  'phosphorylation GO0016310'
#  'positive regulation of inflammatory response GO0050729'
#  'regulation of transcription involved in G1S transition of mitotic cell cycle GO0000083'
#  'establishment or maintenance of cell polarity GO0007163'
#  'negative regulation of I-kappaB kinaseNF-kappaB signaling GO0043124'
#  'calcium-dependent protein binding GO0048306'
#  'engulfment of apoptotic cell GO0043652'
#  'enzyme activator activity GO0008047'
#  'non-membrane spanning protein tyrosine kinase activity GO0004715'
#  'negative regulation of endoplasmic reticulum stress-induced intrinsic apoptotic signaling pathway GO1902236'
#  'negative regulation of protein localization to plasma membrane GO1903077'
#  'post-translational protein modification GO0043687'
#  'regulation of dosage compensation by inactivation of X chromosome GO1900095'
#  'regulation of focal adhesion assembly GO0051893'
#  'cytokine-mediated signaling pathway GO0019221'
#  'growth factor activity GO0008083'
#  'K48-linked deubiquitinase activity GO1990380'
#  'L-glutamine transmembrane transporter activity GO0015186'
#  'MIS12MIND type complex GO0000444' 'Set1CCOMPASS complex GO0048188'
#  'acyl-CoA oxidase activity GO0003997' 'autolysosome GO0044754'
#  'brain morphogenesis GO0048854'
#  'embryonic cranial skeleton morphogenesis GO0048701'
#  'fatty acid beta-oxidation using acyl-CoA oxidase GO0033540'
#  'fatty acid catabolic process GO0009062'
#  'glucuronosyltransferase activity GO0015020'
#  'glutamine transport GO0006868'
#  'hydrogen peroxide biosynthetic process GO0050665'
#  'lysophospholipase activity GO0004622'
#  'mRNA splice site selection GO0006376'
#  'megakaryocyte development GO0035855'
#  'negative regulation of hematopoietic progenitor cell differentiation GO1901533'
#  'negative regulation of hippo signaling GO0035331'
#  'neurotransmitter transport GO0006836'
#  'palmitoyl-CoA oxidase activity GO0016401'
#  'positive regulation of DNA damage response, signal transduction by p53 class mediator resulting in transcription of p21 class mediator GO1902164'
#  'positive regulation of protein acetylation GO1901985'
#  'positive regulation of tyrosine phosphorylation of STAT protein GO0042531'
#  'regulation of p38MAPK cascade GO1900744'
#  'regulation of vesicle size GO0097494'
#  'renal water homeostasis GO0003091' 'secretory granule GO0030141'
#  'very long-chain fatty acid beta-oxidation GO0140493'
#  'actin filament GO0005884' 'regulation of gene expression GO0010468'
#  'mitochondrial proton-transporting ATP synthase complex GO0005753'
#  'proton motive force-driven ATP synthesis GO0015986'
#  'synaptic vesicle membrane GO0030672' 'excitatory synapse GO0060076'
#  'extrinsic apoptotic signaling pathway via death domain receptors GO0008625'
#  'fructose binding GO0070061'
#  'growth hormone receptor signaling pathway via JAK-STAT GO0060397'
#  'negative regulation of vascular endothelial growth factor receptor signaling pathway GO0030948'
#  'plasma membrane signaling receptor complex GO0098802'
#  'positive regulation of endopeptidase activity GO0010950'
#  'positive regulation of nitric-oxide synthase activity GO0051000'
#  'receptor signaling pathway via JAK-STAT GO0007259'
#  'trans-Golgi network transport vesicle GO0030140' 'chemotaxis GO0006935'
#  'mitotic sister chromatid segregation GO0000070'
#  'negative regulation of phosphoprotein phosphatase activity GO0032515'
#  'vasculogenesis GO0001570'
#  'A-type transient outward potassium channel activity GO0005250'
#  'BRE binding GO0042835' 'CRD-mediated mRNA stability complex GO0070937'
#  'CRD-mediated mRNA stabilization GO0070934'
#  'GTP metabolic process GO0046039' 'Golgi disassembly GO0090166'
#  'L-methionine salvage GO0071267' 'PAR polarity complex GO0120157'
#  'S-adenosylmethionine metabolic process GO0046500'
#  'S-methylmethionine-homocysteine S-methyltransferase activity GO0061627'
#  'S-methylmethionine metabolic process GO0033477'
#  'activation of cysteine-type endopeptidase activity GO0097202'
#  'activation of cysteine-type endopeptidase activity involved in apoptotic process by cytochrome c GO0008635'
#  'activation of phospholipase D activity GO0031584'
#  'amino-acid betaine metabolic process GO0006577' 'apoptosome GO0043293'
#  'arginine binding GO0034618' 'asymmetric cell division GO0008356'
#  'axonemal dynein complex assembly GO0070286' 'basal dendrite GO0097441'
#  'betaine-homocysteine S-methyltransferase activity GO0047150'
#  'bone remodeling GO0046849' 'cell motility GO0048870'
#  'central nervous system myelination GO0022010'
#  'chromatin binding GO0003682' 'dihydropyrimidinase activity GO0004157'
#  'dynein axonemal particle GO0120293'
#  'embryonic brain development GO1990403'
#  'entry of viral genome into host nucleus through nuclear pore complex via importin GO0075506'
#  'fatty acid elongase complex GO0009923' 'forebrain development GO0030900'
#  'gastrulation GO0007369'
#  'hydrolase activity, acting on carbon-nitrogen but not peptide bonds, in cyclic amides GO0016812'
#  'hydrolase activity GO0016787' 'lipid droplet formation GO0140042'
#  'mRNA 3-splice site recognition GO0000389'
#  'meiotic spindle assembly GO0090306' 'molecular function GO0003674'
#  'myelination in peripheral nervous system GO0022011'
#  'negative regulation of JUN kinase activity GO0043508'
#  'negative regulation of nuclear-transcribed mRNA catabolic process, deadenylation-dependent decay GO1900152'
#  'neutrophil migration GO1990266' 'nucleolus GO0005730'
#  'photoreceptor disc membrane GO0097381'
#  'positive regulation of RNA polymerase II regulatory region sequence-specific DNA binding GO1905636'
#  'positive regulation of cytokine production involved in immune response GO0002720'
#  'positive regulation of endothelial cell differentiation GO0045603'
#  'positive regulation of gene expression GO0010628'
#  'positive regulation of immune response GO0050778'
#  'positive regulation of protein glycosylation GO0060050'
#  'positive regulation of superoxide anion generation GO0032930'
#  'positive regulation of type II interferon-mediated signaling pathway GO0060335'
#  'protein localization to site of double-strand break GO1990166'
#  'protein serinethreonine kinase activity GO0004674'
#  'pyrimidine nucleobase catabolic process GO0006208'
#  'regulation of cytokine production involved in inflammatory response GO1900015'
#  'regulation of hippo signaling GO0035330'
#  'regulation of rhodopsin mediated signaling pathway GO0022400'
#  'regulatory T cell differentiation GO0045066'
#  'response to UV-A GO0070141' 'response to UV-C GO0010225'
#  'rhodopsin kinase activity GO0050254' 'sarcomere GO0030017'
#  'stem cell factor receptor binding GO0005173'
#  'tubular endosome GO0097422' 'vesicle cargo loading GO0035459']
# Target genes (miRTarBase)
# ['B2M' 'CCDC71L' 'WDR13' 'YIPF4' 'EIF4H' 'LRRC58' 'DCAF7' 'ATP5A1' 'CHSY1'
#  'COL5A1' 'EIF3H' 'KCNH2' 'KCNK5' 'NR3C1' 'PGM2L1' 'SLC4A2' 'TNFAIP1'
#  'AHCY' 'BTG2' 'CCL16' 'CCND1' 'CFAP73' 'DNAJC28' 'DNTTIP2' 'EPS15L1'
#  'GMDS' 'PTPN4' 'SRRD' 'ZCCHC2' 'RUFY2' 'CCDC80' 'PVR' 'ACOX1' 'TAOK1'
#  'BHMT2' 'CCND2' 'DAZAP2' 'FAM241A' 'GOLGA2' 'GPR155' 'KPNA6' 'PER1'
#  'PNRC1' 'SLC35F5' 'SLC35F6' 'ZNF12' 'ZNF317']
# Diseases (MNDR)
# ['Embryonal cancer' 'Glioma' 'Arthritis' 'Urinary bladder cancer'
#  'Stroke lacunar' 'Cholangiocarcinoma' 'Neurodegenerative diseases'
#  'Vascular diseases' 'Bladder urothelial carcinoma' 'Breast carcinoma'
#  'Head and neck cancer' 'Pancreatic ductal adenocarcinoma']
# Published Diseases
# ['pancreatic cancer ducatal deregulated'
#  'pancreatic cancer ducatal upregulated' 'pancreatitis deregulated'
#  'peridontitis downregulated' 'pancreatitis downregulated']
# Pathways (KEGG)
# ['Non-small cell lung cancer' 'Pancreatic cancer'
#  'Amino sugar and nucleotide sugar metabolism' 'Cushing syndrome'
#  'Starch and sucrose metabolism' 'Fructose and mannose metabolism'
#  'Longevity regulating pathway - multiple species' 'Breast cancer'
#  'Gastric cancer' 'Fatty acid degradation'
#  'Carbohydrate digestion and absorption']
# KEGG (miRPathDB)
# ['Epstein-Barr virus infection']
# Tissue specific (isomiRdb)
# ['saliva specific']
# Expressed in tissue (Tissue Atlas)
# ['adipocyte' 'artery' 'colon' 'dura mater' 'epididymis' 'kidney' 'liver'
#  'lung' 'lymph node' 'nerve' 'pancreas' 'small intestine' 'spleen'
#  'stomach' 'tunica albuginea']

# %%
gc['SuperPath Name'].unique()
# Out:
# array(['Signal Transduction', 'Infectious Disease',
#        'Gene Expression (Transcription)',
#        'Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation',
#        'Cellular Responses to Stimuli',
#        'RNA Polymerase I Promoter Opening', 'Pleural Mesothelioma',
#        'Metabolism of Proteins', 'Cellular Senescence',
#        'Signaling By Receptor Tyrosine Kinases', 'Prolactin Signaling',
#        'Apoptotic Pathways in Synovial Fibroblasts', 'ERK Signaling',
#        'Signaling By Rho GTPases', 'Cell Cycle, Mitotic',
#        'MAPK Family Signaling Cascades', 'Innate Immune System',
#        'GPCR Pathway', 'Toll-like Receptor Signaling Pathway',
#        'Sertoli-Sertoli Cell Junction Dynamics',
#        'Regulation of TP53 Activity',
#        'Chromatin Regulation / Acetylation', 'Cytoskeletal Signaling',
#        'Integrin-mediated Cell Adhesion', 'ESR-mediated Signaling',
#        'SARS-CoV-2 Infection',
#        'Validated Targets of C-MYC Transcriptional Activation',
#        'Chromatin Organization', 'Endometrial Cancer',
#        'NFAT and Cardiac Hypertrophy', 'P70S6K Signaling',
#        'TGF-Beta Pathway', 'VEGF Pathway (Qiagen)', 'MAPK-Erk Pathway',
#        'Homology Directed Repair', 'MAP Kinase Signaling',
#        'Focal Adhesion',
#        'Class I MHC Mediated Antigen Processing and Presentation',
#        'Akt Signaling', 'Nervous System Development',
#        'Assembly of The Pre-replicative Complex',
#        'Retinoblastoma Gene in Cancer', 'CKAP4 Signaling Pathway Map',
#        'Breast Cancer Pathway', 'Regulation of Telomerase',
#        'Vesicle-mediated Transport', 'MAPK Signaling Pathway',
#        'Cytokine Signaling in Immune System',
#        'PIP3 Activates AKT Signaling',
#        'Response to Elevated Platelet Cytosolic Ca2+',
#        'Cell Cycle Regulation of G1/S Transition (part 1)',
#        'Development VEGF Signaling Via VEGFR2 - Generic Cascades',
#        'TP53 Regulates Metabolic Genes', 'NGF Pathway',
#        'PI3K-Akt Signaling Pathway',
#        'MiRNA Regulation of DNA Damage Response',
#        'Angiopoietin-like Protein 8 Regulatory Pathway', 'DNA Damage',
#        'Wnt / Hedgehog / Notch',
#        'Cell Cycle Role of 14-3-3 Proteins in Cell Cycle Regulation',
#        'Signaling By VEGF', 'Cell Cycle Checkpoints',
#        'Development EGFR Signaling Pathway', 'CNTF Signaling',
#        'MTOR Signaling Pathway', 'Senescence and Autophagy in Cancer',
#        'Development Dopamine D2 Receptor Transactivation of EGFR',
#        'HIF1Alpha Pathway', 'Integrin Pathway',
#        'Nanog in Mammalian ESC Pluripotency',
#        'Processing of Capped Intron-Containing Pre-mRNA',
#        'Translation Insulin Regulation of Translation',
#        'Development Ligand-independent Activation of ESR1 and ESR2',
#        'Colorectal Cancer Metastasis', 'Autophagy Pathway',
#        'Pre-NOTCH Expression and Processing', 'Cell Cycle',
#        'Serotonin HTR1 Group and FOS Pathway', 'GDNF Signaling',
#        'Integrated Breast Cancer Pathway', 'Deubiquitination',
#        'Development IGF-1 Receptor Signaling',
#        'DYRK1A Involvement Regarding Cell Proliferation in Brain Development',
#        'Semaphorin Interactions', 'Head and Neck Squamous Cell Carcinoma',
#        'Translational Control', 'MAPK Signaling: Oxidative Stress',
#        'CCR3 Pathway in Eosinophils',
#        'DREAM Repression and Dynorphin Expression',
#        'Small Cell Lung Cancer', 'TGF-beta Signaling Pathways',
#        'Signaling By WNT', 'Chks in Checkpoint Regulation',
#        'MAPK Signaling: Mitogens',
#        'Transport of The SLBP Independent Mature MRNA',
#        'NcRNAs Involved in Wnt Signaling in Hepatocellular Carcinoma',
#        'ADORA2B Mediated Anti-inflammatory Cytokines Production',
#        'Microtubule Cytoskeleton Regulation', 'VEGF Signaling Pathway',
#        'Nuclear Events (kinase and Transcription Factor Activation)',
#        'PDGFR-beta Signaling Pathway', 'Signaling By NTRKs',
#        'Development FGFR Signaling Pathway', 'Gene Silencing By RNA',
#        'Sudden Infant Death Syndrome (SIDS) Susceptibility Pathways',
#        'MAP Kinase Activation', 'AMP-activated Protein Kinase Signaling',
#        'HCMV Infection', 'Gastrin Signaling Pathway',
#        'TCR Signaling (Qiagen)', 'P53 Transcriptional Gene Network',
#        'Epithelial to Mesenchymal Transition in Colorectal Cancer',
#        'Signaling Events Mediated By VEGFR1 and VEGFR2',
#        'Glucose / Energy Metabolism', 'Adipogenesis',
#        'CCR5 Pathway in Macrophages',
#        'MyD88 Dependent Cascade Initiated on Endosome',
#        'Nuclear Receptors Meta-pathway',
#        'Interleukin-4 and Interleukin-13 Signaling',
#        'IL-9 Signaling Pathways',
#        'Corticotropin-releasing Hormone Signaling Pathway',
#        'Circadian Clock', 'Hepatocyte Growth Factor Receptor Signaling',
#        'Smith-Magenis and Potocki-Lupski Syndrome Copy Number Variation',
#        'TNFR1 Pathway',
#        'Transcription Androgen Receptor Nuclear Signaling',
#        'HIF-1-alpha Transcription Factor Network',
#        'Intrinsic Pathway For Apoptosis', 'VEGFA-VEGFR2 Signaling',
#        'MNAR-PELP1 and Estrogen Receptor Interaction',
#        'Cyclins and Cell Cycle Regulation',
#        'Mammary Gland Development Pathway - Pregnancy and Lactation (Stage 3 of 4)',
#        'Activation of CAMP-Dependent PKA',
#        'Death Receptor Signaling Pathway', 'Packaging Of Telomere Ends',
#        'Beta-Adrenergic Signaling', 'Metabolism',
#        'Inhibition of Signaling By Overexpressed EGFR',
#        'Clear Cell Renal Cell Carcinoma Pathways',
#        'Oncogene Induced Senescence', 'Signaling By ALK in Cancer',
#        'DNA Double Strand Break Response',
#        'Thyroid Stimulating Hormone (TSH) Signaling Pathway',
#        'Development Endothelin-1/EDNRA Transactivation of EGFR',
#        'RUNX1 Interacts With Co-factors Whose Precise Effect on RUNX1 Targets Is Not Known',
#        'Constitutive Signaling By AKT1 E17K in Cancer',
#        'AP-1 Transcription Factor Network', 'Apoptosis and Autophagy',
#        'IGF1 Pathway', 'PAK Pathway',
#        'Regulation of RUNX1 Expression and Activity',
#        'Non-integrin Membrane-ECM Interactions',
#        'Mitotic G1 Phase and G1/S Transition',
#        'Signaling By TGFB Family Members',
#        'Signaling Events Mediated By HDAC Class I',
#        'Activation of The Pre-replicative Complex',
#        'Apoptosis and Survival BAD Phosphorylation', 'Bladder Cancer',
#        'Development_TGF-beta Receptor Signaling',
#        'Unfolded Protein Response',
#        'Respiratory Syncytial Virus Infection Pathway', 'FMLP Pathway',
#        'NF-kappaB Pathway', 'FOXM1 Transcription Factor Network',
#        'Programmed Cell Death', 'IL2 Signaling Events Mediated By STAT5',
#        'Apoptosis-related Network Due to Altered Notch3 in Ovarian Cancer',
#        'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling',
#        'Role of Hypoxia, Angiogenesis, and FGF Pathway in OA Chondrocyte Hypertrophy',
#        'B Cell Receptor Signaling Pathway',
#        'Photodynamic Therapy-induced HIF-1 Survival Signaling',
#        'G12-G13 in Cellular Signaling',
#        'Immune Response IL-2 Activation and Signaling Pathway',
#        'G-AlphaQ Signaling',
#        'NRP1-triggered Signaling Pathways in Pancreatic Cancer',
#        'Angiotensin II Receptor Type 1 Pathway',
#        'Lissencephaly Gene (LIS1) in Neuronal Migration and Development',
#        'Exercise-induced Circadian Regulation',
#        'Immune Response_IL-6 Signaling Pathway',
#        'Notch Signaling Pathways', 'Jak-Stat Signaling Pathway',
#        'Plasma Membrane Estrogen Receptor Signaling',
#        'VEGFR3 Signaling in Lymphatic Endothelium',
#        'Physico-chemical Features and Toxicity-associated Pathways',
#        'Regulation of Actin Cytoskeleton', 'Signaling By PTK6',
#        'IL-1 Family Signaling Pathways',
#        'PPARA Activates Gene Expression',
#        'EML4 and NUDC in Mitotic Spindle Formation',
#        'DNA Damage Response (only ATM Dependent)',
#        'Metabolic States and Circadian Oscillators',
#        'Genotoxicity Pathway',
#        'Disorders of Folate Metabolism and Transport',
#        'P38 MAPK Signaling Pathway (WikiPathways)',
#        'Type 2 Papillary Renal Cell Carcinoma',
#        'E2F Transcription Factor Network', '4-1BB Pathway',
#        'Fc-GammaR Pathway', 'P53 Pathway', 'P75(NTR)-mediated Signaling',
#        'Modulators of TCR Signaling and T Cell Activation',
#        'Transcriptional Regulation By E2F6', 'RHOBTB GTPase Cycle',
#        'PDGFR-alpha Signaling Pathway', 'SARS-CoV-1-host Interactions',
#        'Overlap Between Signal Transduction Pathways Contributing to LMNA Laminopathies',
#        'ATM Pathway', 'Adhesion',
#        'G-protein Signaling G-Protein Alpha-i Signaling Cascades',
#        'P53 Signaling', 'Guidance Cues and Growth Cone Motility',
#        'Regulation of Actin Dynamics For Phagocytic Cup Formation',
#        'C-MYB Transcription Factor Network', 'Integrins in Angiogenesis',
#        'Ubiquitination Cascade'], dtype=object)

# %%
overlap = miEAA.merge(gc, left_on='Subcategory', right_on='SuperPath Name')
overlap.head()
# Out:
# Empty DataFrame
# Columns: [Category, Subcategory, Enrichment, P-value, P-adjusted, Q-value, Observed, miRNAs/precursors, Score, SuperPath Name, # SuperPath Total Genes, # SuperPath Matched Genes, Matched Genes (Symbols), Evidence URL]
# Index: []
