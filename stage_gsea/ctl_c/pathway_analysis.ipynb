# %%
import pandas as pd

# %%
miEAA = pd.read_csv('./miEAA Analysis Results.csv')
print(miEAA.columns)

# %%
# Print unique categories
print(miEAA['Category'].unique())

# %%
gc = pd.read_csv('./genecards_pathways.csv')
gc.columns

# %%
miEAA.head()
# Out:
#                                             Category  \
# 0  Annotations derived over miRTarBase (Gene Onto...
# 1  Annotations derived over miRTarBase (Gene Onto...
# 2  Annotations derived over miRTarBase (Gene Onto...
# 3  Annotations derived over miRTarBase (Gene Onto...
# 4  Annotations derived over miRTarBase (Gene Onto...
#
#                                          Subcategory Enrichment   P-value  \
# 0  enzyme-linked receptor protein signaling pathw...   depleted  0.000810
# 1  interleukin-15-mediated signaling pathway GO00...   depleted  0.000810
# 2      regulation of calcium ion transport GO0051924   depleted  0.000810
# 3                    gamma-catenin binding GO0045295   enriched  0.001107
# 4  mannosyl-oligosaccharide 1,2-alpha-mannosidase...   depleted  0.001107
#
#    P-adjusted   Q-value  Observed  \
# 0    0.000810  0.504321         3
# 1    0.000810  0.504321         3
# 2    0.000810  0.504321         3
# 3    0.001107  0.504321         2
# 4    0.001107  0.504321         2
#
#                                    miRNAs/precursors
# 0  hsa-miR-6784-5p; hsa-miR-6861-5p; hsa-miR-4732-5p
# 1  hsa-miR-6784-5p; hsa-miR-6861-5p; hsa-miR-4732-5p
# 2  hsa-miR-6784-5p; hsa-miR-6861-5p; hsa-miR-4732-5p
# 3                         hsa-miR-663a; hsa-miR-8073
# 4                  hsa-miR-6769a-5p; hsa-miR-4732-5p

# %%
gc.head()
# Out:
#    Score                                     SuperPath Name  \
# 0  166.1                                Signal Transduction
# 1  166.1                             Metabolism of Proteins
# 2  166.1                                 Infectious Disease
# 3  166.1                    Gene Expression (Transcription)
# 4  166.1  Regulation of Activated PAK-2p34 By Proteasome...
#
#    # SuperPath Total Genes  # SuperPath Matched Genes  \
# 0                     2597                        558
# 1                     2077                        507
# 2                     1818                        458
# 3                     1543                        424
# 4                      943                        258
#
#                              Matched Genes (Symbols)  \
# 0  MUC20, ARL2, MAP2K2, DGKH, ARL4C, PTK6, NHS, S...
# 1  CANX, EIF2B5, MUC17, MUC20, RPS19, ARL2, GAN, ...
# 2  CANX, MUC17, MUC20, RPS19, MAP2K2, MAP2K3, CAP...
# 3  NPM1, NUDT21, THRA, ZNF154, ZNF155, AXIN1, POL...
# 4  CANX, EIF2S3, PTK6, SYVN1, ABCA12, POLE3, ABCA...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/signal_tr...
# 1  https://pathcards.genecards.org/card/metabolis...
# 2  https://pathcards.genecards.org/card/infectiou...
# 3  https://pathcards.genecards.org/card/gene_expr...
# 4  https://pathcards.genecards.org/card/regulatio...

# %%
# print the categories from Reactome
print(miEAA['Category'].unique())
print(miEAA['Category'].value_counts())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)' 'KEGG (miRPathDB)'
#  'Reactome (miRPathDB)' 'WikiPathways (miRPathDB)' 'Pathways (KEGG)'
#  'Target genes (miRTarBase)' 'GO Molecular function (miRPathDB)'
#  'Diseases (MNDR)' 'Chromosomal location (miRBase)'
#  'Tissue specific (isomiRdb)' 'GO Cellular component (miRPathDB)'
#  'Published Diseases' 'GO Biological process (miRPathDB)'
#  'Interactions (NPInter)' 'Expressed in tissue (Tissue Atlas)']
# Category
# Annotations derived over miRTarBase (Gene Ontology)    340
# Target genes (miRTarBase)                               46
# Pathways (KEGG)                                         21
# KEGG (miRPathDB)                                         7
# Diseases (MNDR)                                          6
# WikiPathways (miRPathDB)                                 4
# Published Diseases                                       4
# Interactions (NPInter)                                   3
# GO Molecular function (miRPathDB)                        2
# Chromosomal location (miRBase)                           2
# GO Biological process (miRPathDB)                        2
# Expressed in tissue (Tissue Atlas)                       2
# Reactome (miRPathDB)                                     1
# Tissue specific (isomiRdb)                               1
# GO Cellular component (miRPathDB)                        1
# Name: count, dtype: int64

# %%
# find the overlap of the overlap of supepath name and subcategory
miEAA['Subcategory'].unique()
# Out:
# array(['enzyme-linked receptor protein signaling pathway GO0007167',
#        'interleukin-15-mediated signaling pathway GO0035723',
#        'regulation of calcium ion transport GO0051924',
#        'gamma-catenin binding GO0045295',
#        'mannosyl-oligosaccharide 1,2-alpha-mannosidase activity GO0004571',
#        'negative regulation of T cell proliferation GO0042130',
#        'protein hexamerization GO0034214',
#        'protein localization to kinetochore GO0034501',
#        'interleukin-1-mediated signaling pathway GO0070498',
#        'positive regulation of T cell proliferation GO0042102',
#        'SNARE complex assembly GO0035493',
#        'cyclin-dependent protein kinase activity GO0097472',
#        'histone kinase activity GO0035173', 'mucus secretion GO0070254',
#        'negative regulation of secretion by cell GO1903531',
#        'FoxO signaling pathway', 'Melanoma', 'Pathways in cancer',
#        'Proteoglycans in cancer', 'p53 signaling pathway',
#        'Signal Transduction',
#        'Chromosomal and microsatellite instability in colorectal cancer',
#        'DNA Damage Response only ATM dependent',
#        'Integrin-mediated Cell Adhesion',
#        'cholesterol homeostasis GO0042632',
#        'interleukin-17A-mediated signaling pathway GO0038173',
#        'positive regulation of T cell cytokine production GO0002726',
#        'positive regulation of establishment of T cell polarity GO1903905',
#        'positive regulation of oxidoreductase activity GO0051353',
#        'regulation of cell motility GO2000145', 'AMPK signaling pathway',
#        'heterochromatin GO0000792', 'RNA metabolic process GO0016070',
#        'positive regulation of cell migration involved in sprouting angiogenesis GO0090050',
#        'P-body GO0000932', 'Insulin resistance',
#        '3-5-RNA exonuclease activity GO0000175',
#        'ankyrin binding GO0030506',
#        'cell projection organization GO0030030',
#        'convergent extension GO0060026',
#        'convergent extension involved in gastrulation GO0060027',
#        'determination of intestine leftright asymmetry GO0071908',
#        'determination of liver leftright asymmetry GO0071910',
#        'determination of pancreatic leftright asymmetry GO0035469',
#        'determination of stomach leftright asymmetry GO0071909',
#        'female pregnancy GO0007565', 'insulin secretion GO0030073',
#        'maintenance of animal organ identity GO0048496',
#        'negative regulation of secretion GO0051048',
#        'nuclear protein quality control by the ubiquitin-proteasome system GO0071630',
#        'positive regulation of peptide hormone secretion GO0090277',
#        'regulation of Wnt signaling pathway, planar cell polarity pathway GO2000095',
#        'regulation of planar cell polarity pathway involved in neural tube closure GO2000167',
#        'regulation of vasoconstriction GO0019229',
#        'Riboflavin metabolism', 'KLHL15', 'NPHP3', 'PRR13', 'SBNO1',
#        'RNA polymerase binding', 'ubiquitin conjugating enzyme binding',
#        'neuropilin binding GO0038191', 'Cell adhesion molecules',
#        'exonucleolytic trimming to generate mature 3-end of 5.8S rRNA from tricistronic rRNA transcript SSU-rRNA, 5.8S rRNA, LSU-rRNA GO0000467',
#        'single-stranded DNA binding GO0003697',
#        'post-transcriptional regulation of gene expression GO0010608',
#        'determination of leftright symmetry GO0007368', 'TOMM40',
#        'P-body assembly GO0033962', 'Stroke lacunar',
#        'calcium ion homeostasis GO0055074',
#        'negative regulation of extrinsic apoptotic signaling pathway via death domain receptors GO1902042',
#        'NAD biosynthesis via nicotinamide riboside salvage pathway GO0034356',
#        'T cell selection GO0045058', 'interleukin-16 binding GO0042011',
#        'interleukin-16 receptor activity GO0042012',
#        'maintenance of protein location in cell GO0032507',
#        'positive regulation of monocyte differentiation GO0045657',
#        '2022-09-14 000000', 'CD4', 'PNMA8B', 'Non-small cell lung cancer',
#        'gap junction assembly GO0016264', 'ERAD pathway GO0036503',
#        'HULC complex GO0033503',
#        'bHLH transcription factor binding GO0043425',
#        'exosome RNase complex GO0000178',
#        'histone H2B conserved C-terminal lysine ubiquitination GO0071894',
#        'kinase inhibitor activity GO0019210',
#        'nuclear exosome RNase complex GO0000176',
#        'positive regulation of osteoclast differentiation GO0045672',
#        'protein K11-linked ubiquitination GO0070979',
#        'regulation of receptor signaling pathway via JAK-STAT GO0046425',
#        'tumor necrosis factor receptor superfamily binding GO0032813',
#        'TRAF6', 'damaged DNA binding GO0003684',
#        'actin monomer binding GO0003785',
#        'cellular homeostasis GO0019725',
#        'cellular response to sterol GO0036315',
#        'endoplasmic reticulum quality control compartment GO0044322',
#        'epithelial cilium movement involved in determination of leftright asymmetry GO0060287',
#        'microtubule-based process GO0007017',
#        'negative regulation of cargo loading into COPII-coated vesicle GO1901303',
#        'negative regulation of protein exit from endoplasmic reticulum GO0070862',
#        'INSIG1', 'cellular response to chemokine GO1990869',
#        'cellular response to nutrient levels GO0031669',
#        'early endosome to Golgi transport GO0034498',
#        'ephrin receptor signaling pathway GO0048013',
#        'lens fiber cell morphogenesis GO0070309',
#        'magnesium ion homeostasis GO0010960',
#        'magnesium ion transport GO0015693', 'ABI2',
#        'positive regulation of interleukin-2 production GO0032743',
#        'phospholipase C-activating G protein-coupled receptor signaling pathway GO0007200',
#        'positive regulation of collagen biosynthetic process GO0032967',
#        '1-phosphatidylinositol-3-kinase activity GO0016303',
#        'DNA repair complex GO1990391',
#        'T cell mediated cytotoxicity GO0001913',
#        'activation of cysteine-type endopeptidase activity involved in apoptotic process by cytochrome c GO0008635',
#        'apoptosome GO0043293',
#        'branched-chain amino acid catabolic process GO0009083',
#        'cellular response to mercury ion GO0071288',
#        'glycerol transmembrane transport GO0015793',
#        'glycerol transmembrane transporter activity GO0015168',
#        'proteasome regulatory particle, base subcomplex GO0008540',
#        'tRNA splicing, via endonucleolytic cleavage and ligation GO0006388',
#        'transport vesicle membrane GO0030658',
#        'water transmembrane transporter activity GO0005372', 'AQP2',
#        'LPP', 'TRAF1', 'TVP23C',
#        'DNA-binding transcription activator activity GO0001216',
#        'cytoskeletal anchor activity GO0008093',
#        'positive regulation of B cell proliferation GO0030890',
#        'positive regulation of T cell differentiation GO0045582',
#        'positive regulation of synapse maturation GO0090129',
#        'branching involved in blood vessel morphogenesis GO0001569',
#        'nuclear estrogen receptor binding GO0030331',
#        'positive regulation of inflammatory response GO0050729',
#        'histone H4K12 acetyltransferase activity GO0043997',
#        'histone H4K5 acetyltransferase activity GO0043995',
#        'histone H4K8 acetyltransferase activity GO0043996',
#        'structural constituent of ribosome GO0003735',
#        'insulin metabolic process GO1901142',
#        'neuropeptide signaling pathway GO0007218',
#        'Fc-epsilon receptor signaling pathway GO0038095', 'Chromosome 17',
#        'collagen binding GO0005518', 'protein kinase B binding GO0043422',
#        'response to interleukin-1 GO0070555',
#        'activation of protein kinase activity GO0032147',
#        'cellular response to insulin stimulus GO0032869',
#        'protein transport GO0015031', 'Basal cell carcinoma',
#        'mismatch repair GO0006298', 'regulation of cell growth GO0001558',
#        'Primary immunodeficiency', 'nucleosome binding GO0031491',
#        'NLRP6 inflammasome complex GO0140738',
#        'chromosome condensation GO0030261',
#        'ribosomal large subunit binding GO0043023',
#        'vascular endothelial growth factor signaling pathway GO0038084',
#        'ATXN2', 'HIST1H1E', 'DNA biosynthetic process GO0071897',
#        'DNA synthesis involved in DNA repair GO0000731',
#        'DNA synthesis involved in UV-damage excision repair GO1904161',
#        'artery development GO0060840',
#        'delta DNA polymerase complex GO0043625',
#        'error-prone translesion synthesis GO0042276',
#        'lithium ion binding GO0031403',
#        'lymphatic endothelial cell differentiation GO0060836',
#        'mitochondrial respiratory chain complex assembly GO0033108',
#        'nucleotide-excision repair, DNA gap filling GO0006297',
#        'peptidyl-cysteine oxidation GO0018171',
#        'positive regulation of dendritic spine development GO0060999',
#        'positive regulation of oxidative stress-induced neuron death GO1903223',
#        'positive regulation of triglyceride catabolic process GO0010898',
#        'protein import into mitochondrial intermembrane space GO0045041',
#        'protein serinethreonine kinase binding GO0120283',
#        'protein tyrosine kinase inhibitor activity GO0030292',
#        'pyridoxal 5-phosphate salvage GO0009443',
#        'pyridoxal kinase activity GO0008478', 'rDNA binding GO0000182',
#        'sodium ion binding GO0031402',
#        'venous blood vessel development GO0060841',
#        'zeta DNA polymerase complex GO0016035', 'ABHD5', 'CHCHD4',
#        'DHX33', 'PDXK', 'POLD3', 'VPS37B', '7S RNA binding GO0008312',
#        'CUT catabolic process GO0071034', 'cilium movement GO0003341',
#        'cyclooxygenase pathway GO0019371',
#        'nuclear polyadenylation-dependent rRNA catabolic process GO0071035',
#        'nuclear polyadenylation-dependent tRNA catabolic process GO0071038',
#        'nucleolar exosome RNase complex GO0101019',
#        'polyadenylation-dependent snoRNA 3-end processing GO0071051',
#        'proteoglycan biosynthetic process GO0030166',
#        'regulation of neuron projection development GO0010975', 'TSPAN14',
#        'Skin cutaneous melanoma', 'Skin melanoma',
#        'apical part of cell GO0045177',
#        'commissural neuron axon guidance GO0071679',
#        'protein K27-linked ubiquitination GO0044314',
#        'ubiquitin-specific protease binding GO1990381', 'HDGF',
#        'mRNA stabilization GO0048255',
#        'DNA conformation change GO0071103',
#        'activation of protein kinase C activity GO1990051',
#        'mitochondrial depolarization GO0051882',
#        'negative regulation of phospholipase C activity GO1900275',
#        'neuropilin signaling pathway GO0038189',
#        'peptidyl-tyrosine autophosphorylation GO0038083',
#        'positive regulation of actin filament binding GO1904531',
#        'positive regulation of microtubule binding GO1904528',
#        'protein localization to cytoplasmic microtubule plus-end GO1904518',
#        'regulation of T cell differentiation GO0045580',
#        'regulation of hematopoietic stem cell differentiation GO1902036',
#        'regulation of modification of synaptic structure GO1905244',
#        'ABL1',
#        'positive regulation of execution phase of apoptosis GO1900119',
#        'E-box binding GO0070888', 'IL-17 signaling pathway',
#        'Inositol phosphate metabolism', 'CD40 receptor complex GO0035631',
#        'cytosolic pattern recognition receptor signaling pathway GO0002753',
#        'histone modification GO0016570',
#        'histone monoubiquitination GO0010390', 'perikaryon GO0043204',
#        'positive regulation of neuron migration GO2001224',
#        'NLRP3 inflammasome complex GO0072559',
#        'detection of calcium ion GO0005513',
#        'histone H3K14 acetyltransferase activity GO0036408',
#        'histone H4-K12 acetylation GO0043983',
#        'histone H4K16 acetyltransferase activity GO0046972',
#        'negative regulation of interleukin-1 beta production GO0032691',
#        'regulation of DNA biosynthetic process GO2000278',
#        'retina vasculature development in camera-type eye GO0061298',
#        'MED28', 'positive regulation of phosphorylation GO0042327',
#        'regulation of DNA-binding transcription factor activity GO0051090',
#        'saliva specific',
#        'inward rectifier potassium channel activity GO0005242',
#        'positive regulation of innate immune response GO0045089',
#        'antigen binding GO0003823',
#        'cellular response to molecule of fungal origin GO0071226',
#        'endoplasmic reticulum chaperone complex GO0034663',
#        'extracellular matrix assembly GO0085029',
#        'growth hormone receptor signaling pathway via JAK-STAT GO0060397',
#        'mitochondrial respiratory chain complex IV GO0005751',
#        'mitotic spindle pole GO0097431',
#        'phospholipid biosynthetic process GO0008654',
#        'positive regulation of cholesterol efflux GO0010875',
#        'positive regulation of dendrite morphogenesis GO0050775',
#        'positive regulation of superoxide anion generation GO0032930',
#        'regulation of cardiac muscle cell membrane potential GO0086036',
#        'respiratory chain complex IV GO0045277',
#        'Alanine, aspartate and glutamate metabolism',
#        'Histidine metabolism', 'COX6B1', 'DNAJC10', 'DNLZ', 'RABGAP1L',
#        'GDP-dissociation inhibitor activity GO0005092',
#        'acyltransferase activity GO0016746', 'sperm flagellum GO0036126',
#        'acrosomal vesicle GO0001669',
#        'signal transduction in response to DNA damage GO0042770',
#        'phosphotyrosine residue binding GO0001784',
#        'extrinsic apoptotic signaling pathway GO0097191',
#        'modulation of chemical synaptic transmission GO0050804',
#        'response to lipopolysaccharide GO0032496',
#        'cargo receptor activity GO0038024',
#        'morphogenesis of an epithelium GO0002009',
#        'regulation of lipid transport GO0032368', 'PITPNM3', 'RDH10',
#        'RPTN', 'SURF4', 'ubiquitin conjugating enzyme binding GO0031624',
#        'anaphase-promoting complex GO0005680',
#        'embryonic hemopoiesis GO0035162',
#        'establishment of spindle orientation GO0051294',
#        'female gamete generation GO0007292',
#        'histone H3-K4 trimethylation GO0080182',
#        'kinetochore microtubule GO0005828',
#        'leukocyte chemotaxis involved in inflammatory response GO0002232',
#        'minor groove of adenine-thymine-rich DNA binding GO0003680',
#        'negative regulation of smoothened signaling pathway GO0045879',
#        'odontogenesis of dentin-containing tooth GO0042475',
#        'positive regulation by host of viral process GO0044794',
#        'positive regulation of neural precursor cell proliferation GO2000179',
#        'regulation of meiotic cell cycle GO0051445',
#        'regulation of vesicle size GO0097494', 'DDA1', 'RNF40',
#        '3-UTR-mediated mRNA stabilization GO0070935',
#        'NADP binding GO0050661', 'dynein complex GO0030286',
#        'frizzled binding GO0005109',
#        'inositol-1,3,4,5,6-pentakisphosphate kinase activity GO0000827',
#        'inositol heptakisphosphate kinase activity GO0000829',
#        'inositol hexakisphosphate kinase activity GO0000828',
#        'inositol phosphate metabolic process GO0043647',
#        'phosphatidylethanolamine biosynthetic process GO0006646',
#        'positive regulation of receptor internalization GO0002092',
#        'regulation of protein binding GO0043393',
#        'ribosomal subunit export from nucleus GO0000054',
#        'sodium ion transmembrane transporter activity GO0015081',
#        'tissue regeneration GO0042246', 'CNNM4', 'nucleus',
#        'negative regulation of telomere maintenance via telomerase GO0032211',
#        'kinase binding GO0019900',
#        'mRNA 3-UTR AU-rich region binding GO0035925',
#        'regulation of microtubule polymerization GO0031113',
#        'positive regulation of cytosolic calcium ion concentration GO0007204',
#        'regulation of cell adhesion GO0030155',
#        'response to oxidative stress GO0006979',
#        'syntaxin binding GO0019905',
#        'cellular response to epidermal growth factor stimulus GO0071364',
#        'Cysteine and methionine metabolism',
#        'negative regulation of fat cell differentiation GO0045599',
#        'lipid homeostasis GO0055088', 'Pentose phosphate pathway',
#        'Human T-cell leukemia virus 1 infection',
#        'AV node cell to bundle of His cell communication by electrical coupling GO0086053',
#        'CENP-A containing nucleosome GO0043505',
#        'cell communication involved in cardiac conduction GO0086065',
#        'cyclin-dependent protein serinethreonine kinase activity GO0004693',
#        'gap junction channel activity involved in AV node cell-bundle of His cell electrical coupling GO0086077',
#        'gap junction channel activity involved in cardiac conduction electrical coupling GO0086075',
#        'histone mRNA catabolic process GO0071044',
#        'mRNA splice site selection GO0006376',
#        'melanocyte differentiation GO0030318',
#        'mitochondrial proton-transporting ATP synthase complex assembly GO0033615',
#        'negative regulation of cell communication by electrical coupling involved in cardiac conduction GO1901845',
#        'phosphatidylinositol-3-phosphate biosynthetic process GO0036092',
#        'protein localization to CENP-A containing chromatin GO0061644',
#        'GJD3', 'sarcoidosis deregulated', 'neuronal cell body GO0043025',
#        'filopodium tip GO0032433',
#        'negative regulation of tumor necrosis factor production GO0032720',
#        'sprouting angiogenesis GO0002040', 'vasculogenesis GO0001570',
#        'Ubiquitin mediated proteolysis', 'heme binding GO0020037',
#        'negative regulation of DNA recombination GO0045910',
#        'Cul4-RING E3 ubiquitin ligase complex GO0080008',
#        'positive regulation of miRNA transcription GO1902895',
#        'receptor tyrosine kinase binding GO0030971',
#        'channel activity GO0015267',
#        'negative regulation of anoikis GO2000811',
#        'protein lysine deacetylase activity GO0033558',
#        'regulation of transport GO0051049', 'C10orf111', 'HDAC7', 'ICA1L',
#        'NDEL1', 'B-cell lymphoma', 'Pseudorabies',
#        'acute myocardial infarction deregulated',
#        'acute myocardial infarction downregulated',
#        'sarcoidosis downregulated',
#        'negative regulation of apoptotic process',
#        'negative regulation of programmed cell death', 'CANX', 'COL6A3',
#        'heterochromatin formation GO0031507',
#        'positive regulation of cytoplasmic translation GO2000767',
#        'midbody GO0030496', 'Adrenergic signaling in cardiomyocytes',
#        'positive regulation of I-kappaB kinaseNF-kappaB signaling GO0043123',
#        'skeletal muscle fiber development GO0048741',
#        'terminal bouton GO0043195',
#        'mitotic centrosome separation GO0007100',
#        'vitamin D metabolic process GO0042359',
#        'COPII-coated vesicle cargo loading GO0090110',
#        'COPII vesicle coat GO0030127',
#        'cellular response to organic cyclic compound GO0071407',
#        'histone H3K4meH3K4me2H3K4me3 demethylase activity GO0034647',
#        'positive regulation of vascular associated smooth muscle cell migration GO1904754',
#        'RNA catabolic process GO0006401', 'rRNA binding GO0019843',
#        'Valine, leucine and isoleucine degradation',
#        'Hsp70 protein binding GO0030544',
#        'Rab GDP-dissociation inhibitor activity GO0005093',
#        'Rab protein signal transduction GO0032482',
#        'negative regulation of protein targeting to membrane GO0090315',
#        'neurotransmitter transmembrane transporter activity GO0005326',
#        'positive regulation of cell adhesion mediated by integrin GO0033630',
#        'GDI1', 'amyloid-beta binding GO0001540',
#        'early phagosome GO0032009',
#        'positive regulation of blood vessel endothelial cell proliferation involved in sprouting angiogenesis GO1903589',
#        'protein localization to endosome GO0036010',
#        'regulation of phagocytosis GO0050764', 'SF3B3', 'ALKBH5',
#        'Bile secretion', 'acylglycerol catabolic process GO0046464',
#        'attachment of spindle microtubules to kinetochore GO0008608',
#        'cellular response to low-density lipoprotein particle stimulus GO0071404',
#        'dendrite development GO0016358', 'filamentous actin GO0031941',
#        'Cholesterol metabolism', 'muscle', 'skin',
#        'positive regulation of receptor signaling pathway via JAK-STAT GO0046427',
#        'GnRH secretion', 'p53 binding GO0002039',
#        'Antigen processing and presentation',
#        'EP4 subtype prostaglandin E2 receptor binding GO0031867',
#        'cellular response to platelet-derived growth factor stimulus GO0036120',
#        'glutamatesodium symporter activity GO0015501',
#        'high-affinity L-glutamate transmembrane transporter activity GO0005314',
#        'phosphate-containing compound metabolic process GO0006796',
#        'regulation of ATP-dependent activity GO0043462', 'FEM1A',
#        'cytoplasmic exosome RNase complex GO0000177',
#        'outer dynein arm assembly GO0036158',
#        'regulation of phosphoprotein phosphatase activity GO0043666',
#        'Folate biosynthesis', 'Viral carcinogenesis',
#        'Amyotrophic lateral sclerosis', 'MLL1 complex GO0071339',
#        'cellular response to glucocorticoid stimulus GO0071385',
#        'mRNA catabolic process GO0006402',
#        'ubiquitin protein ligase binding GO0031625',
#        'regulation of actin cytoskeleton organization GO0032956',
#        'regulation of small GTPase mediated signal transduction GO0051056',
#        'regulation of dendritic spine morphogenesis GO0061001',
#        'Chromosome 20'], dtype=object)

# %%
gc['SuperPath Name'].unique()
# Out:
# array(['Signal Transduction', 'Metabolism of Proteins',
#        'Infectious Disease', 'Gene Expression (Transcription)',
#        'Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation',
#        'Cellular Responses to Stimuli', 'Cell Cycle, Mitotic',
#        'RNA Polymerase I Promoter Opening', 'Signaling By Rho GTPases',
#        'Cellular Senescence',
#        'Processing of Capped Intron-Containing Pre-mRNA',
#        'Innate Immune System', 'Vesicle-mediated Transport', 'DNA Damage',
#        'Nervous System Development', 'Prolactin Signaling',
#        'Cytoskeletal Signaling', 'Metabolism',
#        'Sertoli-Sertoli Cell Junction Dynamics', 'SARS-CoV-2 Infection',
#        'Gene Silencing By RNA',
#        'Apoptotic Pathways in Synovial Fibroblasts',
#        'Transport of The SLBP Independent Mature MRNA',
#        'Mitotic G1 Phase and G1/S Transition',
#        'Chromatin Regulation / Acetylation', 'Chromatin Organization',
#        'Assembly of The Pre-replicative Complex',
#        'Cell Cycle Checkpoints', 'Deubiquitination', 'ERK Signaling',
#        'ESR-mediated Signaling', 'MAPK Family Signaling Cascades',
#        'Peptide Chain Elongation', 'Cytokine Signaling in Immune System',
#        'Cell Cycle', 'Endometrial Cancer',
#        'Class I MHC Mediated Antigen Processing and Presentation',
#        'Influenza Infection', 'Packaging Of Telomere Ends',
#        'HCMV Infection', 'Pleural Mesothelioma',
#        'Signaling Events Mediated By HDAC Class I',
#        'Signaling By Receptor Tyrosine Kinases', 'MAPK-Erk Pathway',
#        'Homology Directed Repair',
#        'Validated Targets of C-MYC Transcriptional Activation',
#        'CKAP4 Signaling Pathway Map',
#        'Pre-NOTCH Expression and Processing',
#        'Angiopoietin-like Protein 8 Regulatory Pathway',
#        'Signaling By WNT', 'Glucose / Energy Metabolism',
#        'Regulation of TP53 Activity', 'Translational Control',
#        'Toll-like Receptor Signaling Pathway', 'GPCR Pathway',
#        'Activation of The Pre-replicative Complex',
#        'MAPK Signaling: Mitogens', 'Autophagy Pathway',
#        'Apoptosis and Autophagy', 'MAP Kinase Signaling',
#        'TGF-Beta Pathway', 'E2F Transcription Factor Network',
#        'Retinoblastoma Gene in Cancer',
#        'RRNA Processing in The Nucleus and Cytosol',
#        'Activation of AMPK Downstream of NMDARs', 'P70S6K Signaling',
#        'Cell Cycle Regulation of G1/S Transition (part 1)',
#        'PIP3 Activates AKT Signaling', 'VEGFA-VEGFR2 Signaling',
#        'Small Cell Lung Cancer', 'Programmed Cell Death',
#        'Development VEGF Signaling Via VEGFR2 - Generic Cascades',
#        'Regulation of Expression of SLITs and ROBOs',
#        'Integrin-mediated Cell Adhesion', 'NFAT and Cardiac Hypertrophy',
#        'Integrated Breast Cancer Pathway',
#        'Defective Binding of RB1 Mutants to E2F1,(E2F2, E2F3)',
#        'Oncogene Induced Senescence',
#        'DREAM Repression and Dynorphin Expression',
#        'Development IGF-1 Receptor Signaling',
#        'Hepatocyte Growth Factor Receptor Signaling',
#        'Cellular Response to Heat Stress',
#        'Development Ligand-independent Activation of ESR1 and ESR2',
#        'MAPK Signaling Pathway',
#        'Metabolic Reprogramming in Colon Cancer', 'TNFR1 Pathway',
#        'Semaphorin Interactions', 'Senescence and Autophagy in Cancer',
#        'Chks in Checkpoint Regulation', 'EPH-Ephrin Signaling',
#        'P75 NTR Receptor-mediated Signalling',
#        'Beta-Adrenergic Signaling', 'Nanog in Mammalian ESC Pluripotency',
#        'Focal Adhesion', 'Neuroscience', 'Chromosome Maintenance',
#        'Apoptosis and Survival BAD Phosphorylation',
#        'Apoptosis-related Network Due to Altered Notch3 in Ovarian Cancer',
#        'G0 and Early G1', 'Head and Neck Squamous Cell Carcinoma',
#        'Regulation of Actin Dynamics For Phagocytic Cup Formation',
#        'SARS-CoV-1-host Interactions', 'Signaling By ALK in Cancer',
#        'Response to Elevated Platelet Cytosolic Ca2+', 'FMLP Pathway',
#        'NcRNAs Involved in Wnt Signaling in Hepatocellular Carcinoma',
#        'Ovarian Tumor Domain Proteases',
#        'P73 Transcription Factor Network',
#        'Intrinsic Pathway For Apoptosis',
#        'DNA IR-damage and Cellular Response Via ATR',
#        'Regulation of Telomerase', 'Golgi-to-ER Retrograde Transport',
#        'PKMTs Methylate Histone Lysines',
#        'RNA Polymerase III Transcription Initiation',
#        'Transport to The Golgi and Subsequent Modification',
#        'Rab Regulation of Trafficking', 'Ebola Virus Infection in Host',
#        'DNA Damage Response (only ATM Dependent)', 'Meiosis',
#        'MiRNA Regulation of DNA Damage Response',
#        'Sudden Infant Death Syndrome (SIDS) Susceptibility Pathways',
#        'EML4 and NUDC in Mitotic Spindle Formation',
#        'Aryl Hydrocarbon Receptor Pathway',
#        'MAPK Signaling: Oxidative Stress',
#        'Loss of Proteins Required For Interphase Microtubule Organization From The Centrosome',
#        'Development Slit-Robo Signaling',
#        'DYRK1A Involvement Regarding Cell Proliferation in Brain Development',
#        'Akt Signaling', 'Oncogenic MAPK Signaling',
#        'Gastrin Signaling Pathway', 'PDGFR-beta Signaling Pathway',
#        'Clathrin-mediated Endocytosis', 'TNF Signaling',
#        'Interleukin-4 and Interleukin-13 Signaling',
#        'MET Promotes Cell Motility', 'RHOBTB GTPase Cycle',
#        'Hepatitis C and Hepatocellular Carcinoma',
#        'Breast Cancer Pathway', 'IL-1 Family Signaling Pathways',
#        'ADORA2B Mediated Anti-inflammatory Cytokines Production',
#        'Signaling By TGFB Family Members',
#        'Corticotropin-releasing Hormone Signaling Pathway',
#        'DNA Double Strand Break Response', 'CNTF Signaling',
#        'TGF-beta Signaling Pathways', 'TCR Signaling (Qiagen)',
#        'TP53 Regulates Metabolic Genes', 'Toll Comparative Pathway',
#        'Bladder Cancer', 'RhoGDI Pathway', 'RAB Geranylgeranylation',
#        'Wnt / Hedgehog / Notch',
#        'Cooperation of Prefoldin and TriC/CCT in Actin and Tubulin Folding',
#        'Immune Response IL-2 Activation and Signaling Pathway',
#        'Separation of Sister Chromatids',
#        'Development_Glucocorticoid Receptor Signaling',
#        'Nuclear Events Mediated By NFE2L2', 'Direct P53 Effectors',
#        'Potential Therapeutics For SARS',
#        'Cell Cycle Role of 14-3-3 Proteins in Cell Cycle Regulation',
#        'Translation Factors', 'Death Receptor Signaling Pathway',
#        'Signaling By NTRKs', 'Cyclins and Cell Cycle Regulation',
#        '16p11.2 Proximal Deletion Syndrome',
#        'WtCFTR and Delta508-CFTR Traffic / Generic Schema (norm and CF)',
#        'Intracellular Trafficking Proteins Involved in CMT Neuropathy',
#        'Cytoskeleton Remodeling Regulation of Actin Cytoskeleton By Rho GTPases',
#        'Glycolysis (BioCyc)',
#        'Transcriptional Activity of SMAD2/SMAD3:SMAD4 Heterotrimer',
#        'Regulation of Actin Cytoskeleton', 'NGF Pathway',
#        'Syndecan-4-mediated Signaling Events',
#        'Beta-2 Adrenergic-dependent CFTR Expression',
#        'Regulation of RUNX1 Expression and Activity', 'HIV Life Cycle',
#        'Translation Insulin Regulation of Translation', 'GDNF Signaling',
#        'Smith-Magenis and Potocki-Lupski Syndrome Copy Number Variation',
#        'Nuclear Events (kinase and Transcription Factor Activation)',
#        'P75(NTR)-mediated Signaling', 'Activation of CAMP-Dependent PKA',
#        'IL-9 Signaling Pathways', 'G12-G13 in Cellular Signaling',
#        'Proteolysis Putative SUMO-1 Pathway',
#        'FOXM1 Transcription Factor Network', 'Joubert Syndrome',
#        'EphB-EphrinB Signaling', 'C-MYB Transcription Factor Network',
#        'SARS-CoV-2 Modulates Host Translation Machinery',
#        'Colorectal Cancer Metastasis', 'CD28 Co-stimulation',
#        'L1CAM Interactions', 'Endoderm Differentiation',
#        'Pyrimidine Metabolism', 'FCERI Mediated Ca+2 Mobilization',
#        'APC-Cdc20 Mediated Degradation of Nek2A',
#        'ATM Signaling in Development and Disease', 'PAK Pathway',
#        'Respiratory Syncytial Virus Infection Pathway',
#        'Transport of Inorganic Cations/anions and Amino Acids/oligopeptides',
#        'Apoptosis and Survival_Regulation of Apoptosis By Mitochondrial Proteins',
#        'Signaling By PTK6', 'Nuclear Receptors Meta-pathway',
#        'Immune Response_IFN Gamma Signaling Pathway',
#        'PI3K-Akt Signaling Pathway',
#        'Actin Nucleation By ARP-WASP Complex',
#        'Thromboxane Signalling Through TP Receptor', 'Signaling By ERBB2',
#        '5q35 Copy Number Variation', 'NF-kappaB Pathway',
#        'PLK1 Signaling Events', 'Glycosaminoglycan Metabolism',
#        'Uptake and Actions of Bacterial Toxins',
#        'Stabilization and Expansion of The E-cadherin Adherens Junction',
#        'Metabolic Reprogramming in Pancreatic Cancer', 'Ferroptosis',
#        'Cell Junction Organization', 'Tyrosine Kinases / Adaptors',
#        'Signaling Downstream of RAS Mutants',
#        'AP-1 Transcription Factor Network',
#        'Organelle Biogenesis and Maintenance',
#        'Development Dopamine D2 Receptor Transactivation of EGFR',
#        'Development EGFR Signaling Pathway',
#        'Transcription Androgen Receptor Nuclear Signaling',
#        'Regulation of Nuclear SMAD2/3 Signaling',
#        'Apoptosis and Survival FAS Signaling Cascades',
#        'HIF-1-alpha Transcription Factor Network',
#        '7q11.23 Copy Number Variation Syndrome',
#        'Development Angiotensin Activation of ERK',
#        'CCR5 Pathway in Macrophages', 'Acute Viral Myocarditis',
#        'RAC2 GTPase Cycle'], dtype=object)

# %%
overlap = miEAA.merge(gc, left_on='Subcategory', right_on='SuperPath Name')
overlap.head()
# Out:
#                    Category                      Subcategory Enrichment  \
# 0      Reactome (miRPathDB)              Signal Transduction   enriched
# 1  WikiPathways (miRPathDB)  Integrin-mediated Cell Adhesion   enriched
#
#     P-value  P-adjusted   Q-value  Observed              miRNAs/precursors  \
# 0  0.003322    0.003322  0.336655         2  hsa-miR-663a; hsa-miR-6802-5p
# 1  0.003322    0.003322  0.067183         2  hsa-miR-663a; hsa-miR-6802-5p
#
#     Score                   SuperPath Name  # SuperPath Total Genes  \
# 0  166.10              Signal Transduction                     2597
# 1   19.16  Integrin-mediated Cell Adhesion                      140
#
#    # SuperPath Matched Genes  \
# 0                        558
# 1                         44
#
#                              Matched Genes (Symbols)  \
# 0  MUC20, ARL2, MAP2K2, DGKH, ARL4C, PTK6, NHS, S...
# 1  MAP2K2, MAP2K3, CAPN6, CAPN7, CAPNS1, MAP2K7, ...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/signal_tr...
# 1  https://pathcards.genecards.org/card/integrin-...
