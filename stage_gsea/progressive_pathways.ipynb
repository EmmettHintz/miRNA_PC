# %%
import pandas as pd
from upsetplot import generate_data, UpSet, from_contents
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ctl_s1 = pd.read_csv('./ctl_s1/ctl_s1_genes.csv')
s1_s2 = pd.read_csv('./s1_s2/s1_s2_genes.csv')
s2_s3 = pd.read_csv('./s2_s3/s2_s3_genes.csv')
s3_s4 = pd.read_csv('./s3_s4/s3_s4_genes.csv')

# %%
# Extract 'Gene Symbol' From each list
genes_ctl_s1 = ctl_s1['Gene Symbol']
genes_s1_s2 = s1_s2['Gene Symbol']
genes_s2_s3 = s2_s3['Gene Symbol']
genes_s3_s4 = s3_s4['Gene Symbol']

print(f'Genes in ctl_s1: {" ".join(genes_ctl_s1)}\n')
print(f'Genes in s1_s2: {" ".join(genes_s1_s2)}\n')
print(f'Genes in s2_s3: {" ".join(genes_s2_s3)}\n')
print(f'Genes in s3_s4: {" ".join(genes_s3_s4)}\n')
# Out:
# Genes in ctl_s1: AFG1L AP2S1 CSK ZNF787 CLCN7 HIST1H2BL NACC1 UBE2Q1 H2AFX SLC47A1 NEUROD2 CTDNEP1 SCAMP4 ABL1 ARHGAP40 ATL2 C3orf36 GPR20 HIST1H2BO HOXA7 NPR1 PPP1R14A PTPN9 RNASEK SBF1 SETD1B SPRY4 G6PD ABHD12 BARHL1 NUP62 C10orf95 NKX6-2 GNAI2 HOXB8 NFIC PBX2 SFN NFIX ARHGAP31 INO80E MNT PIAS4 AKT1S1 NPW CALR IVNS1ABP SDF4 SIGLEC12 ZNF764 GPRIN1 HIST1H2BE HPCAL1 PHYKPL GRK5 MIF MIOX ZBTB22 AHDC1 DIAPH1 LAD1 NKX2-2 RHOA PEA15 STMN3 MUL1 HIST1H1E NUBP1 AKNA C22orf39 DHTKD1 EN1 NRGN ZSWIM1 ASB6 OTUB1 TCF3 MLLT1 TPM3 DOT1L LNX2 RPTN CAPN6 CASKIN2 GATAD2A HSP90AB1 LSG1 MEF2D PGAP1 SRCIN1 TACC3 ABHD17B ADGRB2 CHRNE CTDP1 LIMS2 PRSS12 PDE4C CDH6 AQP2 COLGALT1 EPN1 EVI5L GMDS KMT2A MRPL36 PAX2 PDZD4 RTN4RL2 UBLCP1 XBP1 ANKRD39 AQP1 ARHGAP39 ARL8A ATPAF2 BBS1 C10orf55 CHD1L DHRSX DIRAS1 DOK3 DTX3 DUSP14 FMO1 HCFC1 HHLA3 HOXC6 IDH3G KCNN3 KHSRP LETM2 METTL14 MOCS1 NIT2 PCGF3 PCSK4 PMP22 PNMA8A PNMA8B R3HDM1 RNF130 SDK1 SEMA3F SF3B5 SNRPG SORBS1 SP110 THY1 TMEM50A TONSL UNC5A UQCC2 VGF ZNF556 GDI1 MED7 NDRG3 ADIRF CTTN DSG3 EIF2A INVS MAP1S MICAL2 PKM SHANK3 SS18L1 ZC3H10 ZNF207 ADGRL1 RHOB NDOR1 ZNF251 ABHD16A ALKBH6 AMBRA1 AMELX ANKRD52 AP2M1 AP5Z1 APTX AQP4 ARRB2 ATG9A B
 FZD9 FZR1 G3BP2 G6PD GABPA GAGE1 GALM GALNT1 GALNT17 GATA2 GATA6 GCC1 GCFC2 GCM2 GDF11 GDF15 GDF5OS GDI1 GDPD5 GEMIN8 GFER GFPT2 GFRA1 GIGYF1 GIMAP4 GIMAP6 GINS3 GINS4 GJB1 GLB1L3 GLI2 GLIS2 GLIS3 GLO1 GLP1R GLP2R GMDS GMEB2 GMNN GNA13 GNAQ GNB1L GNL3 GOLGA2 GOLGA7 GOLGA7B GOLGA8A GOLGA8H GOLGA8IP GOLGA8J GOLGA8M GOLPH3L GPATCH3 GPC5 GPIHBP1 GPR137B GPR151 GPR155 GPR173 GPR27 GPR37L1 GPR45 GPR75 GPR82 GPRC5A GPRC5B GRASP GRB10 GRIK4 GRK7 GRM5 GSTO2 GTF2IRD2B GTF3C3 GTPBP4 GZMM HABP4 HADHB HAL HAND2 HAS2 HAS3 HAUS5 HAUS8 HCAR2 HCCS HCN2 HDAC5 HDDC2 HEXIM1 HFE HHIPL1 HIGD1A HIPK3 HIST1H1E HIST1H2AA HIST1H2AD HIST1H2AE HIST1H2AG HIST1H2AH HIST1H2AI HIST1H2BB HIST1H2BD HIST1H2BF HIST1H2BN HIST1H3H HIST2H2AA4 HIST2H2AC HIST2H2BE HIST2H3A HIST2H3C HIST3H2BB HIST3H3 HIVEP2 HLA-A HLA-DOA HLA-DRB5 HLA-E HLX HMBOX1 HMGCR HMGN2 HNRNPC HNRNPUL1 HOMER2 HOOK3 HOXA13 HOXA3 HOXA7 HOXB3 HOXC6 HOXD13 HOXD4 HOXD9 HS2ST1 HSP90B1 HSP ...

# %%
ctl_s1 = pd.ExcelFile('./genecards_comparisons/ctl_s1.xlsx')
s1_s2 = pd.ExcelFile('./genecards_comparisons/s1_s2.xlsx')
s2_s3 = pd.ExcelFile('./genecards_comparisons/s2_s3.xlsx')
s3_s4 = pd.ExcelFile('./genecards_comparisons/s3_s4.xlsx')

# %%
ctl_s1_pathways = pd.read_excel(ctl_s1, 'Pathways', skiprows=18)
s1_s2_pathways = pd.read_excel(s1_s2, 'Pathways', skiprows=18)
s2_s3_pathways = pd.read_excel(s2_s3, 'Pathways', skiprows=18)
s3_s4_pathways = pd.read_excel(s3_s4, 'Pathways', skiprows=18)

ctl_s1_diseases = pd.read_excel(ctl_s1, 'Diseases', skiprows=18)
s1_s2_diseases = pd.read_excel(s1_s2, 'Diseases', skiprows=18)
s2_s3_diseases = pd.read_excel(s2_s3, 'Diseases', skiprows=18)
s3_s4_diseases = pd.read_excel(s3_s4, 'Diseases', skiprows=18)

# %%
print(f'ctl_s1_pathways columns: {ctl_s1_pathways.columns}\n')
print(f's1_s2_pathways columns: {s1_s2_pathways.columns}\n')
print(f's2_s3_pathways columns: {s2_s3_pathways.columns}\n')
print(f's3_s4_pathways columns: {s3_s4_pathways.columns}\n')

print(f'ctl_s1_diseases columns: {ctl_s1_diseases.columns}\n')
print(f's1_s2_diseases columns: {s1_s2_diseases.columns}\n')
print(f's2_s3_diseases columns: {s2_s3_diseases.columns}\n')
print(f's3_s4_diseases columns: {s3_s4_diseases.columns}\n')
# Out:
# ctl_s1_pathways columns: Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')
#
# s1_s2_pathways columns: Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')
#
# s2_s3_pathways columns: Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')
#
# s3_s4_pathways columns: Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')
#
# ctl_s1_diseases columns: Index(['Score', 'Name', 'Disease categories', '# Total Genes',
#        '# Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL',
#        'Genetic Associations', 'Matched Genes for Genetic Associations',
#        'Diferentially Expressed Genes in Tissue Samples',
#        'Genes Matched to Differentially Expressed Genes'],
#       dtype='object')
#
# s1_s2_diseases columns: Index(['Score', 'Name', 'Disease categories', '# Total Genes',
#        '# Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL',
#        'Genetic Associations', 'Matched Genes for Genetic Associations',
#        'Diferentially Expressed Genes in Tissue Samples',
#        'Genes Matched to Differentially Expressed Genes'],
#       dtype='object')
#
# s2_s3_diseases columns: Index(['Score', 'Name', 'Disease categories', '# Total Genes',
#        '# Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL',
#        'Genetic Associations', 'Matched Genes for Genetic Associations',
#        'Diferentially Expressed Genes in Tissue Samples',
#        'Genes Matched to Differentially Expressed Genes'],
#       dtype='object')
#
# s3_s4_diseases columns: Index(['Score', 'Name', 'Disease categories', '# Total Genes',
#        '# Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL',
#        'Genetic Associations', 'Matched Genes for Genetic Associations',
#        'Diferentially Expressed Genes in Tissue Samples',
#        'Genes Matched to Differentially Expressed Genes'],
#       dtype='object')

# %%
ctl_s1_pathways_set = ctl_s1_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 'ctl_s1'})

s1_s2_pathways_set = s1_s2_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 's1_s2'})

s2_s3_pathways_set = s2_s3_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 's2_s3'})

s3_s4_pathways_set = s3_s4_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 's3_s4'})

# %%
#  Merge the data on 'SuperPath Name'
merged_df = ctl_s1_pathways_set
merged_df = merged_df.merge(s1_s2_pathways_set, on='SuperPath Name', how='outer')
merged_df = merged_df.merge(s2_s3_pathways_set, on='SuperPath Name', how='outer')
merged_df = merged_df.merge(s3_s4_pathways_set, on='SuperPath Name', how='outer')



# Calculate the score changes only for the numeric columns
numeric_cols = merged_df.columns.drop('SuperPath Name')
merged_df['score_change'] = merged_df[numeric_cols].max(axis=1) - merged_df[numeric_cols].min(axis=1)

# Sort by score changes
sorted_df = merged_df.sort_values(by='score_change', ascending=False)

# Select top pathways with the most significant changes
top_changes_df = sorted_df.head(10)

# Plot the scores of pathways that change the most over time
plt.figure(figsize=(20, 8))
stages = numeric_cols

for index, row in top_changes_df.iterrows():
    plt.plot(stages, row[numeric_cols], marker='o', label=row['SuperPath Name'])

plt.xlabel('Stages of Cancer Progression')
plt.ylabel('GeneCards SuperPath Scores')
plt.title('Top 10 Pathways with Greatest Score Changes Over the Progression of Cancer')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# Display the top pathways with their score changes
print(f'Top pathways with most significant score changes:\n{top_changes_df}')
# Out:
# Top pathways with most significant score changes:
#                                         SuperPath Name      ctl_s1      s1_s2  \
# 54                                 Cell Cycle, Mitotic  166.096405  15.335396
# 161                               Innate Immune System  166.096405  15.376792
# 261                  RNA Polymerase I Promoter Opening  166.096405  20.053440
# 193                             Metabolism of Proteins  166.096405  28.885033
# 57                       Cellular Responses to Stimuli  166.096405  30.741709
# 288                                Signal Transduction  166.096405  31.167757
# 267  Regulation of Activated PAK-2p34 By Proteasome...  166.096405  32.472600
# 158                                 Infectious Disease  166.096405  33.158832
# 131                    Gene Expression (Transcription)  166.096405  49.830075
# 252                                Prolactin Signaling   50.000000  11.239166
#
#           s2_s3       s3_s4  score_change
# 54    50.678072   33.828545    150.761009
# 161   29.942257   31.587565    150.719612
# 261   33.957630   46.933911    146.042965
# 193  166.096405   39.510654    137.211372
# 57   166.096405   53.000000    135.354696
# 288  166.096405  166.096405    134.928648
# 267  166.096405   53.000000    133.623804
# 158  166.096405  166.096405    132.937573
# 131  166.096405  166.096405    116.266330
# 252   25.753791   37.415419     38.760834

# %%
ctl_s1_pathways_set = ctl_s1_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 'ctl_s1'})
s1_s2_pathways_set = s1_s2_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 's1_s2'})
s2_s3_pathways_set = s2_s3_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 's2_s3'})
s3_s4_pathways_set = s3_s4_pathways[['SuperPath Name', 'Score']].rename(columns={'Score': 's3_s4'})

# Merge the data on 'SuperPath Name'
merged_df_pathways = ctl_s1_pathways_set
merged_df_pathways = merged_df_pathways.merge(s1_s2_pathways_set, on='SuperPath Name', how='outer')
merged_df_pathways = merged_df_pathways.merge(s2_s3_pathways_set, on='SuperPath Name', how='outer')
merged_df_pathways = merged_df_pathways.merge(s3_s4_pathways_set, on='SuperPath Name', how='outer')

# Filter pathways that are present in all groups
pathways_in_all_groups = merged_df_pathways.dropna()

# Calculate the average score for each pathway across all groups (numeric columns only)
numeric_cols_pathways = pathways_in_all_groups.columns.drop('SuperPath Name')
pathways_in_all_groups['average_score'] = pathways_in_all_groups[numeric_cols_pathways].mean(axis=1)

# Sort pathways by the average score
sorted_pathways = pathways_in_all_groups.sort_values(by='average_score', ascending=False)

# Select top pathways with the highest average score
top_pathways = sorted_pathways.head(10)

# Print the top pathways with their average scores
print("Top Pathways Involved Across All Groups (Highest Average Scores):")
print(top_pathways[['SuperPath Name', 'average_score']])

# Determine top pathways for each comparison
top_ctl_s1_pathways = ctl_s1_pathways_set.sort_values(by='ctl_s1', ascending=False).head(10)
top_s1_s2_pathways = s1_s2_pathways_set.sort_values(by='s1_s2', ascending=False).head(10)
top_s2_s3_pathways = s2_s3_pathways_set.sort_values(by='s2_s3', ascending=False).head(10)
top_s3_s4_pathways = s3_s4_pathways_set.sort_values(by='s3_s4', ascending=False).head(10)

# Print top pathways for each comparison group
print("\nTop Pathways for ctl_s1:")
print(top_ctl_s1_pathways[['SuperPath Name', 'ctl_s1']])

print("\nTop Pathways for s1_s2:")
print(top_s1_s2_pathways[['SuperPath Name', 's1_s2']])

print("\nTop Pathways for s2_s3:")
print(top_s2_s3_pathways[['SuperPath Name', 's2_s3']])

print("\nTop Pathways for s3_s4:")
print(top_s3_s4_pathways[['SuperPath Name', 's3_s4']])

# Create the UpSet plot for pathways
data_pathways = {
    'ctl_s1': set(ctl_s1_pathways['SuperPath Name']),
    's1_s2': set(s1_s2_pathways['SuperPath Name']),
    's2_s3': set(s2_s3_pathways['SuperPath Name']),
    's3_s4': set(s3_s4_pathways['SuperPath Name'])
}

upset_data_pathways = from_contents(data_pathways)
upset_pathways = UpSet(upset_data_pathways, subset_size='count')

upset_pathways.plot()

# Show the plot
plt.title('UpSet Plot of Pathways Involved in Cancer Progression')
plt.show()
# Out:
# Top Pathways Involved Across All Groups (Highest Average Scores):
#                                         SuperPath Name  average_score
# 131                    Gene Expression (Transcription)     137.029822
# 158                                 Infectious Disease     132.862012
# 288                                Signal Transduction     132.364243
# 267  Regulation of Activated PAK-2p34 By Proteasome...     104.416352
# 57                       Cellular Responses to Stimuli     103.983630
# 193                             Metabolism of Proteins     100.147124
# 261                  RNA Polymerase I Promoter Opening      66.760346
# 54                                 Cell Cycle, Mitotic      66.484604
# 161                               Innate Immune System      60.750755
# 297                           Signaling By Rho GTPases      37.841068
#
# Top Pathways for ctl_s1:
#                                       SuperPath Name      ctl_s1
# 0                                Signal Transduction  166.096405
# 1                             Metabolism of Proteins  166.096405
# 2                                 Infectious Disease  166.096405
# 3                               Innate Immune System  166.096405
# 4                    Gene Expression (Transcription)  166.096405
# 5  Regulation of Activated PAK-2p34 By Proteasome...  166.096405
# 6                      Cellular Responses to Stimuli  166.096405
# 7                                Cell Cycle, Mitotic  166.096405
# 8                  RNA Polymerase I Promoter Opening  166.096405
# 9                                Cellular Senescence   53.000000
#
# Top Pathways for s1_s2:
#                                       SuperPath Name      s1_s2
# 0                    Gene Expression (Transcription)  49.830075
# 1                                 Infectious Disease  33.158832
# 2  Regulation of Activated PAK-2p34 By Proteasome...  32.472600
# 3                                Signal Transduction  31.167757
# 4                      Cellular Responses to Stimuli  30.741709
# 5                               MAP Kinase Signaling  29.528246
# 6                             Metabolism of Proteins  28.885033
# 7                                         DNA Damage  26.683135
# 8                               Pleural Mesothelioma  20.470913
# 9                    IL-17 Family Signaling Pathways  20.404695
#
# Top Pathways for s2_s3:
#                                       SuperPath Name       s2_s3
# 0                                Signal Transduction  166.096405
# 1                             Metabolism of Proteins  166.096405
# 2                                 Infectious Disease  166.096405
# 3                    Gene Expression (Transcription)  166.096405
# 4  Regulation of Activated PAK-2p34 By Proteasome...  166.096405
# 5                      Cellular Responses to Stimuli  166.096405
# 6                                Cell Cycle, Mitotic   50.678072
# 7                           Signaling By Rho GTPases   47.045804
# 8                                         Metabolism   40.847398
# 9    Processing of Capped Intron-Containing Pre-mRNA   39.830232
#
# Top Pathways for s3_s4:
#                                       SuperPath Name       s3_s4
# 0                                Signal Transduction  166.096405
# 1                                 Infectious Disease  166.096405
# 2                    Gene Expression (Transcription)  166.096405
# 3  Regulation of Activated PAK-2p34 By Proteasome...   53.000000
# 4                      Cellular Responses to Stimuli   53.000000
# 5                  RNA Polymerase I Promoter Opening   46.933911
# 6                               Pleural Mesothelioma   41.854068
# 7                             Metabolism of Proteins   39.510654
# 8                                Cellular Senescence   38.417917
# 9             Signaling By Receptor Tyrosine Kinases   37.682093
# /var/folders/c_/rs13jmts3nbf9xfm917mh9p80000gn/T/ipykernel_86347/32592092.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathways_in_all_groups['average_score'] = pathways_in_all_groups[numeric_cols_pathways].mean(axis=1)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %%
# Extract 'Name' and 'Score' columns and rename for each comparison group
# filter for score >= 52.73
ctl_s1_diseases_set = ctl_s1_diseases[['Name', 'Score']].rename(columns={'Score': 'ctl_s1'})
ctl_s1_diseases_set = ctl_s1_diseases_set[ctl_s1_diseases_set['ctl_s1'] >= 52.73]

# filter for score >= 21.16
s1_s2_diseases_set = s1_s2_diseases[['Name', 'Score']].rename(columns={'Score': 's1_s2'})
s1_s2_diseases_set = s1_s2_diseases_set[s1_s2_diseases_set['s1_s2'] >= 21.16]

# filter for score >= 49.95
s2_s3_diseases_set = s2_s3_diseases[['Name', 'Score']].rename(columns={'Score': 's2_s3'})
s2_s3_diseases_set = s2_s3_diseases_set[s2_s3_diseases_set['s2_s3'] >= 49.95]

# filter for score >= 41.18
s3_s4_diseases_set = s3_s4_diseases[['Name', 'Score']].rename(columns={'Score': 's3_s4'})
s3_s4_diseases_set = s3_s4_diseases_set[s3_s4_diseases_set['s3_s4'] >= 41.18]

# Merge the data on 'Name'
merged_df_diseases = ctl_s1_diseases_set.merge(s1_s2_diseases_set, on='Name', how='outer')
merged_df_diseases = merged_df_diseases.merge(s2_s3_diseases_set, on='Name', how='outer')
merged_df_diseases = merged_df_diseases.merge(s3_s4_diseases_set, on='Name', how='outer')

# Filter diseases that are present in all groups
diseases_in_all_groups = merged_df_diseases.dropna()

# Calculate the average score for each disease across all groups (numeric columns only)
numeric_cols = diseases_in_all_groups.columns.drop('Name')
diseases_in_all_groups['average_score'] = diseases_in_all_groups[numeric_cols].mean(axis=1)

# Sort diseases by the average score
sorted_diseases = diseases_in_all_groups.sort_values(by='average_score', ascending=False)

# Select top diseases with the highest average score
top_diseases = sorted_diseases.head(10)

# Print the top diseases with their average scores
print("Top Diseases Involved Across All Groups (Highest Average Scores):")
print(top_diseases[['Name', 'average_score']])

# Determine top diseases for each comparison
top_ctl_s1_diseases = ctl_s1_diseases_set.sort_values(by='ctl_s1', ascending=False).head(10)
top_s1_s2_diseases = s1_s2_diseases_set.sort_values(by='s1_s2', ascending=False).head(10)
top_s2_s3_diseases = s2_s3_diseases_set.sort_values(by='s2_s3', ascending=False).head(10)
top_s3_s4_diseases = s3_s4_diseases_set.sort_values(by='s3_s4', ascending=False).head(10)

# Print top diseases for each comparison group
print("\nTop Diseases for ctl_s1:")
print(top_ctl_s1_diseases[['Name', 'ctl_s1']])

print("\nTop Diseases for s1_s2:")
print(top_s1_s2_diseases[['Name', 's1_s2']])

print("\nTop Diseases for s2_s3:")
print(top_s2_s3_diseases[['Name', 's2_s3']])

print("\nTop Diseases for s3_s4:")
print(top_s3_s4_diseases[['Name', 's3_s4']])

# Create the UpSet plot for diseases with individual score filters from above
data_diseases = {
    # filter for score >= 52.73
    'ctl_s1': set(ctl_s1_diseases['Name'].loc[ctl_s1_diseases['Score'] >= 52.73]),
    's1_s2': set(s1_s2_diseases['Name'].loc[s1_s2_diseases['Score'] >= 21.16]),
    's2_s3': set(s2_s3_diseases['Name'].loc[ctl_s1_diseases['Score'] >= 49.95]),
    's3_s4': set(s3_s4_diseases['Name'].loc[s3_s4_diseases['Score'] >= 41.18]),
}

# Ensure the order of columns
ordered_data_diseases = {key: data_diseases[key] for key in ['ctl_s1', 's1_s2', 's2_s3', 's3_s4']}

# Create UpSet data from the ordered dictionary
upset_data_diseases = from_contents(ordered_data_diseases)

# Reverse the order of the sets before creating the UpSet plot
upset_diseases = UpSet(upset_data_diseases, subset_size='count', sort_by='degree')

# Manually reverse the order of the sets
set_order = ['s3_s4', 's2_s3', 's1_s2', 'ctl_s1']
upset_diseases = UpSet(upset_data_diseases, subset_size='count', sort_categories_by=None)
upset_diseases.plot()

# Show the plot
plt.title('UpSet Plot of Diseases Involved in Cancer Progression')
plt.show()
# Out:
# Top Diseases Involved Across All Groups (Highest Average Scores):
#                         Name  average_score
# 7              Breast Cancer       173.0550
# 10         Colorectal Cancer       159.8650
# 61           Prostate Cancer       121.2425
# 37               Lung Cancer       111.8500
# 62      Retinitis Pigmentosa       111.7225
# 56            Ovarian Cancer       105.8000
# 24            Gastric Cancer       104.4275
# 44              Microcephaly        97.2475
# 27  Hepatocellular Carcinoma        96.8325
# 4   Autism Spectrum Disorder        85.9125
#
# Top Diseases for ctl_s1:
#                        Name  ctl_s1
# 0             Breast Cancer  239.95
# 1         Colorectal Cancer  216.24
# 2           Prostate Cancer  162.91
# 3               Lung Cancer  159.49
# 4            Ovarian Cancer  151.80
# 5            Gastric Cancer  151.06
# 6      Retinitis Pigmentosa  148.45
# 7  Hepatocellular Carcinoma  138.56
# 8              Microcephaly  135.90
# 9   Leukemia, Acute Myeloid  113.66
#
# Top Diseases for s1_s2:
#                        Name  s1_s2
# 0             Breast Cancer  78.73
# 1         Colorectal Cancer  75.62
# 2      Retinitis Pigmentosa  57.71
# 3           Prostate Cancer  57.11
# 4               Lung Cancer  49.57
# 5            Gastric Cancer  48.65
# 6            Ovarian Cancer  45.51
# 7   Leukemia, Acute Myeloid  45.31
# 8  Hepatocellular Carcinoma  42.57
# 9  Autism Spectrum Disorder  42.28
#
# Top Diseases for s2_s3:
#                        Name   s2_s3
# 0             Breast Cancer  199.49
# 1         Colorectal Cancer  182.67
# 2           Prostate Cancer  140.85
# 3      Retinitis Pigmentosa  137.61
# 4               Lung Cancer  129.61
# 5              Microcephaly  120.62
# 6            Gastric Cancer  116.20
# 7            Ovarian Cancer  112.68
# 8  Autism Spectrum Disorder  106.33
# 9  Hepatocellular Carcinoma  105.87
#
# Top Diseases for s3_s4:
#                        Name   s3_s4
# 0             Breast Cancer  174.05
# 1         Colorectal Cancer  164.93
# 2           Prostate Cancer  124.10
# 3            Ovarian Cancer  113.21
# 4               Lung Cancer  108.73
# 5      Retinitis Pigmentosa  103.12
# 6            Gastric Cancer  101.80
# 7  Hepatocellular Carcinoma  100.33
# 8              Microcephaly   90.99
# 9    Nervous System Disease   86.56
# /var/folders/c_/rs13jmts3nbf9xfm917mh9p80000gn/T/ipykernel_86347/2545117062.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diseases_in_all_groups['average_score'] = diseases_in_all_groups[numeric_cols].mean(axis=1)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/data.py:385: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(False, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /Users/emmetthintz/miniconda3/envs/myenv/lib/python3.10/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
