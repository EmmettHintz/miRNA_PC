# %%
import pandas as pd

# %%
miEAA = pd.read_csv('./ctl_s1_miEAA.csv')
print(miEAA.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 miEAA = pd.read_csv('./ctl_s1_miEAA.csv')
#       2 print(miEAA.columns)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './ctl_s1_miEAA.csv'

# %%
# Print unique categories
print(miEAA['Category'].unique())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)'
#  'Target genes (miRTarBase)' 'Pathways (KEGG)' 'Immune cells'
#  'Gene Ontology (miRWalk)' 'WikiPathways (miRPathDB)' 'Diseases (MNDR)'
#  'Published Diseases' 'Drugs (SM2miR)' 'Pathways (miRWalk)'
#  'Interactions (NPInter)' 'Reactome (miRPathDB)'
#  'Tissue specific (isomiRdb)' 'GO Biological process (miRPathDB)'
#  'KEGG (miRPathDB)' 'GO Molecular function (miRPathDB)'
#  'Localization (RNALocate)' 'Chromosomal location (miRBase)']

# %%
gc = pd.read_csv('./ctl_s1_gc.csv')
gc.columns
# Out:
# Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')

# %%
miEAA.head()
# Out:
#                                             Category  \
# 0  Annotations derived over miRTarBase (Gene Onto...
# 1  Annotations derived over miRTarBase (Gene Onto...
# 2  Annotations derived over miRTarBase (Gene Onto...
# 3  Annotations derived over miRTarBase (Gene Onto...
# 4  Annotations derived over miRTarBase (Gene Onto...
#
#                                          Subcategory Enrichment   P-value  \
# 0                        cytokine activity GO0005125   enriched  0.000064
# 1                      monocyte chemotaxis GO0002548   enriched  0.000705
# 2  positive regulation of cytoskeleton organizati...   enriched  0.000705
# 3           triglyceride metabolic process GO0006641   enriched  0.000705
# 4  regulation of DNA-binding transcription factor...   enriched  0.000824
#
#    P-adjusted   Q-value  Observed  \
# 0    0.000064  0.361506        13
# 1    0.000705  0.361506         3
# 2    0.000705  0.361506         3
# 3    0.000705  0.361506         3
# 4    0.000824  0.361506         8
#
#                                    miRNAs/precursors
# 0  hsa-miR-125a-3p; hsa-miR-6802-5p; hsa-miR-1307...
# 1  hsa-miR-125a-3p; hsa-miR-1307-3p; hsa-miR-6729-5p
# 2  hsa-miR-6861-5p; hsa-miR-125a-3p; hsa-miR-6729-5p
# 3  hsa-miR-125a-3p; hsa-miR-1307-3p; hsa-miR-6729-5p
# 4  hsa-miR-125a-3p; hsa-miR-1307-3p; hsa-miR-6729...

# %%
gc.head()
# Out:
#    Score                   SuperPath Name  # SuperPath Total Genes  \
# 0  166.1              Signal Transduction                     2597
# 1  166.1           Metabolism of Proteins                     2077
# 2  166.1               Infectious Disease                     1818
# 3  166.1             Innate Immune System                     2054
# 4  166.1  Gene Expression (Transcription)                     1543
#
#    # SuperPath Matched Genes  \
# 0                        559
# 1                        494
# 2                        455
# 3                        441
# 4                        428
#
#                              Matched Genes (Symbols)  \
# 0  MUC20, ARL2, MAP2K2, DGKH, ARL4C, PTK6, NHS, C...
# 1  CANX, EIF2B5, MUC19, MUC20, RPS19, ARL2, GAN, ...
# 2  CANX, MUC19, MUC20, RPS19, MAP2K2, MAP2K3, CAP...
# 3  CANX, MUC19, MUC20, MAP2K3, GAN, EIF2S3, SLC11...
# 4  NPM1, CARM1, NUDT21, THRA, ZNF154, ZNF155, AXI...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/signal_tr...
# 1  https://pathcards.genecards.org/card/metabolis...
# 2  https://pathcards.genecards.org/card/infectiou...
# 3  https://pathcards.genecards.org/card/innate_im...
# 4  https://pathcards.genecards.org/card/gene_expr...

# %%
# print the categories from Reactome
print(miEAA['Category'].unique())
print(miEAA['Category'].value_counts())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)'
#  'Target genes (miRTarBase)' 'Pathways (KEGG)' 'Immune cells'
#  'Gene Ontology (miRWalk)' 'WikiPathways (miRPathDB)' 'Diseases (MNDR)'
#  'Published Diseases' 'Drugs (SM2miR)' 'Pathways (miRWalk)'
#  'Interactions (NPInter)' 'Reactome (miRPathDB)'
#  'Tissue specific (isomiRdb)' 'GO Biological process (miRPathDB)'
#  'KEGG (miRPathDB)' 'GO Molecular function (miRPathDB)'
#  'Localization (RNALocate)' 'Chromosomal location (miRBase)']
# Category
# Annotations derived over miRTarBase (Gene Ontology)    619
# Target genes (miRTarBase)                              151
# Diseases (MNDR)                                         41
# Gene Ontology (miRWalk)                                 32
# Pathways (KEGG)                                         21
# Interactions (NPInter)                                  16
# WikiPathways (miRPathDB)                                10
# KEGG (miRPathDB)                                         6
# Reactome (miRPathDB)                                     5
# Published Diseases                                       4
# Immune cells                                             3
# Pathways (miRWalk)                                       2
# Drugs (SM2miR)                                           2
# Tissue specific (isomiRdb)                               1
# GO Biological process (miRPathDB)                        1
# GO Molecular function (miRPathDB)                        1
# Localization (RNALocate)                                 1
# Chromosomal location (miRBase)                           1
# Name: count, dtype: int64

# %%
# find the overlap of the overlap of supepath name and subcategory
miEAA['Subcategory'].unique()
# Out:
# array(['cytokine activity GO0005125', 'monocyte chemotaxis GO0002548',
#        'positive regulation of cytoskeleton organization GO0051495',
#        'triglyceride metabolic process GO0006641',
#        'regulation of DNA-binding transcription factor activity GO0051090',
#        'inositol hexakisphosphate 5-kinase activity GO0000832',
#        'mannosyl-oligosaccharide 1,2-alpha-mannosidase activity GO0004571',
#        'photoreceptor cell morphogenesis GO0008594',
#        'white fat cell differentiation GO0050872',
#        'RNA polymerase II transcription regulator complex GO0090575',
#        'tRNA pseudouridine synthesis GO0031119', 'ZKSCAN1',
#        'G2M transition of mitotic cell cycle GO0000086',
#        'positive regulation of G2M transition of mitotic cell cycle GO0010971',
#        'RNA polymerase III general transcription initiation factor binding GO0001025',
#        'high-density lipoprotein particle remodeling GO0034375',
#        'negative regulation of NLRP3 inflammasome complex assembly GO1900226',
#        'Fatty acid elongation', 'DDX19B', 'ZBTB43',
#        'cellular response to hydrogen peroxide GO0070301',
#        'integrin-mediated signaling pathway GO0007229',
#        'DNA replication GO0006260',
#        'cytoplasmic side of lysosomal membrane GO0098574',
#        'CD15 expressed', 'cytosolic small ribosomal subunit GO0022627',
#        'kinetochore GO0000776', 'mannosyltransferase activity GO0000030',
#        'protein methyltransferase activity GO0008276',
#        'ribosome binding GO0043022',
#        'cyclin-dependent protein kinase activity GO0097472',
#        'histone kinase activity GO0035173',
#        'GO0003700 sequence specific dna binding transcription factor activity',
#        'GO0005654 nucleoplasm', 'G1 to S cell cycle control',
#        'positive regulation of NLRP3 inflammasome complex assembly GO1900227',
#        'endocrine pancreas development GO0031018',
#        'GO0005524 atp binding',
#        'positive regulation of cytokine production GO0001819',
#        'Cholangiocarcinoma', 'TRAMP complex GO0031499',
#        'ncRNA processing GO0034470', 'snRNA catabolic process GO0016076',
#        'ZCCHC8', 'dilated cardiomyopathy deregulated',
#        'dilated cardiomyopathy upregulated', 'Trastuzumab',
#        'Integrated Cancer Pathway',
#        'cellular response to type II interferon GO0071346',
#        'chemoattractant activity GO0042056',
#        'Golgi ribbon formation GO0090161',
#        'N-acetylneuraminate metabolic process GO0006054',
#        'N-acylmannosamine kinase activity GO0009384',
#        'Shu complex GO0097196', 'T cell homeostasis GO0043029',
#        'UDP-N-acetylglucosamine 2-epimerase activity GO0008761',
#        'antigen processing and presentation of peptide antigen via MHC class I GO0002474',
#        'chemokine receptor activity GO0004950',
#        'cyclin D2-CDK4 complex GO0097129',
#        'cyclin D3-CDK4 complex GO0097130', 'cytolytic granule GO0044194',
#        'hepatic immune response GO0002384',
#        'immune system process GO0002376',
#        'interleukin-6 receptor complex GO0005896',
#        'long-chain fatty-acyl-CoA biosynthetic process GO0035338',
#        'mesenchymal cell development GO0014031',
#        'muscle system process GO0003012',
#        'positive regulation of activation of Janus kinase activity GO0010536',
#        'positive regulation of anterograde synaptic vesicle transport GO1903744',
#        'regulation of MyD88-dependent toll-like receptor signaling pathway GO0034124',
#        'regulation of cellular respiration GO0043457',
#        'sialylation GO0097503',
#        'type II interferon-mediated signaling pathway GO0060333',
#        'ARHGEF39', 'BORCS5', 'CDK4', 'CENPBD1', 'GNE', 'IRF1', 'MELK',
#        'MRPL36', 'SWSAP1', 'TRIM72', 'WDR31', 'ZNF430', 'ZNF439',
#        'GO0000166 nucleotide binding', 'GO0000922 spindle pole',
#        'GO0005085 guanyl nucleotide exchange factor activity',
#        'GO0016032 viral reproduction',
#        'GO0030529 ribonucleoprotein complex',
#        'GO0042802 identical protein binding',
#        'GO0043123 positive regulation of i kappab kinase nf kappab cascade',
#        'GO0060170 cilium membrane', 'hsa05110 Vibrio cholerae infection',
#        'Pancreatic adenocarcinoma', 'LIN28', 'Rbm20', 'TRIP6', 'Measles',
#        'mitotic spindle assembly checkpoint signaling GO0007094',
#        'L-cysteine desulfurase complex GO1990221',
#        'ferroxidase activity GO0004322',
#        'iron chaperone activity GO0034986',
#        'iron incorporation into metallo-sulfur cluster GO0018283',
#        'positive regulation of lyase activity GO0051349',
#        'positive regulation of succinate dehydrogenase activity GO1904231',
#        'protein autoprocessing GO0016540',
#        'regulation of ferrochelatase activity GO0010722',
#        'response to iron ion GO0010039', 'FXN', 'Cell Cycle',
#        'amyloid-beta formation GO0034205',
#        'amyloid precursor protein metabolic process GO0042982',
#        'gamma-secretase complex GO0070765',
#        'vascular endothelial growth factor production GO0010573',
#        'POLR2E', 'helicase activity GO0004386',
#        'positive regulation of osteoblast differentiation GO0045669',
#        'Cajal body GO0015030',
#        'ubiquitin-dependent protein catabolic process via the C-end degron rule pathway GO0140627',
#        'GAIT complex GO0097452', 'MHC class I protein binding GO0042288',
#        'WD40-repeat domain binding GO0071987',
#        'apoptotic DNA fragmentation GO0006309',
#        'dendritic cell chemotaxis GO0002407',
#        'positive regulation of chemokine C-X-C motif ligand 2 production GO2000343',
#        'positive regulation of monocyte chemotaxis GO0090026', 'SUSD6',
#        'Glioma', 'transcription by RNA polymerase III GO0006383',
#        'positive regulation of vascular endothelial growth factor production GO0010575',
#        'negative regulation of protein phosphorylation GO0001933',
#        'Systemic lupus erythematosus', 'BORC complex GO0099078',
#        'K48-linked deubiquitinase activity GO1990380',
#        'anterograde neuronal dense core vesicle transport GO1990048',
#        'organelle transport along microtubule GO0072384',
#        'regulation of endosome size GO0051036',
#        'regulation of lysosome size GO0062196',
#        'retrograde neuronal dense core vesicle transport GO1990049',
#        'synaptic vesicle transport GO0048489', 'Basal-like breast cancer',
#        'Breast cancer luminal', 'microtubule organizing center GO0005815',
#        'brush border membrane GO0031526',
#        'cellular response to interferon-beta GO0035458',
#        'complement activation GO0006956',
#        'negative regulation of glucose import GO0046325',
#        'reverse cholesterol transport GO0043691', 'PEA15',
#        'C5L2 anaphylatoxin chemotactic receptor binding GO0031715',
#        'GMP biosynthetic process GO0006177',
#        'axonemal microtubule GO0005879',
#        'branchiomotor neuron axon guidance GO0021785',
#        'chitobiosyldiphosphodolichol beta-mannosyltransferase activity GO0004578',
#        'chylomicron GO0042627',
#        'complement-mediated synapse pruning GO0150062',
#        'de novo AMP biosynthetic process GO0044208',
#        'de novo IMP biosynthetic process GO0006189',
#        'de novo XMP biosynthetic process GO0097294',
#        'detection of chemical stimulus involved in sensory perception of bitter taste GO0001580',
#        'facial nerve structural organization GO0021612',
#        'intraciliary anterograde transport GO0035720',
#        'large ribosomal subunit GO0015934',
#        'negative regulation of formation of translation preinitiation complex GO1901194',
#        'neuron projection guidance GO0097485',
#        'nuclease activity GO0004518',
#        'palmitoyltransferase activity GO0016409',
#        'positive regulation of G protein-coupled receptor signaling pathway GO0045745',
#        'positive regulation of apoptotic cell clearance GO2000427',
#        'positive regulation of glucose transmembrane transport GO0010828',
#        'protein palmitoylation GO0018345',
#        'pyramidal neuron development GO0021860',
#        'transforming growth factor beta ligand-receptor complex GO0070021',
#        'tricuspid valve morphogenesis GO0003186',
#        'trigeminal nerve structural organization GO0021637',
#        'vertebrate eye-specific patterning GO0150064',
#        'very-low-density lipoprotein particle assembly GO0034379', 'ALG1',
#        'C3', 'MRPS10', 'PLXNA3', 'PXMP4', 'RPL13A', 'TRUB2', 'ZNF101',
#        'ZNF43', 'Mitotic G1-G1S phases',
#        'roof of mouth development GO0060021',
#        'endothelial cell migration GO0043542',
#        'retrograde transport, endosome to Golgi GO0042147',
#        'type I interferon-mediated signaling pathway GO0060337',
#        'response to organic substance GO0010033',
#        'glucuronosyltransferase activity GO0015020',
#        'monoatomic ion homeostasis GO0050801',
#        'cyclin-dependent protein serinethreonine kinase activity GO0004693',
#        'proteasome-mediated ubiquitin-dependent protein catabolic process GO0043161',
#        'NFAT protein binding GO0051525',
#        'aminopeptidase activity GO0004177',
#        'histone H2A monoubiquitination GO0035518',
#        'positive regulation of DNA ligation GO0051106',
#        'positive regulation of dendritic cell cytokine production GO0002732',
#        'positive regulation of neuroinflammatory response GO0150078',
#        'positive regulation of reactive oxygen species biosynthetic process GO1903428',
#        'protein localization to kinetochore GO0034501',
#        'regulation of innate immune response GO0045088',
#        'telomerase activity GO0003720',
#        'mitotic metaphase plate congression GO0007080',
#        'intracellular protein transport GO0006886',
#        'regulation of ATP-dependent activity GO0043462',
#        'defense response to Gram-negative bacterium GO0050829',
#        'late endosome GO0005770', 'PML body organization GO0030578',
#        'SUMO binding GO0032183',
#        'Wnt signaling pathway, calcium modulating pathway GO0007223',
#        'activin receptor activity, type II GO0016362',
#        'bub1-bub3 complex GO1990298',
#        'cellular response to nitric oxide GO0071732',
#        'centriole replication GO0007099',
#        'lactoylglutathione lyase activity GO0004462',
#        'mitotic checkpoint complex GO0033597',
#        'neuronal ribonucleoprotein granule GO0071598',
#        'positive regulation of B cell activation GO0050871',
#        'positive regulation of activin receptor signaling pathway GO0032927',
#        'positive regulation of heterochromatin formation GO0031453',
#        'protein K33-linked ubiquitination GO1990390',
#        'protein localization to nucleoplasm GO1990173',
#        'serine phosphorylation of STAT protein GO0042501',
#        'tRNA modification GO0006400',
#        'transmembrane receptor protein serinethreonine kinase signaling pathway GO0007178',
#        'ACVR2B', 'AREL1', 'BUB3', 'C11orf1', 'CDK2', 'EIF4EBP2', 'GLO1',
#        'LEFTY1', 'NLK', 'PUS3', 'SERBP1', 'TBRG1',
#        'Regulation of signaling by NODAL', 'Signaling by NODAL',
#        'Mesodermal Commitment Pathway', 'aorta morphogenesis GO0035909',
#        'chondroitin sulfate biosynthetic process GO0030206',
#        'inorganic cation transmembrane transporter activity GO0022890',
#        'secondary palate development GO0062009',
#        'chemical synaptic transmission GO0007268',
#        'Estrogen-receptor negative breast cancer',
#        'Estrogen-receptor positive breast cancer', 'Lung cancer',
#        'Progesterone-receptor positive breast cancer',
#        'viral release from host cell GO0019076', 'ZSWIM1',
#        'negative regulation of DNA binding GO0043392',
#        'Glycerolipid metabolism',
#        'Cul4-RING E3 ubiquitin ligase complex GO0080008',
#        'heme biosynthetic process GO0006783', 'Osteosarcoma',
#        'Prostate cancer', 'Lymphoma', 'Melanoma',
#        'Rho GDP-dissociation inhibitor activity GO0005094',
#        'translation repressor activity GO0030371', 'ARHGDIA',
#        '10-formyltetrahydrofolate biosynthetic process GO0009257',
#        'Derlin-1 retrotranslocation complex GO0036513',
#        'embryonic neurocranium morphogenesis GO0048702',
#        'embryonic viscerocranium morphogenesis GO0048703',
#        'forebrain development GO0030900',
#        'formate-tetrahydrofolate ligase activity GO0004329',
#        'morphogenesis of an epithelium GO0002009',
#        'negative regulation of lipid catabolic process GO0050995',
#        'Breast invasive carcinoma', 'Carcinoma ductal breast',
#        'Gastric adenocarcinoma', 'Multiple myeloma',
#        'Oral squamous cell carcinoma', 'Ovarian clear cell carcinoma',
#        'Pancreatic ductal adenocarcinoma', 'Prostate adenocarcinoma',
#        'Stomach adenocarcinoma', 'semen specific',
#        'positive regulation of focal adhesion assembly GO0051894',
#        'translation initiation factor activity GO0003743',
#        'T cell receptor signaling pathway GO0050852',
#        'BMP signaling pathway GO0030509',
#        'aortic valve morphogenesis GO0003180',
#        'regulation of Rho protein signal transduction GO0035023',
#        '2-acylglycerol O-acyltransferase activity GO0003846',
#        '4-alpha-hydroxytetrahydrobiopterin dehydratase activity GO0008124',
#        'ESCEZ complex GO0035098', 'GMP 5-nucleotidase activity GO0050484',
#        'GMP metabolic process GO0046037',
#        'IMP 5-nucleotidase activity GO0050483',
#        'IMP catabolic process GO0006204',
#        'IMP metabolic process GO0046040',
#        'RNA lariat debranching enzyme activator activity GO0061632',
#        'TRC complex GO0072380', 'Toll-like receptor 2 binding GO0035663',
#        'acetylcholine binding GO0042166',
#        'actin-mediated cell contraction GO0070252',
#        'adenosine metabolic process GO0046085',
#        'allantoin metabolic process GO0000255',
#        'alpha-mannosidase activity GO0004559',
#        'caveola assembly GO0070836',
#        'cell projection organization GO0030030',
#        'cobalamin binding GO0031419',
#        'cobalamin metabolic process GO0009235',
#        'corrinoid adenosyltransferase activity GO0008817',
#        'dGMP metabolic process GO0046054',
#        'diacylglycerol O-acyltransferase activity GO0004144',
#        'embryonic process involved in female pregnancy GO0060136',
#        'fatty acid beta-oxidation using acyl-CoA dehydrogenase GO0033539',
#        'filamin binding GO0031005', 'glycolipid binding GO0051861',
#        'glycolipid transfer activity GO0017089',
#        'growth hormone receptor signaling pathway GO0060396',
#        'heart formation GO0060914', 'heme export GO0097037',
#        'heme transport GO0015886',
#        'isovaleryl-CoA dehydrogenase activity GO0008470',
#        'leucine catabolic process GO0006552', 'lipase activity GO0016298',
#        'lipid catabolic process GO0016042',
#        'membrane raft assembly GO0001765',
#        'mitochondrial RNA 5-end processing GO0000964',
#        'mitochondrion morphogenesis GO0070584',
#        'muscle alpha-actinin binding GO0051371',
#        'muscle structure development GO0061061',
#        'natural killer cell proliferation GO0001787',
#        'negative regulation of hydrogen peroxide biosynthetic process GO0010730',
#        'negative regulation of lymphangiogenesis GO1901491',
#        'negative regulation of very-low-density lipoprotein particle clearance GO0010916',
#        'neutrophil migration GO1990266',
#        'nucleoside phosphotransferase activity GO0050146',
#        'phospholipase A1 activity GO0008970',
#        'photoreceptor outer segment membrane GO0042622',
#        'plasma membrane raft assembly GO0044854',
#        'positive regulation of cardiac epithelial to mesenchymal transition GO0062043',
#        'positive regulation of cholesterol transport GO0032376',
#        'positive regulation of cytokine production involved in inflammatory response GO1900017',
#        'positive regulation of high-density lipoprotein particle clearance GO0010983',
#        'protein localization involved in establishment of planar polarity GO0090251',
#        'regulation of cellular senescence GO2000772',
#        'regulation of endothelial cell migration GO0010594',
#        'regulation of glomerular filtration GO0003093',
#        'regulation of integrin activation GO0033623',
#        'regulation of kinase activity GO0043549',
#        'regulation of vasculogenesis GO2001212',
#        'ribosome assembly GO0042255',
#        'tRNA guanine-N1--methyltransferase activity GO0009019',
#        'tetraspanin-enriched microdomain GO0097197',
#        'thyroid hormone metabolic process GO0042403',
#        'toll-like receptor 4 signaling pathway GO0034142',
#        'toll-like receptor 7 signaling pathway GO0034154',
#        'toll-like receptor TLR1TLR2 signaling pathway GO0038123',
#        'transferase activity, transferring alkyl or aryl other than methyl groups GO0016765',
#        'unconventional myosin complex GO0016461',
#        'uropod membrane GO0031259',
#        'very long-chain fatty acid biosynthetic process GO0042761',
#        'visual behavior GO0007632', 'ABHD18', 'ARPC2', 'CHCHD5',
#        'CWF19L1', 'CYTIP', 'EIF2A', 'EMP2', 'ENAH', 'FAXC', 'FBLIM1',
#        'FBXL2', 'FLVCR1', 'GATAD1', 'GLTP', 'HAUS2', 'HSPE1-MOB4', 'IVD',
#        'KLB', 'LIPG', 'MMAB', 'MOB4', 'NPHP1', 'NT5C2', 'OMD', 'OSTF1',
#        'PBOV1', 'PCBD2', 'PDE6A', 'PDLIM3', 'POLR3A', 'SCIMP', 'SGTB',
#        'SS18L1', 'TMEM132B', 'TMEM154', 'TMIGD2', 'TTC31', 'WDR5B',
#        'ZNF576', 'RP11-108M9.3', 'RP11-160E2.6',
#        'platelet activation GO0030168', 'protein transport GO0015031',
#        'MAP kinase activity GO0004707',
#        'phosphatidylinositol 3-kinase signaling GO0014065',
#        'positive regulation of protein localization to centrosome GO1904781',
#        'syntaxin-1 binding GO0017075',
#        'regulation of ubiquitin-protein transferase activity GO0051438',
#        'stress fiber assembly GO0043149',
#        'endoplasmic reticulum to Golgi vesicle-mediated transport GO0006888',
#        '2Fe-2S cluster assembly GO0044571',
#        '4Fe-4S cluster assembly GO0044572',
#        'ATPase-coupled inorganic anion transmembrane transporter activity GO0043225',
#        'export across plasma membrane GO0140115',
#        'iron-sulfur cluster assembly complex GO1990229',
#        'mitochondrial iron-sulfur cluster assembly complex GO0099128',
#        'positive regulation of aconitate hydratase activity GO1904234',
#        'L-methionine salvage from methylthioadenosine GO0019509',
#        'cAMP response element binding GO0035497',
#        'dendrite morphogenesis GO0048813',
#        'negative regulation of peptidyl-serine dephosphorylation GO1902309',
#        'regulation of epithelial to mesenchymal transition GO0010717',
#        'small ribosomal subunit GO0015935',
#        'mitotic spindle assembly GO0090307',
#        'visual perception GO0007601', '9+0 non-motile cilium GO0097731',
#        'ATP metabolic process GO0046034', 'ATP transport GO0015867',
#        'EP4 subtype prostaglandin E2 receptor binding GO0031867',
#        'Golgi-associated vesicle membrane GO0030660',
#        'RNA decapping GO0110154', 'abscission GO0009838',
#        'acetyl-CoA carboxylase activity GO0003989',
#        'acetyl-CoA metabolic process GO0006084',
#        'adenosine 5-hexahydrogen pentaphosphate catabolic process GO1901911',
#        'anterior commissure morphogenesis GO0021960',
#        'bis5-adenosyl-hexaphosphatase activity GO0034431',
#        'bis5-adenosyl-pentaphosphatase activity GO0034432',
#        'chemorepulsion involved in embryonic olfactory bulb interneuron precursor migration GO0021834',
#        'club cell differentiation GO0060486',
#        'diadenosine hexaphosphate catabolic process GO1901909',
#        'diadenosine pentaphosphate catabolic process GO1901907',
#        'diadenosine polyphosphate catabolic process GO0015961',
#        'diphosphoinositol-polyphosphate diphosphatase activity GO0008486',
#        'diphosphoinositol polyphosphate catabolic process GO0071544',
#        'diphosphoinositol polyphosphate metabolic process GO0071543',
#        'endopolyphosphatase activity GO0000298',
#        'fatty-acyl-CoA biosynthetic process GO0046949',
#        'hindbrain development GO0030902',
#        'inositol diphosphate pentakisphosphate diphosphatase activity GO0052842',
#        'inositol diphosphate tetrakisphosphate diphosphatase activity GO0052840',
#        'interleukin-6-mediated signaling pathway GO0070102',
#        'lung ciliated cell differentiation GO0061141',
#        'mRNA 3-end processing GO0031124',
#        'mitochondrial transcription GO0006390',
#        'negative regulation of epithelial cell proliferation involved in lung morphogenesis GO2000795',
#        'negative regulation of mesenchymal cell proliferation involved in lung development GO2000791',
#        'principal sensory nucleus of trigeminal nerve development GO0021740',
#        'proteasome regulatory particle binding GO1904855',
#        'regulation of cellular response to stress GO0080135',
#        'regulation of proteasome assembly GO0090364',
#        'response to cold GO0009409',
#        'type II pneumocyte differentiation GO0060510',
#        'type I pneumocyte differentiation GO0060509', 'ACACA', 'APH1A',
#        'FEM1A', 'MAP2K3', 'MRPS16', 'NFIB', 'NUDT3', 'SPART', 'TMED4',
#        'TNRC18P2', 'UBLCP1', 'ZER1', 'ZNF251', 'ZNF764',
#        'positive regulation of cellular metabolic process',
#        'Central carbon metabolism in cancer',
#        'transport across blood-brain barrier GO0150104',
#        'acylglycerol lipase activity GO0047372',
#        'apoptotic cell clearance GO0043277',
#        'keratan sulfate biosynthetic process GO0018146',
#        'lens fiber cell morphogenesis GO0070309',
#        'mitotic sister chromatid cohesion, centromeric GO0071962',
#        'negative regulation of fat cell differentiation GO0045599',
#        'positive regulation of receptor signaling pathway via STAT GO1904894',
#        'Glycosaminoglycan biosynthesis - keratan sulfate',
#        'Cell Cycle Checkpoints',
#        'determination of leftright symmetry GO0007368',
#        'enzyme regulator activity GO0030234',
#        'toll-like receptor 3 signaling pathway GO0034138',
#        'Phototransduction', 'PHLDA3', 'RABGAP1L',
#        'blood microparticle GO0072562', 'T cell migration GO0072678',
#        'axon extension involved in axon guidance GO0048846',
#        'methylosome GO0034709',
#        'positive regulation of calcium ion transport GO0051928',
#        'positive regulation of interleukin-10 production GO0032733',
#        'ubiquitin binding GO0043130', 'Lysosome',
#        'cell migration GO0016477',
#        'inward rectifier potassium channel activity GO0005242',
#        '1-phosphatidylinositol-4-phosphate 3-kinase activity GO0035005',
#        'Wnt signalosome GO1990909',
#        'attachment of mitotic spindle microtubules to kinetochore GO0051315',
#        'cyclin B1-CDK1 complex GO0097125',
#        'phosphatidylinositol 3-kinase activity GO0035004',
#        'positive regulation of B cell receptor signaling pathway GO0050861',
#        'positive regulation of mitochondrial ATP synthesis coupled electron transport GO1905448',
#        'FYTTD1', 'TOR2A',
#        'GO0000122 negative regulation of transcription from rna polymerase ii promoter',
#        'GO0000226 microtubule cytoskeleton organization',
#        'GO0003690 double stranded dna binding',
#        'GO0005576 extracellular region',
#        'GO0005815 microtubule organizing center',
#        'GO0006915 apoptotic process', 'GO0007067 mitosis',
#        'GO0007173 epidermal growth factor receptor signaling pathway',
#        'GO0007569 cell aging', 'GO0008022 protein c terminus binding',
#        'GO0008286 insulin receptor signaling pathway',
#        'GO0008543 fibroblast growth factor receptor signaling pathway',
#        'GO0010467 gene expression',
#        'GO0048011 nerve growth factor receptor signaling pathway',
#        'P00031 Inflammation mediated by chemokine and cytokine signaling pathway',
#        'B cell lymphoma of malt type', 'Intellectual disability',
#        'FoxO signaling pathway', 'Pathways in cancer',
#        'Proteoglycans in cancer', 'p53 signaling pathway',
#        'Signal Transduction',
#        'Chromosomal and microsatellite instability in colorectal cancer',
#        'DNA Damage Response only ATM dependent',
#        'Integrin-mediated Cell Adhesion', 'Retinoblastoma Gene in Cancer',
#        'GGA3', 'LTBP4', 'NCKAP5L', 'PTGDS', 'SAP18', 'SEMA4C', 'SYN2',
#        'ZNF385A', 'cholesterol biosynthetic process GO0006695',
#        'ephrin receptor signaling pathway GO0048013',
#        'glucose metabolic process GO0006006',
#        'positive regulation of autophagy GO0010508',
#        'positive regulation of interleukin-6 production GO0032755',
#        'histone deacetylase binding GO0042826',
#        'CARD domain binding GO0050700',
#        'N-acetylglucosamine 6-O-sulfotransferase activity GO0001517',
#        'TIM22 mitochondrial import inner membrane insertion complex GO0042721',
#        'cyclin A2-CDK2 complex GO0097124',
#        'intracellular copper ion homeostasis GO0006878',
#        'negative regulation of interleukin-1 beta production GO0032691',
#        'negative regulation of phagocytosis GO0050765',
#        'photoreceptor disc membrane GO0097381',
#        'regulation of MAP kinase activity GO0043405',
#        'respiratory chain complex IV assembly GO0008535',
#        'ribosomal large subunit binding GO0043023',
#        'sulfur compound metabolic process GO0006790', 'JARID2', 'KIF1C',
#        'Cervical squamous cell carcinoma',
#        'High-grade serous ovarian carcinoma', 'Lung small cell carcinoma',
#        'Ovarian cancer', 'Ovarian carcinoma', 'Ovarian neoplasms',
#        'Small cell lung cancer', 'CD3 expressed', 'CD56 expressed',
#        '4-hydroxynonenal', 'Apoptosis Modulation and Signaling', 'ATPIF1',
#        'NADPH regeneration GO0006740', 'NADP metabolic process GO0006739',
#        'glucose-6-phosphate dehydrogenase activity GO0004345',
#        'negative regulation of protein glutathionylation GO0010734',
#        'pentose-phosphate shunt, oxidative branch GO0009051',
#        'pentose-phosphate shunt GO0006098',
#        'pentose biosynthetic process GO0019322',
#        'positive regulation of aspartic-type endopeptidase activity involved in amyloid precursor protein catabolic process GO1902961',
#        'regulation of cell adhesion mediated by integrin GO0033628',
#        'response to interferon-beta GO0035456',
#        'ribose phosphate biosynthetic process GO0046390', 'G6PD',
#        'transcription regulatory region DNA binding',
#        'Rho protein signal transduction GO0007266',
#        'cytoplasmic microtubule GO0005881',
#        'DNA-binding transcription factor activity GO0003700',
#        'phospholipid catabolic process GO0009395',
#        'cholesterol metabolic process GO0008203',
#        'metaphase plate congression GO0051310',
#        'retinoic acid receptor signaling pathway GO0048384',
#        'synaptic vesicle membrane GO0030672', 'Microvesicle',
#        'T cell proliferation GO0042098',
#        'lipopolysaccharide binding GO0001530',
#        'membrane insertase activity GO0032977',
#        'proteolysis involved in protein catabolic process GO0051603',
#        'protein-DNA complex GO0032993',
#        'regulation of gene expression GO0010468',
#        'double-stranded DNA binding GO0003690', 'Wnt signaling pathway',
#        'cell projection GO0042995', 'chloride channel activity GO0005254',
#        'negative regulation of cell size GO0045792',
#        'positive regulation of interleukin-12 production GO0032735',
#        'acute-phase response GO0006953', 'axon ensheathment GO0008366',
#        'intraciliary transport particle B GO0030992',
#        'negative regulation of intracellular estrogen receptor signaling pathway GO0033147',
#        'phosphatidylinositol-3-phosphate biosynthetic process GO0036092',
#        'GO0003677 dna binding', 'GO0005515 protein binding',
#        'GO0005634 nucleus', 'GO0005737 cytoplasm', 'GO0005829 cytosol',
#        'GO0005886 plasma membrane', 'Rheumatoid arthritis', 'Cell cycle',
#        'receptor ligand activity GO0048018', 'social behavior GO0035176',
#        'JAK pathway signal transduction adaptor activity GO0008269',
#        'NEDD8 ligase activity GO0061663',
#        'alanine transmembrane transporter activity GO0022858',
#        'cell cycle GO0007049',
#        'central nervous system vasculogenesis GO0022009',
#        'interleukin-22 receptor activity GO0042018',
#        'ligase activity GO0016874',
#        'multivesicular body membrane GO0032585',
#        'negative regulation of intrinsic apoptotic signaling pathway by p53 class mediator GO1902254',
#        'negative regulation of protein autophosphorylation GO0031953',
#        'regulation of glucose transmembrane transport GO0010827',
#        'taurine transmembrane transporter activity GO0005368',
#        'taurine transport GO0015734',
#        'transcription factor catabolic process GO0036369',
#        'type I interferon receptor activity GO0004905',
#        'Phenylalanine metabolism', 'Chromosome 12', 'ELMSAN1', 'IFNAR2',
#        'MDM2', 'SLC36A1', 'ZNF460', 'Breast neoplasms',
#        'DNA IR-Double Strand Breaks DSBs and cellular response via ATM',
#        'C-type lectin receptor signaling pathway',
#        'Osteoclast differentiation',
#        'negative regulation of vascular associated smooth muscle cell proliferation GO1904706',
#        'embryonic cranial skeleton morphogenesis GO0048701',
#        'Kidney renal papillary cell carcinoma',
#        'Papillary renal cell carcinoma',
#        'lysine-acetylated histone binding GO0070577',
#        'positive regulation of transforming growth factor beta receptor signaling pathway GO0030511',
#        'protein-folding chaperone binding GO0051087',
#        'molecular condensate scaffold activity GO0140693',
#        'mRNA splice site selection GO0006376',
#        'phospholipase activity GO0004620', 'tRNA binding GO0000049',
#        'transcription coregulator binding GO0001221',
#        'double-stranded RNA binding GO0003725',
#        'transport vesicle GO0030133', 'histone binding GO0042393',
#        'Breast cancer', 'Coronavirus disease - COVID-19',
#        '1-phosphatidylinositol-3-kinase activity GO0016303',
#        '5-nucleotidase activity GO0008253', 'BLOC-1 complex GO0031083',
#        'L-alanine transmembrane transporter activity GO0015180',
#        'L-alanine transport GO0015808',
#        'L-proline transmembrane transporter activity GO0015193',
#        'amino acidproton symporter activity GO0005280',
#        'anterograde synaptic vesicle transport GO0048490',
#        'branched-chain amino acid catabolic process GO0009083',
#        'cysteine-type endopeptidase activator activity involved in apoptotic process GO0008656',
#        'extrinsic component of endoplasmic reticulum membrane GO0042406',
#        'glutamate secretion GO0014047',
#        'glycine transmembrane transporter activity GO0015187',
#        'glycine transport GO0015816', 'lateral element GO0000800',
#        'mitochondrion-endoplasmic reticulum membrane tethering GO1990456',
#        'multi-pass translocon complex GO0160064',
#        'multi-pass transmembrane protein insertion into ER membrane GO0160063',
#        'negative regulation of beta-galactosidase activity GO1903770',
#        'negative regulation of exonuclease activity GO1905778',
#        'negative regulation of glucocorticoid receptor signaling pathway GO2000323',
#        'negative regulation of telomere capping GO1904354',
#        'negative regulation of telomere maintenance GO0032205',
#        'negative regulation of telomere maintenance via recombination GO0032208',
#        'negative regulation of telomere maintenance via semi-conservative replication GO0032214',
#        'negative regulation of telomere single strand break repair GO1903824',
#        'negative regulation of telomeric D-loop disassembly GO1905839',
#        'nuclear ubiquitin ligase complex GO0000152',
#        'positive regulation of chromosome separation GO1905820',
#        'positive regulation of melanin biosynthetic process GO0048023',
#        'proline transmembrane transport GO0035524',
#        'prolineproton symporter activity GO0005297',
#        'protection from non-homologous end joining at telomere GO0031848',
#        'regulation of double-strand break repair via homologous recombination GO0010569',
#        'regulation of telomere maintenance via telomerase GO0032210',
#        'shelterin complex GO0070187', 'steroid binding GO0005496',
#        'telomeric loop formation GO0031627',
#        'vacuolar membrane GO0005774', 'vesicle membrane GO0012506',
#        'DIRAS1', 'GIPC1', 'TERF2', 'TMCO1', 'TMEM170A',
#        'Rac protein signal transduction GO0016601',
#        'actin polymerization or depolymerization GO0008154',
#        'humoral immune response GO0006959',
#        'mitochondrial ribosome GO0005761', 'GO0005739 mitochondrion',
#        'Myopathy', 'Synovial sarcoma', 'colon cancer upregulated',
#        'renal cancer deregulated', 'apical part of cell GO0045177',
#        'Familial ovarian cancer', 'Familiar ovarian carcinoma',
#        'Her2-receptor positive breast cancer',
#        'Progesterone-receptor negative breast cancer',
#        'Hypertrophic cardiomyopathy',
#        'Cytokine-cytokine receptor interaction',
#        'neutrophil chemotaxis GO0030593', 'Thyroid hormone synthesis',
#        'lipid droplet GO0005811',
#        'nuclear retinoid X receptor binding GO0046965', 'Renin secretion',
#        '2-methylacyl-CoA dehydrogenase activity GO0003853',
#        'AP-1 adaptor complex binding GO0035650',
#        'AP-3 adaptor complex binding GO0035651',
#        'BAT3 complex binding GO1904288',
#        'BLOC-2 complex binding GO0036461',
#        'C-X-C chemokine binding GO0019958',
#        'DNA geometric change GO0032392',
#        'DNA topological change GO0006265',
#        'GPI-anchor transamidase complex GO0042765',
#        'N-acetylglucosaminyl-proteoglycan 4-beta-glucuronosyltransferase activity GO0050509',
#        'RAGE receptor binding GO0050786',
#        'T-helper 1 cell activation GO0035711',
#        'T-helper 1 cell differentiation GO0045063',
#        'VDJ recombination GO0033151',
#        'acyl-CoA dehydrogenase activity GO0003995',
#        'alphav-beta3 integrin-HMGB1 complex GO0035868',
#        'angiostatin binding GO0043532',
#        'cellular response to misfolded protein GO0071218',
#        'epithelial cilium movement involved in determination of leftright asymmetry GO0060287',
#        'error-free translesion synthesis GO0070987',
#        'glucuronosyl-N-acetylglucosaminyl-proteoglycan 4-alpha-N-acetylglucosaminyltransferase activity GO0050508',
#        'heparan sulfate N-acetylglucosaminyltransferase activity GO0042328',
#        'histone pre-mRNA 3end processing complex GO0071204',
#        'inorganic cation transmembrane transport GO0098662',
#        'isoleucine catabolic process GO0006550',
#        'kinesin I complex GO0016938',
#        'large ribosomal subunit rRNA binding GO0070180',
#        'metal ion transport GO0030001',
#        'mitochondrial proton-transporting ATP synthase, catalytic core GO0005754',
#        'mitochondrial proton-transporting ATP synthase complex GO0005753',
#        'myelin assembly GO0032288',
#        'myeloid dendritic cell activation GO0001773',
#        'negative regulation of apoptotic cell clearance GO2000426',
#        'neuroblast differentiation GO0014016',
#        'neutrophil clearance GO0097350',
#        'peptidyl-proline hydroxylation to 3-hydroxy-L-proline GO0018400',
#        'phospholipid efflux GO0033700',
#        'positive regulation of centriole elongation GO1903724',
#        'positive regulation of centrosome duplication GO0010825',
#        'positive regulation of cilium assembly GO0045724',
#        'positive regulation of dendritic cell differentiation GO2001200',
#        'positive regulation of establishment of protein localization GO1904951',
#        'positive regulation of microglial cell activation GO1903980',
#        'positive regulation of mismatch repair GO0032425',
#        'positive regulation of nucleic acid-templated transcription GO1903508',
#        'positive regulation of sodium ion transmembrane transporter activity GO2000651',
#        'positive regulation of toll-like receptor 9 signaling pathway GO0034165',
#        'protein insertion into mitochondrial membrane GO0051204',
#        'protein localization to cytosolic proteasome complex involved in ERAD pathway GO1904379',
#        'proton-transporting ATP synthase activity, rotational mechanism GO0046933',
#        'proton-transporting ATP synthase complex, catalytic core F1 GO0045261',
#        'proton-transporting ATP synthase complex GO0045259',
#        'proton motive force-driven ATP synthesis GO0015986',
#        'pyramidal neuron migration to cerebral cortex GO0021852',
#        'regulation of B cell proliferation GO0030888',
#        'regulation of SREBP signaling pathway GO2000638',
#        'regulation of T cell mediated immune response to tumor cell GO0002840',
#        'regulation of monoatomic ion transmembrane transport GO0034765',
#        'regulation of neuroblast proliferation GO1902692',
#        'regulation of protein sumoylation GO0033233',
#        'regulation of restriction endodeoxyribonuclease activity GO0032072',
#        'regulation of tolerance induction GO0002643',
#        'serine C-palmitoyltransferase activity GO0004758',
#        'serine C-palmitoyltransferase complex GO0017059',
#        'short-branched-chain-acyl-CoA dehydrogenase activity GO0016937',
#        'vacuolar proton-transporting V-type ATPase complex assembly GO0070072',
#        'ACADSB', 'AMFR', 'ARHGAP18', 'ATP1B4', 'ATP5A1', 'ATXN3',
#        'CCDC149', 'CDC5L', 'CDCP1', 'CEP120', 'COX18', 'CRTAP', 'DCAF8',
#        'DNAJC24', 'EGFLAM', 'EXT1', 'FAM19A3', 'HMGB1', 'ING1', 'KLC2',
#        'KLHDC10', 'LONRF2', 'PIGS', 'PMP22', 'PNMA8A', 'POLDIP2',
#        'PRR5-ARHGAP8', 'RAB32', 'RABGEF1', 'RPL12', 'SIGLEC9', 'TM6SF2',
#        'VMA21', 'WNK2', 'ZMIZ1', 'ZNF543', 'RP11-217B1.2', 'RP4-561L24.3',
#        'cyclosporin A binding GO0016018',
#        'glycosaminoglycan biosynthetic process GO0006024',
#        'organic anion transmembrane transporter activity GO0008514',
#        'positive regulation of ATP-dependent activity GO0032781',
#        'positive regulation of activated T cell proliferation GO0042104',
#        'positive regulation of mitochondrial translation GO0070131',
#        'positive regulation of mitotic cell cycle GO0045931',
#        'positive regulation of receptor-mediated endocytosis GO0048260',
#        'regulation of protein ubiquitination GO0031396',
#        'P-body assembly GO0033962',
#        'Roundabout signaling pathway GO0035385',
#        'endopeptidase activator activity GO0061133',
#        'endothelial tube lumen extension GO0097498',
#        'insulin-like growth factor receptor signaling pathway GO0048009',
#        'membrane protein intracellular domain proteolysis GO0031293',
#        'polyA binding GO0008143',
#        'regulation of synaptic transmission, glutamatergic GO0051966',
#        'plasma membrane repair GO0001778',
#        'positive regulation of cellular extravasation GO0002693',
#        'receptor clustering GO0043113',
#        'type I transforming growth factor beta receptor binding GO0034713',
#        'mRNA 3-UTR AU-rich region binding GO0035925',
#        'DNA-binding transcription activator activity, RNA polymerase II-specific GO0001228',
#        'cell surface GO0009986', 'endocytic vesicle lumen GO0071682',
#        'establishment of cell polarity GO0030010',
#        'positive regulation of innate immune response GO0045089',
#        'positive regulation of lipase activity GO0060193',
#        'stem cell differentiation GO0048863',
#        'stress granule assembly GO0034063',
#        'Other types of O-glycan biosynthesis',
#        'Transcriptional misregulation in cancer',
#        'membrane fission GO0090148',
#        'Notch receptor processing GO0007220',
#        'RNA polymerase II, core complex GO0005665',
#        'RNA polymerase II activity GO0001055',
#        'amyloid precursor protein catabolic process GO0042987',
#        'barbed-end actin filament capping GO0051016',
#        'calcium-ion regulated exocytosis GO0017156',
#        'cellular response to estrogen stimulus GO0071391',
#        'cytokine binding GO0019955',
#        'establishment of Golgi localization GO0051683',
#        'establishment of epithelial cell polarity GO0090162',
#        'guanyl-nucleotide exchange factor complex GO0032045',
#        'hippocampus development GO0021766', 'inclusion body GO0016234',
#        'late endosome to vacuole transport via multivesicular body sorting pathway GO0032511',
#        'maintenance of blood-brain barrier GO0035633',
#        'microtubule plus-end GO0035371',
#        'mitral valve morphogenesis GO0003183',
#        'negative regulation of ATP-dependent activity GO0032780',
#        'negative regulation of exocytosis GO0045920',
#        'neuron remodeling GO0016322',
#        'oligosaccharide biosynthetic process GO0009312',
#        'phosphatidylinositol phosphate binding GO1901981',
#        'positive regulation of lipid storage GO0010884',
#        'protein localization to microtubule GO0035372',
#        'receptor signaling pathway via JAK-STAT GO0007259', 'YIPF4',
#        'negative regulation of neuron projection development GO0010977',
#        'BBSome GO0034464',
#        'NLS-dependent protein nuclear import complex GO0042564',
#        'intermediate filament GO0005882',
#        'intracellular oxygen homeostasis GO0032364',
#        'negative regulation of T cell activation GO0050868',
#        'positive regulation of viral budding via host ESCRT complex GO1903774',
#        'regulation of CD8-positive, alpha-beta T cell proliferation GO2000564'],
#       dtype=object)

# %%
gc['SuperPath Name'].unique()
# Out:
# array(['Signal Transduction', 'Metabolism of Proteins',
#        'Infectious Disease', 'Innate Immune System',
#        'Gene Expression (Transcription)',
#        'Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation',
#        'Cellular Responses to Stimuli', 'Cell Cycle, Mitotic',
#        'RNA Polymerase I Promoter Opening', 'Cellular Senescence',
#        'Signaling By Rho GTPases', 'Prolactin Signaling',
#        'Vesicle-mediated Transport',
#        'Processing of Capped Intron-Containing Pre-mRNA',
#        'Deubiquitination', 'Gene Silencing By RNA',
#        'Sertoli-Sertoli Cell Junction Dynamics', 'ERK Signaling',
#        'Apoptotic Pathways in Synovial Fibroblasts',
#        'MAPK Family Signaling Cascades',
#        'Cytokine Signaling in Immune System',
#        'Nervous System Development', 'DNA Damage',
#        'Chromatin Regulation / Acetylation', 'ESR-mediated Signaling',
#        'Transport of The SLBP Independent Mature MRNA',
#        'Signaling By Receptor Tyrosine Kinases', 'Cytoskeletal Signaling',
#        'SARS-CoV-2 Infection', 'Pleural Mesothelioma',
#        'Mitotic G1 Phase and G1/S Transition', 'Cell Cycle Checkpoints',
#        'HCMV Infection',
#        'Class I MHC Mediated Antigen Processing and Presentation',
#        'Assembly of The Pre-replicative Complex',
#        'Homology Directed Repair', 'Endometrial Cancer',
#        'Pre-NOTCH Expression and Processing', 'Metabolism',
#        'Chromatin Organization', 'CKAP4 Signaling Pathway Map',
#        'Signaling Events Mediated By HDAC Class I', 'MAPK-Erk Pathway',
#        'Toll-like Receptor Signaling Pathway', 'MAP Kinase Signaling',
#        'Angiopoietin-like Protein 8 Regulatory Pathway',
#        'Packaging Of Telomere Ends', 'GPCR Pathway',
#        'Influenza Infection', 'Autophagy Pathway',
#        'Regulation of TP53 Activity', 'TGF-Beta Pathway', 'Cell Cycle',
#        'Development VEGF Signaling Via VEGFR2 - Generic Cascades',
#        'Signaling By WNT',
#        'Validated Targets of C-MYC Transcriptional Activation',
#        'Hepatocyte Growth Factor Receptor Signaling',
#        'E2F Transcription Factor Network', 'PIP3 Activates AKT Signaling',
#        'NFAT and Cardiac Hypertrophy', 'Translational Control',
#        'IL-1 Family Signaling Pathways', 'P70S6K Signaling',
#        'Senescence and Autophagy in Cancer', 'Neuroscience',
#        'PDGFR-beta Signaling Pathway', 'Peptide Chain Elongation',
#        'Cell Cycle Regulation of G1/S Transition (part 1)',
#        'Apoptosis and Autophagy',
#        'ADORA2B Mediated Anti-inflammatory Cytokines Production',
#        'Regulation of Actin Dynamics For Phagocytic Cup Formation',
#        'Activation of The Pre-replicative Complex',
#        'Cytoskeleton Remodeling Regulation of Actin Cytoskeleton By Rho GTPases',
#        'MAPK Signaling: Mitogens',
#        'Development Ligand-independent Activation of ESR1 and ESR2',
#        'Programmed Cell Death', 'MAPK Signaling Pathway',
#        'Development IGF-1 Receptor Signaling', 'Akt Signaling',
#        'P73 Transcription Factor Network',
#        'Rab Regulation of Trafficking',
#        'Cellular Response to Heat Stress', 'CNTF Signaling',
#        'PKMTs Methylate Histone Lysines', 'VEGFA-VEGFR2 Signaling',
#        'Chromosome Maintenance', 'Integrated Breast Cancer Pathway',
#        'DNA Double Strand Break Response', 'Semaphorin Interactions',
#        'Small Cell Lung Cancer', 'TNFR1 Pathway',
#        'Oncogene Induced Senescence',
#        'DNA Damage Response (only ATM Dependent)',
#        'Development Endothelin-1/EDNRA Transactivation of EGFR',
#        'EPH-Ephrin Signaling', 'Wnt / Hedgehog / Notch',
#        'Gastrin Signaling Pathway', 'Integrin-mediated Cell Adhesion',
#        'Retinoblastoma Gene in Cancer',
#        'Smith-Magenis and Potocki-Lupski Syndrome Copy Number Variation',
#        'Metabolic Reprogramming in Colon Cancer',
#        'Signaling By ALK in Cancer',
#        'MiRNA Regulation of DNA Damage Response',
#        'Chks in Checkpoint Regulation', 'TCR Signaling (Qiagen)',
#        'MAPK Signaling: Oxidative Stress', 'Focal Adhesion',
#        'FMLP Pathway', 'Hepatitis C and Hepatocellular Carcinoma',
#        'Meiosis', 'Regulation of Expression of SLITs and ROBOs',
#        'DNA IR-damage and Cellular Response Via ATR', 'G0 and Early G1',
#        'AP-1 Transcription Factor Network',
#        'Corticotropin-releasing Hormone Signaling Pathway',
#        'Nuclear Events (kinase and Transcription Factor Activation)',
#        'DREAM Repression and Dynorphin Expression',
#        'Defective Binding of RB1 Mutants to E2F1,(E2F2, E2F3)',
#        'TGF-beta Signaling Pathways', 'Toll Comparative Pathway',
#        'Beta-Adrenergic Signaling', 'HIV Life Cycle',
#        'PI3K-Akt Signaling Pathway', 'Glucose / Energy Metabolism',
#        'Development Slit-Robo Signaling',
#        'Ovarian Tumor Domain Proteases', 'Clathrin-mediated Endocytosis',
#        'GDNF Signaling', 'MET Promotes Cell Motility', 'PAK Pathway',
#        'Cell Junction Organization', 'Breast Cancer Pathway',
#        'Nanog in Mammalian ESC Pluripotency', 'FLT3 Signaling in Disease',
#        'Nuclear Events Mediated By NFE2L2', 'Signaling By NTRKs',
#        'CCL18 Signaling Pathway',
#        'Immune Response_IL-6 Signaling Pathway', 'NGF Pathway',
#        'WtCFTR and Delta508-CFTR Traffic / Generic Schema (norm and CF)',
#        'Regulation of Actin Cytoskeleton', 'Acute Viral Myocarditis',
#        'Oncogenic MAPK Signaling',
#        '7q11.23 Copy Number Variation Syndrome',
#        'DYRK1A Involvement Regarding Cell Proliferation in Brain Development',
#        'P75 NTR Receptor-mediated Signalling',
#        'Transcription Androgen Receptor Nuclear Signaling',
#        'Guidance Cues and Growth Cone Motility', 'TNF Signaling',
#        'Signaling By ERBB2', 'RRNA Processing in The Nucleus and Cytosol',
#        'Death Receptor Signaling Pathway', 'Regulation of Telomerase',
#        'Transport to The Golgi and Subsequent Modification',
#        'Androgen Receptor Network in Prostate Cancer',
#        'Head and Neck Squamous Cell Carcinoma',
#        'TP53 Regulates Metabolic Genes',
#        'Apoptosis-related Network Due to Altered Notch3 in Ovarian Cancer',
#        'EPHA-mediated Growth Cone Collapse', 'RAB Geranylgeranylation',
#        'Bladder Cancer', 'Beta-2 Adrenergic-dependent CFTR Expression',
#        'Jak-Stat Signaling Pathway',
#        'NcRNAs Involved in Wnt Signaling in Hepatocellular Carcinoma',
#        'Integrin Pathway', 'Nuclear Receptors Meta-pathway',
#        'Loss of Proteins Required For Interphase Microtubule Organization From The Centrosome',
#        'Development Dopamine D2 Receptor Transactivation of EGFR',
#        'C-MYB Transcription Factor Network',
#        'Signaling Events Mediated By Hepatocyte Growth Factor Receptor (c-Met)',
#        'Development FGFR Signaling Pathway',
#        'Signaling By TGFB Family Members',
#        'Ebola Virus Infection in Host', 'Colorectal Cancer Metastasis',
#        'Cell Cycle Role of 14-3-3 Proteins in Cell Cycle Regulation',
#        'Aryl Hydrocarbon Receptor Pathway', 'RhoGDI Pathway',
#        'MRNA Splicing - Minor Pathway',
#        'Cyclins and Cell Cycle Regulation',
#        'Integrin-linked Kinase Signaling',
#        'Microtubule Cytoskeleton Regulation',
#        'P38 MAPK Signaling Pathway (WikiPathways)', 'Spinal Cord Injury',
#        'Stabilization and Expansion of The E-cadherin Adherens Junction',
#        'Signaling By EGFR', 'Intrinsic Pathway For Apoptosis',
#        '5q35 Copy Number Variation',
#        'Translation Insulin Regulation of Translation',
#        'CCR5 Pathway in Macrophages',
#        'Regulation of CDH11 Expression and Function',
#        'RHOBTB GTPase Cycle',
#        'Apoptosis and Survival BAD Phosphorylation',
#        'Regulation of RUNX1 Expression and Activity',
#        'IL2 Signaling Events Mediated By STAT5',
#        'HIF-1-alpha Transcription Factor Network',
#        'Glycolysis (REACTOME)', 'IL-9 Signaling Pathways',
#        'Direct P53 Effectors',
#        'Interleukin-4 and Interleukin-13 Signaling',
#        'Apoptosis and Survival FAS Signaling Cascades',
#        'Sudden Infant Death Syndrome (SIDS) Susceptibility Pathways',
#        'Activation of AMPK Downstream of NMDARs',
#        'MyD88 Dependent Cascade Initiated on Endosome',
#        'Development EGFR Signaling Pathway',
#        'TP53 Regulates Transcription of Cell Cycle Genes',
#        'Immune Response IL-2 Activation and Signaling Pathway',
#        'Immune Response_Role of Integrins in NK Cells Cytotoxicity',
#        'Integrins in Angiogenesis', 'CXCR4-mediated Signaling Events',
#        'GADD45 Pathway', 'Response to Elevated Platelet Cytosolic Ca2+',
#        'Immune Response IL-23 Signaling Pathway',
#        'FOXM1 Transcription Factor Network', 'CD28 Co-stimulation',
#        'EML4 and NUDC in Mitotic Spindle Formation',
#        'Separation of Sister Chromatids',
#        'Development Angiotensin Activation of ERK',
#        'NF-KappaB Family Pathway', 'NF-kappaB Signaling',
#        'Epithelial to Mesenchymal Transition in Colorectal Cancer',
#        'APC-Cdc20 Mediated Degradation of Nek2A',
#        'Mesodermal Commitment Pathway',
#        'Activated TAK1 Mediates P38 MAPK Activation',
#        'Regulation of TP53 Expression and Degradation',
#        'Thromboxane Signalling Through TP Receptor', 'Signaling By PTK6',
#        'Immune Response_IFN Gamma Signaling Pathway',
#        "Alzheimer's Disease and MiRNA Effects",
#        'P38 Signaling Mediated By MAPKAP Kinases', 'P53 Pathway',
#        'TGF-beta Receptor Signaling',
#        'Cooperation of Prefoldin and TriC/CCT in Actin and Tubulin Folding',
#        'P53 Signaling', 'Uptake and Actions of Bacterial Toxins',
#        'Metabolic Reprogramming in Pancreatic Cancer',
#        'Actin Nucleation By ARP-WASP Complex',
#        'MIF Mediated Glucocorticoid Regulation',
#        'G12-G13 in Cellular Signaling', 'VEGF Signaling Pathway',
#        'Transcriptional Activity of SMAD2/SMAD3:SMAD4 Heterotrimer',
#        'ATM Pathway', 'G-protein Signaling RAC1 in Cellular Process',
#        'EphB-EphrinB Signaling', 'Netrin-1 Signaling',
#        'DNA Damage Induced 14-3-3Sigma Signaling',
#        'Regulation of Nuclear SMAD2/3 Signaling',
#        'Golgi-to-ER Retrograde Transport',
#        'NR1H2 and NR1H3-mediated Signaling',
#        'Transport of Mature Transcript to Cytoplasm',
#        'RAF-independent MAPK1/3 Activation', 'RAC2 GTPase Cycle',
#        'Transport of Inorganic Cations/anions and Amino Acids/oligopeptides',
#        'Apoptotic Cleavage of Cellular Proteins',
#        'TCR Signaling (REACTOME)', 'Syndecan-4-mediated Signaling Events',
#        'Acute Myeloid Leukemia',
#        'Microglia Pathogen Phagocytosis Pathway',
#        'Nucleotide-binding Domain, Leucine Rich Repeat Containing Receptor (NLR) Signaling Pathways',
#        'Adipogenesis', 'DNA Damage_ATM/ATR Regulation of G1/S Checkpoint',
#        'Interleukin-11 Signaling Pathway',
#        'Overlap Between Signal Transduction Pathways Contributing to LMNA Laminopathies',
#        'Antiviral Mechanism By IFN-stimulated Genes',
#        'NRP1-triggered Signaling Pathways in Pancreatic Cancer',
#        'Sphingolipid Metabolism', 'Glycolysis (BioCyc)',
#        'CCR3 Pathway in Eosinophils', 'Interleukin-1 Family Signaling'],
#       dtype=object)

# %%
overlap = miEAA.merge(gc, left_on='Subcategory', right_on='SuperPath Name')
overlap.head()
# Out:
#                    Category                      Subcategory Enrichment  \
# 0  WikiPathways (miRPathDB)                       Cell Cycle   enriched
# 1  WikiPathways (miRPathDB)    Mesodermal Commitment Pathway   enriched
# 2      Reactome (miRPathDB)           Cell Cycle Checkpoints   enriched
# 3      Reactome (miRPathDB)              Signal Transduction   enriched
# 4  WikiPathways (miRPathDB)  Integrin-mediated Cell Adhesion   enriched
#
#     P-value  P-adjusted   Q-value  Observed  \
# 0  0.006669    0.006669  0.266763         5
# 1  0.015152    0.015152  0.418301         2
# 2  0.026782    0.026782  0.458347         5
# 3  0.028283    0.028283  0.458347         2
# 4  0.028283    0.028283  0.418301         2
#
#                                    miRNAs/precursors   Score  \
# 0  hsa-miR-6802-5p; hsa-miR-6729-5p; hsa-miR-6800...   24.44
# 1                   hsa-miR-6802-5p; hsa-miR-6800-5p   11.81
# 2  hsa-miR-6802-5p; hsa-miR-6729-5p; hsa-miR-663a...   31.67
# 3                      hsa-miR-6802-5p; hsa-miR-663a  166.10
# 4                      hsa-miR-6802-5p; hsa-miR-663a   18.52
#
#                     SuperPath Name  # SuperPath Total Genes  \
# 0                       Cell Cycle                      137
# 1    Mesodermal Commitment Pathway                      146
# 2           Cell Cycle Checkpoints                      292
# 3              Signal Transduction                     2597
# 4  Integrin-mediated Cell Adhesion                      140
#
#    # SuperPath Matched Genes  \
# 0                         47
# 1                         38
# 2                         86
# 3                        559
# 4                         43
#
#                              Matched Genes (Symbols)  \
# 0  WEE1, CCNA2, CCNB1, CCND1, CCND2, MDM2, MYC, C...
# 1  AXIN1, EXT1, CCND1, KLF4, DIP2A, ELK4, CSRP2, ...
# 2  RANBP2, TOP3A, BRCA1, NUP43, WEE1, CCNA2, CCNB...
# 3  MUC20, ARL2, MAP2K2, DGKH, ARL4C, PTK6, NHS, C...
# 4  MAP2K2, MAP2K3, CAPN6, CAPNS1, MAP2K7, MAP3K2,...
#
#                                         Evidence URL
# 0    https://pathcards.genecards.org/card/cell_cycle
# 1  https://pathcards.genecards.org/card/mesoderma...
# 2  https://pathcards.genecards.org/card/cell_cycl...
# 3  https://pathcards.genecards.org/card/signal_tr...
# 4  https://pathcards.genecards.org/card/integrin-...
