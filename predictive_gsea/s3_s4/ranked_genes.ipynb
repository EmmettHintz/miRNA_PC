# %%
import pandas as pd

# %%
ranked_features = pd.read_csv('./miRNA_disease_ranked.csv')
gene_targets = pd.read_csv('./s3_s4_genes.csv')

# %%
ranked_features['miRNA_rank'] = ranked_features['Importance'].rank()
miRNA_ranks = ranked_features['miRNA_rank'].to_dict()

# %%
total_miRNA = len(ranked_features)

# %% [markdown]
# *Formula*:
# score_gene= 1/t∑_{i=1}^{t}(1−rank_{miRNA}^{i}/total_{miRNA})
#
# *Explanation*
# - t: the number of miRNAs that target the gene
# - rank_{miRNA}^{i}: the rank of miRNA i that targets the gene
# - total_{miRNA}: the total number of miRNAs that target the gene
#
# ***High Gene Score***:
# - Indicates that the gene interacts with miRNAs that are highly ranked (i.e., have a low padj value).
# - A high score suggests that the gene is likely to be regulated by miRNAs that are significant in the context of differential expression analysis.
# - Thus, genes with high scores are potentially more important or relevant to the biological conditions being studied.
#
# ***Low Gene Score***:
# - Indicates that the gene interacts with miRNAs that are lower ranked (i.e., have a higher padj value).
# - A low score suggests that the gene is less likely to be regulated by significant miRNAs.
# - Such genes may be of lower priority for further investigation.

# %%
def calculate_gene_score(row, miRNA_ranks, total_miRNA):
    total_interactions = 0
    score = 0
    for miRNA in row.index[4:]:  # Assuming the miRNAs start from the 5th column
        if pd.notna(row[miRNA]) and row[miRNA] in miRNA_ranks:
            rank = miRNA_ranks[row[miRNA]]
            score += (1 - (rank / total_miRNA))
            total_interactions += 1
    if total_interactions > 0:
        return score / total_interactions
    else:
        return 0

# %%
gene_targets['gene_score'] = gene_targets.apply(calculate_gene_score, axis=1, miRNA_ranks=miRNA_ranks, total_miRNA=total_miRNA)

# Sort genes based on their scores in descending order
ranked_genes = gene_targets.sort_values(by='gene_score', ascending=False)

# Reorder columns so that 'gene_score' is the second column
columns = ['Gene Symbol', 'gene_score'] + [col for col in ranked_genes.columns if col not in ['Gene Symbol', 'gene_score']]
ranked_genes = ranked_genes[columns]


# Save ranked genes to a CSV file
ranked_genes.to_csv('ranked_genes.csv', index=False)

print(ranked_genes.shape)
# Display top ranked genes
print(ranked_genes.head(10))
# Out:
# (2669, 13)
#      Gene Symbol  gene_score  p-value   FDR  Odd ratio  \
# 492       GIGYF1    0.134615   0.0095  0.61      0.359
# 1410       TXNIP    0.115385   0.0220  0.61      0.380
# 1369      TNRC6B    0.115385   0.0123  0.61      0.335
# 837         NFIC    0.115385   0.0431  0.61      0.444
# 703        LMNB2    0.115385   0.0233  0.61      0.385
# 1470       YWHAZ    0.096154   0.0552  0.61      0.424
# 456        FOXK1    0.096154   0.1100  0.61      0.518
# 1123       SBNO1    0.096154   0.0132  0.61      0.292
# 712       LRRC58    0.096154   0.0438  0.61      0.398
# 766         MIDN    0.096154   0.0609  0.61      0.436
#
#       Number of interactions        microRNA 1        microRNA 2  \
# 492                        7   hsa-miR-6734-3p      hsa-miR-4516
# 1410                       6   hsa-miR-520d-3p      hsa-miR-3975
# 1369                       6  hsa-miR-29b-1-5p  hsa-miR-6715b-5p
# 837                        6   hsa-miR-4727-5p   hsa-miR-6756-5p
# 703                        6   hsa-miR-6735-5p   hsa-miR-5582-5p
# 1470                       5  hsa-miR-6769b-5p   hsa-miR-6756-5p
# 456                        5   hsa-miR-548h-5p   hsa-miR-520d-3p
# 1123                       5       hsa-miR-922   hsa-miR-520d-3p
# 712                        5      hsa-miR-4516      hsa-miR-1205
# 766                        5  hsa-miR-548ah-5p   hsa-miR-6735-5p
#
#             microRNA 3        microRNA 4        microRNA 5        microRNA 6  \
# 492    hsa-miR-6735-5p  hsa-miR-6769b-5p  hsa-miR-548ah-5p   hsa-miR-520d-3p
# 1410   hsa-miR-6735-5p  hsa-miR-29b-1-5p      hsa-miR-4511  hsa-miR-548ah-5p
# 1369   hsa-miR-6756-5p   hsa-miR-520d-3p      hsa-miR-4511   hsa-miR-6734-3p
# 837       hsa-miR-1205      hsa-miR-3975      hsa-miR-4516   hsa-miR-6815-5p
# 703       hsa-miR-1205      hsa-miR-378c      hsa-miR-3975   hsa-miR-6756-5p
# 1470  hsa-miR-548ah-5p    hsa-miR-134-3p      hsa-miR-4516               NaN
# 456     hsa-miR-134-3p  hsa-miR-548ah-5p  hsa-miR-6715b-5p               NaN
# 1123      hsa-miR-1205      hsa-miR-4516   hsa-miR-6735-5p               NaN
# 712    hsa-miR-5582-5p  hsa-miR-6715b-5p   hsa-miR-520d-3p               NaN
# 766   hsa-miR-6715b-5p   hsa-miR-6756-5p  hsa-miR-6769b-5p               NaN
#
#            microRNA 7
# 492   hsa-miR-6756-5p
# 1410              NaN
# 1369              NaN
# 837               NaN
# 703               NaN
# 1470              NaN
# 456               NaN
# 1123              NaN
# 712               NaN
# 766               NaN

# %%
# get top 50 genes
top_genes = ranked_genes.iloc[:,1].tolist()
# print the row and the score as a string on a new line
for i in range(1001):
    if str(top_genes[i]) != 'nan':
        # print(ranked_genes.iloc[i,0], ranked_genes.iloc[i,1], sep = '\t')
        print(ranked_genes.iloc[i,0])
# Out:
# GIGYF1
# TXNIP
# TNRC6B
# NFIC
# LMNB2
# YWHAZ
# FOXK1
# SBNO1
# LRRC58
# MIDN
# GLO1
# ULK1
# UNC5B
# YIPF4
# DGAT2
# ZBTB33
# MAP3K2
# ATP5A1
# FEM1A
# FGFR1OP
# KIAA1191
# KIAA0513
# MAFK
# TRAF6
# UBE2H
# IGF1R
# REST
# RAB5B
# CRY2
# RUFY2
# PTBP1
# SELENON
# SF3B3
# DNAJC10
# PAFAH1B2
# PABPN1
# ORAI2
# NUDT3
# TAOK1
# ELFN2
# NFIX
# CDKN1A
# C16orf58
# AGO2
# ACOX1
# ABI2
# HMGN2
# CCNT1
# ACACA
# NEK7
# NFIB
# CAPZA2
# TAF1D
# SYT7
# DSN1
# STAT3
# NUCB1
# NUMBL
# C6orf223
# NUP62
# CCDC198
# SPRY4
# CCDC80
# DUSP2
# NACC2
# ENPP5
# PEA15
# MINK1
# HIST2H2BE
# UBXN2A
# FAM102B
# UBE2G1
# C10orf76
# C11orf54
# F2RL3
# TSR1
# TRIOBP
# TMEM184A
# MKNK2
# TP53
# MLLT1
# MNT
# C18orf32
# TMEM241
# C2orf48
# TMEM214
# SLC6A4
# GATA6
# MEX3A
# DCAF7
# ZNF460
# SBF1
# PTPN14
# SAMD8
# PVR
# RPRD2
# RPL17-C18orf32
# CRK
# CSTF2
# HRK
# COX10
# CLOCK
# CCDC117
# ITM2C
# AMDHD2
# CALU
# LRP10
# MBNL3
# MIGA2
# NUP98
# CADM2
# PKNOX1
# C3orf36
# BCL2L2-PABPN1
# PLPP3
# ATG2A
# VDR
# UGT2B4
# RBM8A
# DEGS1
# SESN1
# SERTAD2
# SERINC1
# DDR2
# SEPT2
# SEMA7A
# SEC14L4
# RUNX3
# RPS24
# RPL24
# RNPS1
# RNF41
# TTC39B
# RHOBTB3
# FADS1
# RGS9BP
# FN3K
# GXYLT1
# KIAA1586
# KIF2C
# MANEAL
# REEP4
# MAP1B
# RDH13
# ANKRD11
# CSNK1E
# SLC43A3
# ANKH
# ANKMY1
# TPI1
# TRIM44
# TRMT5
# TMEM30B
# TM4SF5
# ALS2CL
# ZBED3
# TIMELESS
# THAP6
# TFPI
# ZNF275
# TFAP2A
# ZNF770
# TFAM
# B3GALNT2
# TBCCD1
# SYNGR1
# SUCO
# STMN1
# CLIP1
# SPC25
# SOWAHC
# ANKRD50
# GOLGA7B
# AKAP2
# BACH2
# CTXN1
# CPSF7
# CPEB3
# COIL
# CMPK1
# CHEK1
# CEBPB
# CD209
# APLP2
# C16orf72
# C16orf70
# BTBD19
# BDP1
# BCL7B
# B4GALT5
# DLGAP3
# APEX1
# APAF1
# ZFYVE9
# ZBED1
# USP46
# UBE2D1
# TM9SF4
# SNX5
# NAP1L1
# MTMR6
# MCM7
# KCTD10
# INIP
# INHBA
# DGKE
# DPYSL2
# PNMA8B
# HOXC4
# P4HB
# NLGN4X
# NEUROD2
# MSRB2
# MID1IP1
# MCUR1
# MAP2K1
# M6PR
# LRCH3
# LIN52
# KIAA1841
# KCNA7
# JPH2
# ITGB1
# HIST2H2AA3
# APLN
# HIST1H3B
# HIST1H2BK
# H1F0
# GTF2H2C
# GRID1
# GPATCH8
# GP5
# GMPS
# GCNT3
# G2E3
# ELOC
# ELK1
# EIF4EBP1
# DUSP4
# HAVCR1
# APPL1
# EPB41
# GTF2H3
# MFSD2A
# MCM9
# MAPKAPK2
# MAP2K3
# MAN2B2
# LRRC40
# ARID4B
# KIAA0895L
# KCND3
# IL2RA
# IKZF5
# IGSF6
# HPRT1
# HES6
# GON7
# DDX19A
# GNB5
# GNAI2
# FAM46A
# ERN1
# EIF2S1
# EHD3
# DTWD2
# DNAJB14
# DDB1
# CNDP1
# CLEC2D
# CENPQ
# CCL5
# CCDC30
# NAB2
# NPFFR1
# NXN
# ARID2
# CAB39
# BUB3
# BCL2L12
# ABHD5
# ARC
# ZNF800
# ARHGAP40
# ARHGAP42
# XKR7
# WRN
# VASH1
# USP48
# UMPS
# TMEM151A
# SYNRG
# SRGAP1
# ARHGEF12
# SNAP29
# SMIM13
# SMARCE1
# SLAIN2
# SERAC1
# SEC22C
# SCARF1
# ARHGEF37
# RAI1
# PTCD3
# PPP3R1
# PPIL1
# PACSIN1
# POLR3F
# AK2
# ZADH2
# FNBP1L
# EFNA5
# EDN1
# DIS3L
# ANKRD65
# CRNKL1

# %%
# Save genes and gene score columns to csv
ranked_genes[['Gene Symbol', 'gene_score']].to_csv('final_ranked_genes.csv', index=False)
