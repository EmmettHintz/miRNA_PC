# %%
import pandas as pd

# %%
miEAA = pd.read_csv('./s1_s2_mieAA.csv')
print(miEAA.columns)
# Out:
# Index(['Category', 'Subcategory', 'Enrichment', 'P-value', 'P-adjusted',
#        'Q-value', 'Observed', 'miRNAs/precursors'],
#       dtype='object')

# %%
# Print unique categories
print(miEAA['Category'].unique())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)' 'Pathways (KEGG)'
#  'Target genes (miRTarBase)' 'Expressed in tissue (Tissue Atlas)'
#  'GO Molecular function (miRPathDB)']

# %%
gc = pd.read_csv('./s1_s2_gc.csv')
gc.columns
# Out:
# Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')

# %%
miEAA.head()
# Out:
#                                             Category  \
# 0  Annotations derived over miRTarBase (Gene Onto...
# 1  Annotations derived over miRTarBase (Gene Onto...
# 2  Annotations derived over miRTarBase (Gene Onto...
# 3  Annotations derived over miRTarBase (Gene Onto...
# 4                                    Pathways (KEGG)
#
#                                         Subcategory Enrichment   P-value  \
# 0       transcription corepressor binding GO0001222   depleted  0.000333
# 1                   alpha-tubulin binding GO0043014   depleted  0.002997
# 2                    beta-tubulin binding GO0048487   depleted  0.002997
# 3  positive regulation of GTPase activity GO0043547   depleted  0.002997
# 4                                            Glioma   depleted  0.006527
#
#    P-adjusted   Q-value  Observed  \
# 0    0.000333  0.488152         5
# 1    0.002997  0.488152         6
# 2    0.002997  0.488152         6
# 3    0.002997  0.488152         6
# 4    0.006527  0.515387         8
#
#                                    miRNAs/precursors
# 0  hsa-miR-4472; hsa-miR-139-3p; hsa-miR-4647; hs...
# 1  hsa-miR-6769b-5p; hsa-miR-4472; hsa-miR-139-3p...
# 2  hsa-miR-6769b-5p; hsa-miR-4472; hsa-miR-139-3p...
# 3  hsa-miR-6895-3p; hsa-miR-4472; hsa-miR-139-3p;...
# 4  hsa-miR-548h-5p; hsa-miR-937-5p; hsa-miR-4439;...

# %%
gc.head()
# Out:
#    Score                                     SuperPath Name  \
# 0  49.83                    Gene Expression (Transcription)
# 1  33.16                                 Infectious Disease
# 2  32.47  Regulation of Activated PAK-2p34 By Proteasome...
# 3  31.17                                Signal Transduction
# 4  30.74                      Cellular Responses to Stimuli
#
#    # SuperPath Total Genes  # SuperPath Matched Genes  \
# 0                     1543                        161
# 1                     1818                        163
# 2                      943                        100
# 3                     2597                        212
# 4                      819                         89
#
#                              Matched Genes (Symbols)  \
# 0  LRPPRC, ZNF154, HAND2, POLR1B, DR1, ZNF699, ZN...
# 1  SLC5A5, MUC17, MAP2K1, MAP2K3, MAP2K4, SLC12A6...
# 2  MAP2K4, HAND2, MAP2K7, INO80B, BRD2, TAB1, B2M...
# 3  MAP2K1, ARL4C, NHS, ADM, NCKAP1, STAT5A, AXL, ...
# 4  MAP2K3, CAPZA1, CAPZA2, RAI1, SZT2, LRPPRC, MA...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/gene_expr...
# 1  https://pathcards.genecards.org/card/infectiou...
# 2  https://pathcards.genecards.org/card/regulatio...
# 3  https://pathcards.genecards.org/card/signal_tr...
# 4  https://pathcards.genecards.org/card/cellular_...

# %%
# print the categories from Reactome
print(miEAA['Category'].unique())
print(miEAA['Category'].value_counts())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)' 'Pathways (KEGG)'
#  'Target genes (miRTarBase)' 'Expressed in tissue (Tissue Atlas)'
#  'GO Molecular function (miRPathDB)']
# Category
# Annotations derived over miRTarBase (Gene Ontology)    141
# Expressed in tissue (Tissue Atlas)                      31
# Pathways (KEGG)                                         22
# Target genes (miRTarBase)                                7
# GO Molecular function (miRPathDB)                        1
# Name: count, dtype: int64

# %%
# find the overlap of the overlap of supepath name and subcategory
miEAA['Subcategory'].unique()
# Out:
# array(['transcription corepressor binding GO0001222',
#        'alpha-tubulin binding GO0043014',
#        'beta-tubulin binding GO0048487',
#        'positive regulation of GTPase activity GO0043547', 'Glioma',
#        'Parkinson disease',
#        'extracellular matrix structural constituent GO0005201',
#        'G-protein beta-subunit binding GO0031681',
#        'L-amino acid transmembrane transporter activity GO0015179',
#        'L-leucine transmembrane transporter activity GO0015190',
#        'branching morphogenesis of an epithelial tube GO0048754',
#        'cytoplasmic sequestering of transcription factor GO0042994',
#        'embryonic placenta development GO0001892',
#        'epidermal growth factor receptor signaling pathway GO0007173',
#        'isoleucine transport GO0015818', 'leucine transport GO0015820',
#        'methionine transport GO0015821',
#        'neutral L-amino acid transmembrane transporter activity GO0015175',
#        'phenylalanine transport GO0015823', 'response to UV-C GO0010225',
#        'G protein-coupled receptor internalization GO0002031',
#        'Grb2-EGFR complex GO0070436',
#        'I-kappaB phosphorylation GO0007252',
#        'L-histidine transport GO1902024',
#        'L-leucine import across plasma membrane GO1903801',
#        'L-tryptophan transmembrane transport GO1904556',
#        'L-tryptophan transmembrane transporter activity GO0015196',
#        'adrenomedullin receptor binding GO0031700',
#        'adrenomedullin receptor signaling pathway GO1990410',
#        'amino acid transport complex GO1990184',
#        'amylin receptor signaling pathway GO0097647',
#        'aromatic amino acid transmembrane transporter activity GO0015173',
#        'cellular response to exogenous dsRNA GO0071360',
#        'external side of apical plasma membrane GO0098591',
#        'insulin receptor substrate binding GO0043560',
#        'leucine import across plasma membrane GO0098713',
#        'negative regulation of vasoconstriction GO0045906',
#        'neural crest cell migration GO0001755',
#        'phosphatase activity GO0016791',
#        'positive regulation of cytokine production involved in immune response GO0002720',
#        'positive regulation of heart rate GO0010460',
#        'positive regulation of interleukin-4 production GO0032753',
#        'positive regulation of progesterone biosynthetic process GO2000184',
#        'positive regulation of tumor necrosis factor production GO0032760',
#        'positive regulation of vasoconstriction GO0045907',
#        'regulation of systemic arterial blood pressure GO0003073',
#        'regulation of urine volume GO0035809',
#        'thyroid hormone transmembrane transporter activity GO0015349',
#        'thyroid hormone transport GO0070327',
#        'tryptophan transport GO0015827', 'tyrosine transport GO0015828',
#        'valine transport GO0015829', 'xenobiotic transport GO0042908',
#        'Mineral absorption', 'Proximal tubule bicarbonate reclamation',
#        'ADM', 'C12orf49', 'GRB2', 'SLC7A5',
#        'phosphatidylinositol biosynthetic process GO0006661',
#        'response to lipopolysaccharide GO0032496',
#        'Inositol phosphate metabolism',
#        'protein-folding chaperone binding GO0051087',
#        'protein sumoylation GO0016925', 'Phagosome',
#        'negative regulation of protein kinase activity GO0006469',
#        'Hepatocellular carcinoma', 'adipocyte', 'arachnoid mater',
#        'artery', 'bladder', 'bone', 'brain', 'colon', 'dura mater',
#        'epididymis', 'esophagus', 'fascia', 'gallbladder', 'liver',
#        'lung', 'lymph node', 'muscle', 'myocardium', 'nerve', 'pancreas',
#        'pleura', 'prostate', 'skin', 'spinal cord', 'spleen', 'testis',
#        'thyroid', 'tunica albuginea', 'vein',
#        'intrinsic apoptotic signaling pathway in response to endoplasmic reticulum stress GO0070059',
#        'MHC class I peptide loading complex GO0042824',
#        'U4U6 x U5 tri-snRNP complex GO0046540', 'U4 snRNP GO0005687',
#        'negative regulation of amyloid-beta formation GO1902430',
#        'negative regulation of trophoblast cell migration GO1901164',
#        'nuclear androgen receptor binding GO0050681',
#        'signal complex assembly GO0007172',
#        'spermatid nucleus differentiation GO0007289',
#        'structural constituent of muscle GO0008307',
#        'Mucin type O-glycan biosynthesis',
#        'organic cyclic compound binding',
#        'Central carbon metabolism in cancer',
#        'Signaling pathways regulating pluripotency of stem cells',
#        'kidney', 'small intestine', 'stomach', 'ESCEZ complex GO0035098',
#        'L-glutamine transmembrane transporter activity GO0015186',
#        'acetyl-CoA carboxylase activity GO0003989',
#        'acetyl-CoA metabolic process GO0006084',
#        'adipose tissue development GO0060612',
#        'branching involved in ureteric bud morphogenesis GO0001658',
#        'chromosome organization GO0051276',
#        'fatty-acyl-CoA biosynthetic process GO0046949',
#        'glutamine transport GO0006868',
#        'membrane repolarization GO0086009',
#        'mitochondrial translational elongation GO0070125',
#        'nuclear steroid receptor activity GO0003707',
#        'positive regulation of cell-matrix adhesion GO0001954',
#        'positive regulation of chemokine C-X-C motif ligand 1 production GO2000340',
#        'pre-miRNA binding GO0070883',
#        'protein localization to basolateral plasma membrane GO1903361',
#        'regulation of cellular response to stress GO0080135',
#        'regulation of defense response to virus by host GO0050691',
#        'translation factor activity, RNA binding GO0008135',
#        'Fatty acid biosynthesis', 'ACACA', 'NUCB1', 'ZNF347',
#        'basal plasma membrane GO0009925',
#        'cyclin-dependent protein kinase holoenzyme complex GO0000307',
#        'fat cell differentiation GO0045444', 'filopodium GO0030175',
#        'peptide antigen binding GO0042605',
#        'phagocytic vesicle membrane GO0030670',
#        'phosphotyrosine residue binding GO0001784',
#        'response to virus GO0009615',
#        'unfolded protein binding GO0051082',
#        'Retrograde endocannabinoid signaling', 'p53 binding GO0002039',
#        'site of double-strand break GO0035861',
#        'small GTPase binding GO0031267', 'JAK-STAT signaling pathway',
#        'Neuroactive ligand-receptor interaction',
#        'Phospholipase D signaling pathway',
#        'DNA-binding transcription activator activity GO0001216',
#        'RNA polymerase II transcription regulatory region sequence-specific DNA binding GO0000977',
#        'cilium GO0005929',
#        'positive regulation of peptidyl-tyrosine phosphorylation GO0050731',
#        'cytoplasmic vesicle GO0031410', 'endocytic recycling GO0032456',
#        'growth cone GO0030426',
#        'multicellular organism development GO0007275',
#        'peptidyl-threonine phosphorylation GO0018107',
#        'substrate adhesion-dependent cell spreading GO0034446',
#        'Adrenergic signaling in cardiomyocytes', 'ATP binding GO0005524',
#        'DNA damage response GO0006974', 'bone development GO0060348',
#        'calcium ion import across plasma membrane GO0098703',
#        'cell surface GO0009986',
#        'intracellular signal transduction GO0035556',
#        'nuclear speck GO0016607',
#        'peptidyl-prolyl cis-trans isomerase activity GO0003755',
#        'positive regulation of cell migration GO0030335',
#        'positive regulation of gene expression GO0010628',
#        'protein stabilization GO0050821',
#        'regulation of cytokinesis GO0032465',
#        'regulation of filopodium assembly GO0051489', 'Breast cancer',
#        'Human T-cell leukemia virus 1 infection',
#        'PI3K-Akt signaling pathway', 'Shigellosis',
#        'MLL34 complex GO0044666', 'cell projection GO0042995',
#        'chromosome, telomeric region GO0000781',
#        'phosphatidylinositol-4,5-bisphosphate binding GO0005546',
#        'Chemokine signaling pathway',
#        'amino acid transmembrane transporter activity GO0015171',
#        'cytosolic large ribosomal subunit GO0022625',
#        'four-way junction DNA binding GO0000400',
#        'in utero embryonic development GO0001701',
#        'microvillus membrane GO0031528',
#        'mitotic spindle assembly GO0090307',
#        'negative regulation of vascular endothelial growth factor receptor signaling pathway GO0030948',
#        'neutral amino acid transport GO0015804',
#        'phosphatidylinositol dephosphorylation GO0046856',
#        'plasma membrane repair GO0001778',
#        'positive regulation of neutrophil chemotaxis GO0090023',
#        'positive regulation of stress fiber assembly GO0051496',
#        'regulation of cell growth GO0001558',
#        'regulation of endocytosis GO0030100',
#        'signal transduction in response to DNA damage GO0042770',
#        'spindle assembly GO0051225', 'vasculogenesis GO0001570',
#        'Phosphatidylinositol signaling system'], dtype=object)

# %%
gc['SuperPath Name'].unique()
# Out:
# array(['Gene Expression (Transcription)', 'Infectious Disease',
#        'Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation',
#        'Signal Transduction', 'Cellular Responses to Stimuli',
#        'MAP Kinase Signaling', 'Metabolism of Proteins', 'DNA Damage',
#        'Pleural Mesothelioma', 'IL-17 Family Signaling Pathways',
#        'RNA Polymerase I Promoter Opening', 'Toll Comparative Pathway',
#        'Cellular Senescence', 'MAPK Signaling: Oxidative Stress',
#        'Signaling By Rho GTPases',
#        'Signaling By Receptor Tyrosine Kinases', 'TCR Signaling (Qiagen)',
#        'Regulation of TP53 Activity', 'Signaling By TGFB Family Members',
#        'Sertoli-Sertoli Cell Junction Dynamics',
#        'Tacrolimus/Cyclosporine Pathway, Pharmacodynamics',
#        'IL-1 Family Signaling Pathways', 'GPCR Pathway',
#        'MAPK Family Signaling Cascades',
#        'Assembly of The Pre-replicative Complex',
#        'Regulation of Actin Cytoskeleton', 'Cell Cycle Checkpoints',
#        'TGF-Beta Pathway',
#        'Class I MHC Mediated Antigen Processing and Presentation',
#        'Chromatin Organization', 'Toll-Like Receptor Signaling Pathways',
#        'Cytoskeletal Signaling', 'Homology Directed Repair',
#        'PDGFR-beta Signaling Pathway', 'Innate Immune System',
#        'Cell Cycle, Mitotic', 'Cell Cycle', 'CNTF Signaling',
#        'Chromatin Regulation / Acetylation',
#        'Apoptotic Pathways in Synovial Fibroblasts',
#        'Cell Cycle Role of 14-3-3 Proteins in Cell Cycle Regulation',
#        'Toll-like Receptor Signaling Pathway',
#        'Transcription_P53 Signaling Pathway',
#        'Transcriptional Regulation By The AP-2 (TFAP2) Family of Transcription Factors',
#        'Ovarian Tumor Domain Proteases',
#        'Immune Response IL-2 Activation and Signaling Pathway',
#        'Ubiquitination Cascade', '5q35 Copy Number Variation',
#        'TGF-beta Signaling Pathways', 'PKMTs Methylate Histone Lysines',
#        'Development_Glucocorticoid Receptor Signaling', 'Akt Signaling',
#        'AP-1 Transcription Factor Network',
#        'Transcriptional Activity of SMAD2/SMAD3:SMAD4 Heterotrimer',
#        'Validated Targets of C-MYC Transcriptional Activation',
#        'Signaling Events Mediated By Hepatocyte Growth Factor Receptor (c-Met)',
#        'Activation of The Pre-replicative Complex',
#        'Processing of Capped Intron-Containing Pre-mRNA',
#        'SARS-CoV-2 Infection', 'ERK Signaling', 'MAPK Signaling Pathway',
#        'Tyrosine Kinases / Adaptors', 'Deubiquitination',
#        'Downstream Signaling in Naïve CD8+ T Cells',
#        'Disorders of Folate Metabolism and Transport',
#        'Signaling Events Mediated By HDAC Class I', 'Endometrial Cancer',
#        'MTOR Signaling Pathway', 'PtdIns(4,5)P2 in Cytokinesis Pathway',
#        'EPH-Ephrin Signaling', 'Glucose / Energy Metabolism',
#        'Prolactin Signaling', 'P53 Pathway', 'ESR-mediated Signaling',
#        'Immune Response_IL-6 Signaling Pathway',
#        'Cell Cycle Regulation of G1/S Transition (part 1)',
#        'Signaling By ALK in Cancer',
#        'Corticotropin-releasing Hormone Signaling Pathway',
#        'CD28 Signaling in T-Helper Cell',
#        'Calcineurin-regulated NFAT-dependent Transcription in Lymphocytes',
#        'Packaging Of Telomere Ends', 'Integrated Breast Cancer Pathway',
#        'VEGF Signaling Pathway',
#        'Transport of Inorganic Cations/anions and Amino Acids/oligopeptides',
#        'MAP Kinase Activation', 'Development_TGF-beta Receptor Signaling',
#        '3q29 Copy Number Variation Syndrome', 'Chromosome Maintenance',
#        'Nervous System Development'], dtype=object)

# %%
overlap = miEAA.merge(gc, left_on='Subcategory', right_on='SuperPath Name')
overlap.head()
# Out:
# Empty DataFrame
# Columns: [Category, Subcategory, Enrichment, P-value, P-adjusted, Q-value, Observed, miRNAs/precursors, Score, SuperPath Name, # SuperPath Total Genes, # SuperPath Matched Genes, Matched Genes (Symbols), Evidence URL]
# Index: []
