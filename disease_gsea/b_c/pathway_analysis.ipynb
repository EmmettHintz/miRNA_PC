# %%
import pandas as pd

# %%
miEAA = pd.read_csv('./b_c_miEAA.csv')
print(miEAA.columns)
# Out:
# Index(['Category', 'Subcategory', 'Enrichment', 'P-value', 'P-adjusted',
#        'Q-value', 'Observed', 'miRNAs/precursors'],
#       dtype='object')

# %%
# Print unique categories
print(miEAA['Category'].unique())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)' 'Diseases (MNDR)'
#  'Target genes (miRTarBase)' 'Gene Ontology (miRWalk)' 'Pathways (KEGG)'
#  'Published Diseases' 'Annotation (Gene Ontology)' 'Pathways (miRWalk)'
#  'Interactions (NPInter)' 'isomiRs (isomiRdb)'
#  'GO Biological process (miRPathDB)' 'GO Molecular function (miRPathDB)'
#  'WikiPathways (miRPathDB)' 'Localization (RNALocate)'
#  'Conservation (miRBase)' 'Tissue specific (isomiRdb)'
#  'Chromosomal location (miRBase)' 'Reactome (miRPathDB)'
#  'KEGG (miRPathDB)']

# %%
gc = pd.ExcelFile('./b_c_gc.xlsx')
gc = pd.read_excel(gc, 'Pathways', skiprows=18)
gc.columns
# Out:
# Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')

# %%
miEAA.head()
# Out:
#                                             Category  \
# 0  Annotations derived over miRTarBase (Gene Onto...
# 1  Annotations derived over miRTarBase (Gene Onto...
# 2                                    Diseases (MNDR)
# 3  Annotations derived over miRTarBase (Gene Onto...
# 4  Annotations derived over miRTarBase (Gene Onto...
#
#                                          Subcategory Enrichment   P-value  \
# 0  positive regulation of cell-cell adhesion medi...   enriched  0.000282
# 1  regulation of insulin secretion involved in ce...   enriched  0.000282
# 2                           Hepatocellular carcinoma   depleted  0.000624
# 3  glutathione disulfide oxidoreductase activity ...   depleted  0.000705
# 4                    inner ear development GO0048839   depleted  0.000705
#
#    P-adjusted   Q-value  Observed  \
# 0    0.000282  0.502418         3
# 1    0.000282  0.502418         3
# 2    0.000624  0.125402        12
# 3    0.000705  0.502418         3
# 4    0.000705  0.502418         3
#
#                                    miRNAs/precursors
# 0   hsa-miR-1185-2-3p; hsa-miR-1290; hsa-miR-4685-3p
# 1   hsa-miR-1185-2-3p; hsa-miR-1290; hsa-miR-4685-3p
# 2  hsa-miR-17-3p; hsa-miR-1224-5p; hsa-miR-940; h...
# 3   hsa-miR-6819-5p; hsa-miR-342-5p; hsa-miR-4769-5p
# 4   hsa-miR-6819-5p; hsa-miR-342-5p; hsa-miR-1227-3p

# %%
gc.head()
# Out:
#         Score                   SuperPath Name  # SuperPath Total Genes  \
# 0  166.096405              Signal Transduction                     2597
# 1  166.096405           Metabolism of Proteins                     2077
# 2  166.096405             Innate Immune System                     2054
# 3  166.096405               Infectious Disease                     1818
# 4  166.096405  Gene Expression (Transcription)                     1543
#
#    # SuperPath Matched Genes  \
# 0                        627
# 1                        507
# 2                        484
# 3                        479
# 4                        453
#
#                              Matched Genes (Symbols)  \
# 0  MUC20, ARL2, PPP1CC, SALL4, CAPZB, ARL4C, PTK2...
# 1  CANX, EIF2B5, MUC17, MUC20, RPS19, RPS2, ARL2,...
# 2  CANX, MUC17, CAPN1, MUC20, A1BG, MAP2K3, GAN, ...
# 3  CANX, SLC5A5, MUC17, CAPN1, MUC20, RPS19, RPS2...
# 4  LAMTOR1, NPM1, ZNF317, CARM1, ABCA6, THOC5, TH...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/signal_tr...
# 1  https://pathcards.genecards.org/card/metabolis...
# 2  https://pathcards.genecards.org/card/innate_im...
# 3  https://pathcards.genecards.org/card/infectiou...
# 4  https://pathcards.genecards.org/card/gene_expr...

# %%
# print the categories from Reactome
print(miEAA['Category'].unique())
print(miEAA['Category'].value_counts())
# Out:
# ['Annotations derived over miRTarBase (Gene Ontology)' 'Diseases (MNDR)'
#  'Target genes (miRTarBase)' 'Gene Ontology (miRWalk)' 'Pathways (KEGG)'
#  'Published Diseases' 'Annotation (Gene Ontology)' 'Pathways (miRWalk)'
#  'Interactions (NPInter)' 'isomiRs (isomiRdb)'
#  'GO Biological process (miRPathDB)' 'GO Molecular function (miRPathDB)'
#  'WikiPathways (miRPathDB)' 'Localization (RNALocate)'
#  'Conservation (miRBase)' 'Tissue specific (isomiRdb)'
#  'Chromosomal location (miRBase)' 'Reactome (miRPathDB)'
#  'KEGG (miRPathDB)']
# Category
# Annotations derived over miRTarBase (Gene Ontology)    637
# Target genes (miRTarBase)                              116
# Gene Ontology (miRWalk)                                103
# Interactions (NPInter)                                  55
# Pathways (KEGG)                                         19
# GO Biological process (miRPathDB)                       18
# Pathways (miRWalk)                                      15
# Diseases (MNDR)                                         12
# Published Diseases                                       3
# Localization (RNALocate)                                 2
# Conservation (miRBase)                                   1
# Reactome (miRPathDB)                                     1
# Chromosomal location (miRBase)                           1
# Tissue specific (isomiRdb)                               1
# isomiRs (isomiRdb)                                       1
# WikiPathways (miRPathDB)                                 1
# GO Molecular function (miRPathDB)                        1
# Annotation (Gene Ontology)                               1
# KEGG (miRPathDB)                                         1
# Name: count, dtype: int64

# %%
# find the overlap of the overlap of supepath name and subcategory
miEAA['Subcategory'].unique()
# Out:
# array(['positive regulation of cell-cell adhesion mediated by cadherin GO2000049',
#        'regulation of insulin secretion involved in cellular response to glucose stimulus GO0061178',
#        'Hepatocellular carcinoma',
#        'glutathione disulfide oxidoreductase activity GO0015038',
#        'inner ear development GO0048839',
#        'positive regulation of membrane potential GO0045838',
#        'protein deglutathionylation GO0080058', '2022-03-09 000000',
#        'GLRX', 'peptide biosynthetic process GO0043043',
#        'GO0005813 centrosome', 'AP-1 adaptor complex binding GO0035650',
#        'AP-3 adaptor complex binding GO0035651',
#        'BLOC-2 complex binding GO0036461',
#        'early endosome lumen GO0031905',
#        'positive regulation of interleukin-18 production GO0032741',
#        'NLRP9', 'PCSK1', 'RAB32', 'SESN3',
#        'regulation of RNA splicing GO0043484',
#        'RNA phosphodiester bond hydrolysis, endonucleolytic GO0090502',
#        'ASB6', 'beta-tubulin binding GO0048487',
#        'dendritic spine morphogenesis GO0060997',
#        'oxidoreductase activity, acting on peroxide as acceptor GO0016684',
#        'negative regulation of cell size GO0045792',
#        'positive regulation of T cell differentiation in thymus GO0033089',
#        'GO0016887 atpase activity', 'Cardiac muscle contraction',
#        'oxidative phosphorylation GO0006119',
#        'positive regulation of peptidyl-lysine acetylation GO2000758',
#        'procollagen galactosyltransferase activity GO0050211',
#        'regulation of smoothened signaling pathway GO0008589',
#        'ubiquinol-cytochrome-c reductase activity GO0008121',
#        'GO0043984 histone h4 k16 acetylation',
#        'endocrine pancreas development GO0031018',
#        'ligand-activated transcription factor activity GO0098531',
#        'negative regulation of cytokinesis GO0032466',
#        'negative regulation of transcription from RNA polymerase II promoter by glucose GO0061987',
#        'positive regulation of transcription from RNA polymerase II promoter by glucose GO0000432',
#        'primitive streak formation GO0090009',
#        'response to interleukin-6 GO0070741', 'FOXA2', 'RORA',
#        'melanoma upregulated',
#        'positive regulation of integrin-mediated signaling pathway GO2001046',
#        'synaptic membrane adhesion GO0099560', 'APOL6',
#        'GO0031145 anaphase promoting complex dependent proteasomal ubiquitin dependent protein catabolic process',
#        'GO0051436 negative regulation of ubiquitin protein ligase activity involved in mitotic cell cycle',
#        'GO0051437 positive regulation of ubiquitin protein ligase activity involved in mitotic cell cycle',
#        'GO0051439 regulation of ubiquitin protein ligase activity involved in mitotic cell cycle',
#        'extracellular space GO0005615',
#        'anaphase-promoting complex GO0005680', 'Synaptic vesicle cycle',
#        'positive regulation of cytokine production GO0001819',
#        'autophagy GO0006914',
#        'positive regulation of muscle cell differentiation GO0051149',
#        'zymogen activation GO0031638', 'SEC22C',
#        'apolipoprotein A-I-mediated signaling pathway GO0038027',
#        'negative regulation of kinase activity GO0033673', 'Glioma',
#        'cellular response to transforming growth factor beta stimulus GO0071560',
#        'JAK-STAT signaling pathway', 'Cholangiocarcinoma',
#        'cellular response to cytokine stimulus GO0071345',
#        'neuregulin binding GO0038132',
#        'positive regulation of glycoprotein metabolic process GO1903020',
#        'positive regulation of protein kinase A signaling GO0010739',
#        'response to UV-C GO0010225',
#        'GO0000080 g1 phase of mitotic cell cycle', 'GO0005764 lysosome',
#        'GO0006461 protein complex assembly', 'GO0006508 proteolysis',
#        'GO0007417 central nervous system development',
#        'hsa04142 Lysosome', 'hsa05222 Small cell lung cancer',
#        'GO0006915 apoptotic process',
#        'cytoplasmic microtubule organization GO0031122',
#        'DNA protection GO0042262',
#        'G protein-coupled receptor signaling pathway, coupled to cyclic nucleotide second messenger GO0007187',
#        'G protein-coupled serotonin receptor activity GO0004993',
#        'L-cysteine catabolic process GO0019448',
#        'autophagic cell death GO0048102',
#        'carbon monoxide binding GO0070025',
#        'cellular response to lithium ion GO0071285',
#        'cystathionine beta-synthase activity GO0004122',
#        'cysteine biosynthetic process GO0019344',
#        'cysteine biosynthetic process from serine GO0006535',
#        'cysteine synthase activity GO0004124',
#        'embryo implantation GO0007566',
#        'homocysteine catabolic process GO0043418',
#        'hydrogen peroxide catabolic process GO0042744',
#        'hydrogen sulfide biosynthetic process GO0070814',
#        'nitric oxide binding GO0070026',
#        'nitrite reductase NO-forming activity GO0050421',
#        'protein localization to bicellular tight junction GO1902396',
#        'very long-chain fatty acid-CoA ligase activity GO0031957',
#        'ACTG1', 'CBS', 'CDKN1B', 'DIP2A', 'MAGEB4', 'MBNL1',
#        'RP4-550H1.6',
#        'positive regulation of mitochondrial fission GO0090141',
#        'postsynaptic density membrane GO0098839',
#        'transmitter-gated monoatomic ion channel activity involved in regulation of postsynaptic membrane potential GO1904315',
#        'response to virus GO0009615', 'RNA polyadenylation GO0043631',
#        'hair follicle morphogenesis GO0031069',
#        'negative regulation of cell cycle G1S phase transition GO1902807',
#        'regulation of voltage-gated calcium channel activity GO1901385',
#        'secretion by cell GO0032940', 'MLX',
#        'alternative DROSHA processing', 'C-C chemokine binding GO0019957',
#        'microtubule associated complex GO0005875',
#        'negative regulation of calcineurin-NFAT signaling cascade GO0070885',
#        'polyubiquitin modification-dependent protein binding GO0031593',
#        'positive regulation of cell death GO0010942',
#        'regulation of keratinocyte proliferation GO0010837',
#        'regulation of mRNA splicing, via spliceosome GO0048024',
#        'stress-activated protein kinase signaling cascade GO0031098',
#        'DNARNA helicase activity GO0033677',
#        'Roundabout signaling pathway GO0035385',
#        'positive regulation of stress granule assembly GO0062029',
#        'regulation of gene expression', 'axon GO0030424',
#        'negative regulation of inflammatory response GO0050728',
#        'p38MAPK cascade GO0038066',
#        'protein-disulfide reductase activity GO0015035',
#        'NSL complex GO0044545', 'GO0006200 atp catabolic process',
#        'calcium-dependent cysteine-type endopeptidase activity GO0004198',
#        'mRNA transcription by RNA polymerase II GO0042789',
#        'branching morphogenesis of an epithelial tube GO0048754',
#        'hindbrain development GO0030902',
#        'ventral midline development GO0007418',
#        'neurotransmitter transmembrane transporter activity GO0005326',
#        'GO0006366 transcription from rna polymerase ii promoter',
#        'GO0006511 ubiquitin dependent protein catabolic process',
#        'hsa04110 Cell cycle',
#        'BMP signaling pathway involved in heart development GO0061312',
#        'BMP signaling pathway involved in heart induction GO0003130',
#        'C21-steroid hormone biosynthetic process GO0006700',
#        'CRLF-CLCF1 complex GO0097058',
#        'DNA-templated transcription termination GO0006353',
#        'GINS complex GO0000811',
#        'Krueppel-associated box domain binding GO0035851',
#        'atrioventricular canal morphogenesis GO1905222',
#        'cardiac atrium formation GO0003210',
#        'cardiac jelly development GO1905072',
#        'cellular response to lectin GO1990858',
#        'cellular response to lipid GO0071396',
#        'cholesterol monooxygenase side-chain-cleaving activity GO0008386',
#        'chromo shadow domain binding GO0070087',
#        'ciliary neurotrophic factor receptor binding GO0005127',
#        'corticotropin hormone secreting cell differentiation GO0060128',
#        'cortisol metabolic process GO0034650',
#        'embryonic heart tube anteriorposterior pattern specification GO0035054',
#        'equilibrioception GO0050957',
#        'extracellular matrix constituent, lubricant activity GO0030197',
#        'glucocorticoid biosynthetic process GO0006704',
#        'macrophage activation involved in immune response GO0002281',
#        'mesenchymal cell proliferation involved in ureteric bud development GO0072138',
#        'mesenchyme development GO0060485',
#        'molecular sequestering activity GO0140313',
#        'negative regulation of Wnt signaling pathway involved in heart development GO0003308',
#        'negative regulation of calcium-independent cell-cell adhesion GO0051042',
#        'negative regulation of steroid biosynthetic process GO0010894',
#        'pericardium development GO0060039',
#        'photoreceptor cell cilium GO0097733',
#        'positive regulation of Wnt signaling pathway by BMP signaling pathway GO0060804',
#        'positive regulation of astrocyte differentiation GO0048711',
#        'positive regulation of bone mineralization involved in bone maturation GO1900159',
#        'positive regulation of extracellular matrix constituent secretion GO0003331',
#        'positive regulation of neuroinflammatory response GO0150078',
#        'positive regulation of odontogenesis GO0042482',
#        'positive regulation of phosphatase activity GO0010922',
#        'positive regulation of reactive oxygen species biosynthetic process GO1903428',
#        'regulation of thalamus size GO0090067',
#        'sensory perception of light stimulus GO0050953',
#        'serotonin binding GO0051378',
#        'serotoninsodiumchloride symporter activity GO0005335',
#        'thyroid-stimulating hormone-secreting cell differentiation GO0060129',
#        'Phenylalanine metabolism', 'BMP2', 'CABP4', 'CDH6', 'CRLF1',
#        'CYP11A1', 'EPN1', 'FAM136A', 'FOXRED2', 'GINS3', 'MUC17', 'PLCG2',
#        'PQLC1', 'RPS16', 'SETBP1', 'SLC6A4', 'TRIM28', 'UCK1', 'UQCRH',
#        'USH1G', 'Acute myeloid leukemia',
#        'positive regulation of RNA biosynthetic process',
#        'positive regulation of cellular biosynthetic process',
#        'positive regulation of macromolecule biosynthetic process',
#        'positive regulation of nucleic acid-templated transcription',
#        'ADARB1', 'ANKRD13C', 'APPBP2', 'BUB1', 'CKMT1B', 'DNAJB9', 'FZD6',
#        'GFM1', 'GPR37', 'HNRNPA3', 'IRF2BP2', 'LDLR', 'MXD1', 'OXA1L',
#        'PBRM1', 'PHGDH', 'PPP1R3B', 'PTPRD', 'RAB1A', 'SLC46A3', 'SLTM',
#        'SMURF1', 'SOBP', 'TCF4', 'TMEM87A', 'UBQLN2', 'ZFP36L2',
#        'substrate adhesion-dependent cell spreading GO0034446',
#        'kinase activity GO0016301', 'Coronavirus disease - COVID-19',
#        'positive regulation of neuron differentiation GO0045666',
#        'activation of GTPase activity GO0090630',
#        'regulation of sodium ion transport GO0002028',
#        'sialic acid binding GO0033691',
#        'snRNA export from nucleus GO0006408',
#        'clathrin vesicle coat GO0030125', 'ZNF587',
#        'mRNA 3-UTR AU-rich region binding GO0035925',
#        'cellular response to lipopolysaccharide GO0071222',
#        'protease binding GO0002020',
#        'vesicle-mediated transport GO0016192',
#        'cell projection GO0042995', 'bone mineralization GO0030282',
#        'histone H3-K4 trimethylation GO0080182',
#        'negative regulation of DNA methylation GO1905642',
#        'protein-cysteine methyltransferase activity GO0106363', 'KMT2A',
#        'response to lipopolysaccharide GO0032496',
#        'cellular response to leucine starvation GO1990253',
#        'leucine binding GO0070728',
#        'negative regulation of transcription elongation by RNA polymerase II GO0034244',
#        'LRTOMT', 'nucleosomal DNA binding GO0031492',
#        'Cell adhesion molecules', 'alpha-tubulin binding GO0043014',
#        'cellular response to glucose starvation GO0042149',
#        'intermediate filament cytoskeleton GO0045111',
#        'positive regulation of release of cytochrome c from mitochondria GO0090200',
#        'positive regulation of collagen fibril organization GO1904028',
#        'primary adaptive immune response involving T cells and B cells GO0090721',
#        'BACH2', 'COLGALT1', 'PURA',
#        'cellular macromolecule catabolic process',
#        'chloride channel inhibitor activity',
#        'Exercise-induced Circadian Regulation',
#        'L-lysine transmembrane transporter activity GO0015189',
#        'L-ornithine transmembrane transporter activity GO0000064',
#        'basic amino acid transmembrane transporter activity GO0015174',
#        'lysine transport GO0015819',
#        'positive regulation of I-kappaB phosphorylation GO1903721',
#        'vitamin D metabolic process GO0042359',
#        'Maturity onset diabetes of the young', 'PROSER3', 'TMEM109',
#        'regulation of epithelial cell migration', 'GPX3', 'RASA1',
#        'RCAN2', 'UBQLN4', 'autophagosome GO0005776',
#        'anaphase-promoting complex-dependent catabolic process GO0031145',
#        'Gastric cancer', 'FMN binding GO0010181',
#        'GDP-dissociation inhibitor activity GO0005092',
#        'K63-linked polyubiquitin modification-dependent protein binding GO0070530',
#        'MAP-kinase scaffold activity GO0005078',
#        'chromatoid body GO0033391',
#        'negative regulation of inflammatory response to antigenic stimulus GO0002862',
#        'regulation of DNA strand elongation GO0060382',
#        'regulation of chromosome organization GO0033044',
#        'regulation of keratinocyte differentiation GO0045616', 'MPRIP',
#        'myosin binding GO0017022',
#        'negative regulation of sprouting angiogenesis GO1903671',
#        'negative regulation of NF-kappaB transcription factor activity GO0032088',
#        'EP4 subtype prostaglandin E2 receptor binding GO0031867', 'FEM1A',
#        'centrosome cycle GO0007098',
#        'clathrin-coated endocytic vesicle membrane GO0030669',
#        'U2-type precatalytic spliceosome GO0071005',
#        'endosomal transport GO0016197',
#        'anterograde axonal transport GO0008089',
#        'positive regulation of macroautophagy GO0016239',
#        'potassium ion leak channel activity GO0022841',
#        'stabilization of membrane potential GO0030322',
#        'GO0005576 extracellular region',
#        'phosphatidylinositol dephosphorylation GO0046856',
#        'protein-containing complex localization GO0031503',
#        'regulation of proteasomal ubiquitin-dependent protein catabolic process GO0032434',
#        'serine-type peptidase activity GO0008236', 'G3BP1', 'UBN2',
#        'positive regulation of cellular metabolic process',
#        'positive regulation of metabolic process',
#        'deoxyribonuclease inhibitor activity GO0060703',
#        'laminin-10 complex GO0043259', 'laminin-11 complex GO0043260',
#        'laminin-1 complex GO0005606',
#        'methenyltetrahydrofolate cyclohydrolase activity GO0004477',
#        'methylenetetrahydrofolate dehydrogenase NAD+ activity GO0004487',
#        'methylenetetrahydrofolate dehydrogenase NADP+ activity GO0004488',
#        'negative regulation of apoptotic DNA fragmentation GO1902511',
#        'negative regulation of deoxyribonuclease activity GO0032076',
#        'negative regulation of gluconeogenesis GO0045721',
#        'phospholipase D activity GO0004630',
#        'positive regulation of osteoblast proliferation GO0033690',
#        'protein complex involved in cell-matrix adhesion GO0098637',
#        'regulation of basement membrane organization GO0110011',
#        'spermatid nucleus differentiation GO0007289', 'DFFA', 'LAMC1',
#        'LEAP2', 'PYGO1', 'ZNF321P', 'ZNF799',
#        'positive regulation of gene expression',
#        'GO0000075 cell cycle checkpoint',
#        'GO0016071 mrna metabolic process',
#        '3-UTR-mediated mRNA stabilization GO0070935',
#        'branching involved in ureteric bud morphogenesis GO0001658',
#        'cell death GO0008219',
#        'cellular response to epidermal growth factor stimulus GO0071364',
#        'eye development GO0001654',
#        'protein disulfide isomerase activity GO0003756',
#        'secretory granule GO0030141', 'Nucleus',
#        'adenylate cyclase-activating dopamine receptor signaling pathway GO0007191',
#        'histone H3K27 methyltransferase activity GO0046976',
#        'protein K69-linked ufmylation GO1990592',
#        'protein ufmylation GO0071569',
#        'regulation of RNA polymerase II transcription preinitiation complex assembly GO0045898',
#        'Conserved in at least 5 species', 'ATF7IP', 'ND2', 'NHS',
#        'GO0002039 p53 binding', 'GO0003680 at dna binding',
#        'GO0004842 ubiquitin protein ligase activity',
#        'GO0005770 late endosome',
#        'GO0005832 chaperonin containing t complex',
#        'GO0006306 dna methylation', 'GO0006338 chromatin remodeling',
#        'GO0006887 exocytosis',
#        'GO0008023 transcription elongation factor complex',
#        'GO0008026 atp dependent helicase activity',
#        'GO0009060 aerobic respiration', 'GO0009615 response to virus',
#        'GO0014823 response to activity', 'GO0015992 proton transport',
#        'GO0019905 syntaxin binding',
#        'GO0030198 extracellular matrix organization',
#        'GO0032411 positive regulation of transporter activity',
#        'GO0034329 cell junction assembly',
#        'GO0035162 embryonic hemopoiesis',
#        'GO0043330 response to exogenous dsrna',
#        'GO0045216 cell cell junction organization',
#        'GO0045322 unmethylated cpg binding', 'GO0071339 mll1 complex',
#        'GO0080182 histone h3 k4 trimethylation',
#        'GO2001022 positive regulation of response to dna damage stimulus',
#        'WP1545 miRNAs involved in DDR',
#        'hsa00051 Fructose and mannose metabolism',
#        'hsa04742 Taste transduction',
#        'hsa04914 Progesterone mediated oocyte maturation',
#        'hsa05215 Prostate cancer', 'muscle specific', 'VCL',
#        'positive regulation of NIKNF-kappaB signaling GO1901224',
#        'potassium ion transmembrane transport GO0071805',
#        'bicellular tight junction assembly GO0070830',
#        'methyl-CpG binding GO0008327',
#        'ribonucleoprotein complex binding GO0043021',
#        'postsynaptic membrane GO0045211', 'macroautophagy GO0016236',
#        'positive regulation of protein serinethreonine kinase activity GO0071902',
#        'phagocytic vesicle membrane GO0030670',
#        'RNA cap binding complex GO0034518', 'mRNA transport GO0051028',
#        'nuclear cap binding complex GO0005846',
#        'nucleotide-activated protein kinase complex GO0031588', 'ESF1',
#        'ferric iron binding GO0008199',
#        'muscle structure development GO0061061',
#        'odontogenesis of dentin-containing tooth GO0042475',
#        'positive regulation of DNA methylation GO1905643',
#        'GO0002474 antigen processing and presentation of peptide antigen via mhc class i',
#        'GO0002479 antigen processing and presentation of exogenous peptide antigen via mhc class i tap dependent',
#        'GO0008284 positive regulation of cell proliferation',
#        'GO0009986 cell surface', 'GO0016020 membrane',
#        'GO0042590 antigen processing and presentation of exogenous peptide antigen via mhc class i',
#        'GO0042981 regulation of apoptotic process',
#        'GO0044212 transcription regulatory region dna binding',
#        'GO0070577 histone acetyl lysine binding', 'TPM3',
#        'actin filament depolymerization GO0030042',
#        'beta-catenin-TCF complex assembly GO1904837',
#        'oocyte growth GO0001555',
#        'positive regulation of protein exit from endoplasmic reticulum GO0070863',
#        'regulation of meiotic cell cycle GO0051445',
#        'Allograft rejection', 'Autoimmune thyroid disease', 'KMT2D',
#        'mTOR signaling pathway', 'Malignant glioma',
#        'GLI-SUFU complex GO1990788', 'JUN kinase activity GO0004705',
#        'RNA polymerase II core promoter sequence-specific DNA binding GO0000979',
#        'Schmidt-Lanterman incisure GO0043220',
#        'actinin binding GO0042805',
#        'alphav-beta3 integrin-PKCalpha complex GO0035866',
#        'cell growth involved in cardiac muscle cell development GO0061049',
#        'cellular response to ATP GO0071318',
#        'cerebellar cortex morphogenesis GO0021696',
#        'determination of adult lifespan GO0008340',
#        'floor plate formation GO0021508',
#        'hindgut morphogenesis GO0007442',
#        'membrane depolarization during AV node cell action potential GO0086045',
#        'membrane depolarization during atrial cardiac muscle cell action potential GO0098912',
#        'negative regulation of hh target transcription factor activity GO1990787',
#        'nerve growth factor production GO0032902',
#        'positive regulation of miRNA catabolic process GO2000627',
#        'protein demethylation GO0006482',
#        'regulation of lipoprotein lipase activity GO0051004',
#        'regulation of stress fiber assembly GO0051492',
#        'smoothened signaling pathway involved in ventral spinal cord interneuron specification GO0021775',
#        'spinal cord dorsalventral patterning GO0021513',
#        'spinal cord ventral commissure morphogenesis GO0021965',
#        'sulfur oxidation GO0019417', 'synapse maturation GO0060074',
#        'voltage-gated calcium channel activity involved in AV node cell action potential GO0086056',
#        'voltage-gated calcium channel activity involved in cardiac muscle cell action potential GO0086007',
#        'GLI2', 'HIST1H1B', 'HIST2H2AB', 'MAPK10', 'MICAL2', 'PDLIM5',
#        'THBS2', 'negative regulation of transcription DNA-templated',
#        'negative regulation of transcription by RNA polymerase II',
#        'alpha-1-3-fucosyltransferase activity GO0046920',
#        'high voltage-gated calcium channel activity GO0008331',
#        'negative regulation of programmed cell death GO0043069',
#        'pericentriolar material GO0000242', 'snRNA binding GO0017069',
#        'FBRS', 'gene expression', 'PTP4A2',
#        'GTPase inhibitor activity GO0005095', 'aggrephagy GO0035973',
#        'aortic valve development GO0003176', 'co-SMAD binding GO0070410',
#        'mitochondrial respiratory chain complex III GO0005750',
#        'positive regulation of macrophage cytokine production GO0060907',
#        'zygotic specification of dorsalventral axis GO0007352',
#        'Chromosome 14', 'GO0007411 axon guidance',
#        'P00029 Huntington disease',
#        'U2-type prespliceosome assembly GO1903241', 'U2 snRNP GO0005686',
#        'cellular defense response GO0006968',
#        'peptide antigen binding GO0042605',
#        'positive regulation of TOR signaling GO0032008',
#        'positive regulation of protein autophosphorylation GO0031954',
#        'protein monoubiquitination GO0006513',
#        'structural molecule activity GO0005198',
#        'ionotropic glutamate receptor activity GO0004970',
#        'kainate selective glutamate receptor activity GO0015277',
#        'kainate selective glutamate receptor complex GO0032983',
#        'regulation of oxidative stress-induced intrinsic apoptotic signaling pathway GO1902175',
#        'thiol oxidase activity GO0016972',
#        'GO0030336 negative regulation of cell migration',
#        'ovarian cancer upregulated',
#        'RNA polymerase II, core complex GO0005665',
#        'cell junction assembly GO0034329', 'response to UV-A GO0070141',
#        'synaptic transmission, glutamatergic GO0035249',
#        'basement membrane GO0005604', 'wound healing GO0042060',
#        'Hsp70 protein binding GO0030544',
#        'protein serinethreonine kinase activator activity GO0043539',
#        'spermatogenesis GO0007283', 'telomere organization GO0032200',
#        'autophagosome maturation GO0097352',
#        'protein-macromolecule adaptor activity GO0030674',
#        'protein tyrosine kinase activity GO0004713',
#        'recycling endosome GO0055037', 'Colorectal cancer',
#        'Stomach cancer', 'establishment of planar polarity GO0001736',
#        'membrane depolarization during cardiac muscle cell action potential GO0086012',
#        'positive regulation of SMAD protein signal transduction GO0060391',
#        'APOL1', 'PPAP2B', 'RPL18',
#        'MHC class I protein complex GO0042612',
#        'aortic valve formation GO0003189',
#        'brain morphogenesis GO0048854',
#        'chromosome condensation GO0030261',
#        'elastic fiber assembly GO0048251',
#        'endothelial tube lumen extension GO0097498',
#        'mitotic cleavage furrow formation GO1903673',
#        'muscle myosin complex GO0005859',
#        'negative regulation of G protein-coupled receptor signaling pathway GO0045744',
#        'negative regulation of PERK-mediated unfolded protein response GO1903898',
#        'ossification involved in bone maturation GO0043931',
#        'positive regulation of cytosolic calcium ion concentration involved in phospholipase C-activating G protein-coupled signaling pathway GO0051482',
#        'positive regulation of superoxide anion generation GO0032930',
#        'regulation of modification of postsynaptic actin cytoskeleton GO1905274',
#        'regulation of modification of postsynaptic structure GO0099159',
#        'regulation of osteoblast proliferation GO0033688',
#        'skeletal muscle myosin thick filament assembly GO0030241',
#        'synaptic vesicle maturation GO0016188',
#        'trabecula morphogenesis GO0061383', 'HIST3H3', 'MYH11', 'RHOA',
#        'Cellular Senescence', 'DNA replication origin binding GO0003688',
#        'mRNA cap binding complex GO0005845',
#        'membrane organization GO0061024',
#        'negative regulation of TORC1 signaling GO1904262',
#        'negative regulation of nitric oxide biosynthetic process GO0045019',
#        'phosphatidic acid binding GO0070300',
#        'protein stabilization GO0050821', 'HULC complex GO0033503',
#        'extracellular matrix disassembly GO0022617',
#        'regulation of neuronal synaptic plasticity GO0048168',
#        'heterocycle metabolic process', 'macromolecule metabolic process',
#        'nitrogen compound metabolic process',
#        'regulation of metabolic process',
#        'cytoplasmic side of plasma membrane GO0009898',
#        'Hippo signaling pathway',
#        'RNA polymerase I core promoter sequence-specific DNA binding GO0001164',
#        'SMAD protein complex GO0071141',
#        'T-helper 2 cell differentiation GO0045064',
#        'dynein intermediate chain binding GO0045505',
#        'ferrous iron binding GO0008198',
#        'monoatomic cation transmembrane transport GO0098655',
#        'protein kinase A catalytic subunit binding GO0034236',
#        'GO0000184 nuclear transcribed mrna catabolic process nonsense mediated decay',
#        'GO0003700 sequence specific dna binding transcription factor activity',
#        'GO0005794 golgi apparatus', 'GO0006412 translation',
#        'GO0006413 translational initiation',
#        'GO0007275 multicellular organismal development',
#        'GO0007596 blood coagulation',
#        'GO0042803 protein homodimerization activity',
#        'GO0044267 cellular protein metabolic process',
#        'GO0045944 positive regulation of transcription from rna polymerase ii promoter',
#        'hsa04114 Oocyte meiosis',
#        'negative regulation of extrinsic apoptotic signaling pathway via death domain receptors GO1902042',
#        'actin binding GO0003779', 'late endosome membrane GO0031902',
#        'endopeptidase activity GO0004175',
#        'phosphatidylinositol-4,5-bisphosphate binding GO0005546',
#        'synapse assembly GO0007416',
#        'positive regulation of endothelial cell migration GO0010595',
#        'negative regulation of cell migration involved in sprouting angiogenesis GO0090051',
#        'excitatory chemical synaptic transmission GO0098976',
#        'glutamate receptor signaling pathway GO0007215',
#        'GO0005615 extracellular space', 'ovarian cancer deregulated',
#        'negative regulation of mitochondrial membrane potential GO0010917',
#        'WSB1', '6-phosphofructo-2-kinase activity GO0003873',
#        'ATPase inhibitor activity GO0042030',
#        'C-X3-C chemokine binding GO0019960',
#        'D-aspartate import across plasma membrane GO0070779',
#        'L-aspartate transmembrane transport GO0070778',
#        'L-glutamate import across plasma membrane GO0098712',
#        'MAP kinase serinethreonine phosphatase activity GO1990439',
#        'UDP-galactosebeta-N-acetylglucosamine beta-1,3-galactosyltransferase activity GO0008499',
#        'WASH complex GO0071203',
#        'alphav-beta3 integrin-HMGB1 complex GO0035868',
#        'alphav-beta3 integrin-vitronectin complex GO0071062',
#        'axonemal dynein complex GO0005858',
#        'cilium-dependent cell motility GO0060285',
#        'cilium movement GO0003341',
#        'cleavage in ITS2 between 5.8S rRNA and LSU-rRNA of tricistronic rRNA transcript SSU-rRNA, 5.8S rRNA, LSU-rRNA GO0000448',
#        'coreceptor activity involved in Wnt signaling pathway, planar cell polarity pathway GO1904929',
#        'corpus callosum development GO0022038',
#        'crossover junction DNA endonuclease activity GO0008821',
#        'dibasic protein processing GO0090472',
#        'epithelial cell migration GO0010631',
#        'fatty-acyl-CoA biosynthetic process GO0046949',
#        'fibrinogen binding GO0070051',
#        'fructose-2,6-bisphosphate 2-phosphatase activity GO0004331',
#        'fructose 2,6-bisphosphate metabolic process GO0006003',
#        'glutamatesodium symporter activity GO0015501',
#        'glycolipid floppase activity GO0034202',
#        'glycolipid translocation GO0034203',
#        'high-affinity L-glutamate transmembrane transporter activity GO0005314',
#        'histone H3 methyltransferase activity GO0140938',
#        'immature B cell differentiation GO0002327',
#        'integrin alphav-beta3 complex GO0034683',
#        'mRNA N6-methyladenosine dioxygenase activity GO1990931',
#        'membrane raft organization GO0031579',
#        'minus-end-directed microtubule motor activity GO0008569',
#        'myoblast proliferation GO0051450',
#        'negative regulation of dendrite morphogenesis GO0050774',
#        'negative regulation of double-strand break repair via nonhomologous end joining GO2001033',
#        'negative regulation of lipid transport GO0032369',
#        'negative regulation of lipoprotein metabolic process GO0050748',
#        'negative regulation of low-density lipoprotein particle receptor catabolic process GO0032804',
#        'negative regulation of macrophage derived foam cell differentiation GO0010745',
#        'negative regulation of mature B cell apoptotic process GO0002906',
#        'negative regulation of nerve growth factor production GO0032904',
#        'negative regulation of protein kinase C signaling GO0090038',
#        'oxidative RNA demethylase activity GO0035515',
#        'oxidative single-stranded RNA demethylation GO0035553',
#        'phosphatidylcholine transporter activity GO0008525',
#        'polynucleotide 5-hydroxyl-kinase activity GO0051731',
#        'positive regulation of lipophagy GO1904504',
#        'positive regulation of lymphotoxin A production GO0032761',
#        'positive regulation of mast cell cytokine production GO0032765',
#        'positive regulation of membrane protein ectodomain proteolysis GO0051044',
#        'positive regulation of mitochondrial depolarization GO0051901',
#        'positive regulation of myoblast fusion GO1901741',
#        'positive regulation of transcription from RNA polymerase II promoter in response to endoplasmic reticulum stress GO1990440',
#        'positive regulation of transforming growth factor beta1 activation GO1901394',
#        'promoter-enhancer loop anchoring activity GO0140585',
#        'protein-transporting ATPase activity GO0015450',
#        'protein localization to plasma membrane raft GO0044860',
#        'regulation of B cell differentiation GO0045577',
#        'regulation of cell-substrate adhesion GO0010810',
#        'regulation of endopeptidase activity GO0052548',
#        'regulation of mRNA 3-end processing GO0031440',
#        'regulation of postsynaptic neurotransmitter receptor internalization GO0099149',
#        'regulation of serotonin uptake GO0051611',
#        'regulation of striated muscle contraction GO0006942',
#        'resolution of mitotic recombination intermediates GO0071140',
#        'response to food GO0032094',
#        'smooth muscle cell migration GO0014909',
#        'tRNA import into mitochondrion GO0016031',
#        'tRNA processing GO0008033', 'transepithelial transport GO0070633',
#        'vascular endothelial growth factor binding GO0038085',
#        'vascular endothelial growth factor receptor activity GO0005021',
#        'viral life cycle GO0019058', 'viral translation GO0019081',
#        'AGAP1', 'ARL5C', 'B3GALT5', 'BCL10', 'BRI3BP', 'C6orf132',
#        'DNAH17', 'DUSP28', 'DUSP4', 'FURIN', 'GEN1', 'GPC4', 'ITGB3',
#        'MIER3', 'MYADM', 'NOL9', 'OPA3', 'PCDHB11', 'RAB1B', 'RFT1',
#        'SIGLEC14', 'SPTLC2', 'SUGT1', 'TOMM20', 'TRIM66',
#        'GO0000723 telomere maintenance',
#        'GO0003743 translation initiation factor activity',
#        'GO0004004 atp dependent rna helicase activity',
#        'GO0004065 arylsulfatase activity',
#        'GO0004519 endonuclease activity', 'GO0005506 iron ion binding',
#        'GO0005543 phospholipid binding',
#        'GO0005680 anaphase promoting complex', 'GO0005819 spindle',
#        'GO0006275 regulation of dna replication',
#        'GO0006446 regulation of translational initiation',
#        'GO0006644 phospholipid metabolic process',
#        'GO0006892 post golgi vesicle mediated transport',
#        'GO0006914 autophagy',
#        'GO0007094 mitotic cell cycle spindle assembly checkpoint',
#        'GO0007584 response to nutrient',
#        'GO0016538 cyclin dependent protein kinase regulator activity',
#        'GO0016702 oxidoreductase activity acting on single donors with incorporation of molecular oxygen incorporation of two atoms of oxygen',
#        'GO0017049 gtp rho binding', 'GO0030686 90s preribosome',
#        'GO0031418 l ascorbic acid binding',
#        'GO0031464 cul4a ring ubiquitin ligase complex',
#        'GO0048147 negative regulation of fibroblast proliferation',
#        'GO0051597 response to methylmercury',
#        'GO0060348 bone development', 'GO0070888 e box binding',
#        'WP107 Translation Factors', 'FAM69C',
#        'transcription cis-regulatory region binding GO0000976',
#        'AMP metabolic process GO0046033',
#        'GABA receptor binding GO0050811', 'Ino80 complex GO0031011',
#        'acyltransferase activity GO0016746',
#        'cell-cell junction maintenance GO0045217',
#        'cilium disassembly GO0061523', 'copper ion binding GO0005507',
#        'excitatory synapse GO0060076',
#        'internal peptidyl-lysine acetylation GO0018393',
#        'mitochondrial genome maintenance GO0000002',
#        'mitochondrial outer membrane translocase complex GO0005742',
#        'mitochondrion targeting sequence binding GO0030943',
#        'negative regulation of erythrocyte differentiation GO0045647',
#        'negative regulation of organ growth GO0046621',
#        'negative regulation of protein import into nucleus GO0042308',
#        'negative regulation of type II interferon production GO0032689',
#        'nerve growth factor binding GO0048406',
#        'nuclear-transcribed mRNA catabolic process, deadenylation-independent decay GO0031086',
#        'peptide hormone processing GO0016486',
#        'positive regulation of endopeptidase activity GO0010950',
#        'positive regulation of intracellular mRNA localization GO1904582',
#        'positive regulation of phospholipase C activity GO0010863',
#        'positive regulation of telomere maintenance in response to DNA damage GO1904507',
#        'positive regulation of xenophagy GO1904417',
#        'presynaptic membrane assembly GO0097105',
#        'primary miRNA processing GO0031053',
#        'protein insertion into mitochondrial outer membrane GO0045040',
#        'protein quality control for misfolded or incompletely synthesized proteins GO0006515',
#        'protein repair GO0030091',
#        'protein serine kinase activity GO0106310',
#        'regulation of DNA-templated DNA replication initiation GO0030174',
#        'regulation of cytokine production involved in inflammatory response GO1900015',
#        'regulation of embryonic development GO0045995',
#        'regulation of keratinocyte apoptotic process GO1902172',
#        'regulation of protein kinase activity GO0045859',
#        'removal of superoxide radicals GO0019430',
#        'retina layer formation GO0010842',
#        'transmembrane receptor protein tyrosine phosphatase signaling pathway GO0007185',
#        'triglyceride homeostasis GO0070328',
#        'vesicle budding from membrane GO0006900',
#        'Collecting duct acid secretion', 'CAPN15', 'LRRC3C', 'ONECUT3',
#        'SBNO1', 'TMEM43', 'Intracranial aneurysm', 'Cytoplasm', 'CALM3',
#        'CS', 'CUX1', 'PLS3', 'TSC22D2',
#        'regulation of mRNA stability GO0043488',
#        'epigenetic regulation of gene expression GO0040029',
#        'positive regulation of DNA methylation-dependent heterochromatin formation GO0090309',
#        'ribosomal protein S6 kinase activity GO0004711',
#        'RNA polymerase II activity GO0001055',
#        'TORC2 signaling GO0038203',
#        'U12-type spliceosomal complex GO0005689',
#        'apoptotic process involved in development GO1902742',
#        'cellular response to interferon-beta GO0035458',
#        'flavin-linked sulfhydryl oxidase activity GO0016971',
#        'positive regulation of calcium ion transport GO0051928',
#        'programmed cell death GO0012501',
#        'pyruvate kinase activity GO0004743',
#        'regulation of actin filament polymerization GO0030833', 'PKM',
#        'GO0016070 rna metabolic process',
#        'SNARE interactions in vesicular transport',
#        'endocytic recycling GO0032456',
#        'cellular response to sterol GO0036315',
#        'lipid droplet disassembly GO1905691',
#        'oxysterol binding GO0008142',
#        'retromer complex binding GO1905394', 'BTBD3', 'PPP6R1', 'PTP4A1',
#        'CHMP7', 'IDS', 'ISCU', 'PPP2CB', 'SCD', 'SDF2',
#        'mRNA binding GO0003729', 'actin filament severing GO0051014',
#        'cAMP-dependent protein kinase complex GO0005952',
#        'cAMP-dependent protein kinase inhibitor activity GO0004862',
#        'cAMP-dependent protein kinase regulator activity GO0008603',
#        'cellular response to amino acid stimulus GO0071230',
#        'chromosome passenger complex GO0032133',
#        'intrinsic apoptotic signaling pathway in response to oxidative stress GO0008631',
#        'negative regulation of cAMP-dependent protein kinase activity GO2000480',
#        'negative regulation of protein kinase activity by regulation of protein phosphorylation GO0044387',
#        'osmosensory signaling pathway GO0007231',
#        'phosphatidylinositol-3,5-bisphosphate 5-phosphatase activity GO0043813',
#        'phosphatidylinositol-3-phosphate phosphatase activity GO0004438',
#        'platelet alpha granule membrane GO0031092',
#        'positive regulation of execution phase of apoptosis GO1900119',
#        'regulation of autophagosome assembly GO2000785',
#        'tRNA aminoacylation for protein translation GO0006418', 'PRKAR2A',
#        'PAM', 'phosphatidylserine binding GO0001786',
#        'fatty acid beta-oxidation GO0006635',
#        'positive regulation of positive chemotaxis GO0050927',
#        'regulation of ubiquitin-protein transferase activity GO0051438',
#        'stress fiber assembly GO0043149',
#        'autophagosome membrane GO0000421',
#        'cellular response to glucocorticoid stimulus GO0071385',
#        'mRNA catabolic process GO0006402', 'Breast cancer her3+ negative',
#        'early endosome GO0005769',
#        'L-amino acid transmembrane transporter activity GO0015179',
#        'midbody GO0030496', 'cytoplasmic stress granule GO0010494',
#        'site of double-strand break GO0035861',
#        'Longevity regulating pathway',
#        'cardiac muscle cell differentiation GO0055007',
#        'intra-Golgi vesicle-mediated transport GO0006891',
#        'intrinsic apoptotic signaling pathway by p53 class mediator GO0072332',
#        'mitotic metaphase plate congression GO0007080',
#        'modulation of chemical synaptic transmission GO0050804',
#        'positive regulation of miRNA-mediated gene silencing GO2000637',
#        'pre-miRNA processing GO0031054',
#        'Progesterone-mediated oocyte maturation',
#        'Prolactin signaling pathway',
#        'RNA splicing, via transesterification reactions GO0000375',
#        'activation of protein kinase activity GO0032147',
#        'cell body GO0044297',
#        'endoplasmic reticulum unfolded protein response GO0030968',
#        'keratinocyte differentiation GO0030216',
#        'phosphatidylinositol-4-phosphate binding GO0070273',
#        'DNA replication initiation GO0006270',
#        'K63-linked deubiquitinase activity GO0061578',
#        'RNA polymerase III activity GO0001056',
#        'adenylate cyclase-inhibiting G protein-coupled receptor signaling pathway GO0007193',
#        'ankyrin binding GO0030506', 'blood coagulation GO0007596',
#        'cortical actin cytoskeleton GO0030864',
#        'histone methyltransferase activity GO0042054',
#        'negative regulation of Rho protein signal transduction GO0035024',
#        'positive regulation of T cell mediated cytotoxicity GO0001916',
#        'smooth muscle contraction GO0006939',
#        'tumor necrosis factor-mediated signaling pathway GO0033209',
#        'very long-chain fatty acid biosynthetic process GO0042761',
#        'Terpenoid backbone biosynthesis',
#        'endocytic vesicle membrane GO0030666',
#        'positive regulation of cytosolic calcium ion concentration GO0007204',
#        'Golgi lumen acidification GO0061795',
#        'positive regulation of cell proliferation in bone marrow GO0071864',
#        'positive regulation of histone H3-K4 methylation GO0051571',
#        'proton-transporting V-type ATPase complex GO0033176',
#        'vacuolar acidification GO0007035', 'FAM3C',
#        'GO0005753 mitochondrial proton transporting atp synthase complex',
#        'GO0022857 transmembrane transporter activity',
#        'GO0042776 mitochondrial atp synthesis coupled proton transport',
#        'GO0046933 hydrogen ion transporting atp synthase activity rotational mechanism',
#        'GO0046961 proton transporting atpase activity rotational mechanism',
#        'arachidonic acid metabolic process GO0019369',
#        'Graft-versus-host disease', 'phosphoprotein binding GO0051219',
#        'protein K11-linked ubiquitination GO0070979',
#        'atrial septum development GO0003283',
#        'positive regulation of mRNA catabolic process GO0061014',
#        'protein kinase B signaling GO0043491',
#        'regulation of protein kinase B signaling GO0051896',
#        'Golgi localization GO0051645',
#        'NADPH dehydrogenase quinone activity GO0003955',
#        'cell-substrate adhesion GO0031589',
#        'cellular response to actinomycin D GO0072717',
#        'ceramide transport GO0035627',
#        'dihydronicotinamide riboside quinone reductase activity GO0001512',
#        'dopamine receptor signaling pathway GO0007212',
#        'dynein complex GO0030286',
#        'histone deacetylase activity GO0004407',
#        'melatonin binding GO1904408', 'mesoderm formation GO0001707',
#        'monoamine transmembrane transporter activity GO0008504',
#        'monoamine transport GO0015844',
#        'monoatomic ion channel activity GO0005216',
#        'negative regulation of heterotypic cell-cell adhesion GO0034115',
#        'oxidoreductase activity, acting on other nitrogenous compounds as donors GO0016661',
#        'positive regulation of mitochondrial fusion GO0010636',
#        'positive regulation of viral entry into host cell GO0046598',
#        'positive regulation of viral life cycle GO1903902',
#        'quinone catabolic process GO1901662',
#        'resveratrol binding GO1905594', 'serotonin uptake GO0051610',
#        'NQO2', 'ZNF264',
#        'GO0000086 g2 m transition of mitotic cell cycle',
#        'GO0000790 nuclear chromatin', 'GO0008283 cell proliferation',
#        'GO0042493 response to drug',
#        'P00016 Cytoskeletal regulation by Rho GTPase', 'WP179 Cell cycle',
#        'WP289 Myometrial Relaxation and Contraction Pathways',
#        'WP615 Senescence and Autophagy', 'TXLNA',
#        'RNA polymerase II general transcription initiation factor activity GO0016251',
#        'cyclin-dependent protein serinethreonine kinase inhibitor activity GO0004861',
#        'negative regulation of stress-activated MAPK cascade GO0032873',
#        'polyG binding GO0034046',
#        'response to tumor necrosis factor GO0034612',
#        'GO0005886 plasma membrane', 'Familial ovarian cancer',
#        'Familiar ovarian carcinoma',
#        'trans-Golgi network membrane GO0032588',
#        'DNA replication-dependent chromatin disassembly GO0140889',
#        'RNA polymerase II general transcription initiation factor binding GO0001091',
#        'beta-1,3-galactosyl-O-glycosyl-glycoprotein beta-1,3-N-acetylglucosaminyltransferase activity GO0047223',
#        'cellular response to leucine GO0071233',
#        'developmental growth GO0048589',
#        'heterochromatin organization GO0070828',
#        'mammary gland development GO0030879',
#        'morphogenesis of a polarized epithelium GO0001738',
#        'negative regulation of amyloid-beta formation GO1902430',
#        'phospholipid translocation GO0045332',
#        'positive regulation of cardiac muscle hypertrophy GO0010613',
#        'positive regulation of extrinsic apoptotic signaling pathway GO2001238',
#        'positive regulation of sodium ion transmembrane transporter activity GO2000651',
#        'positive regulation of stem cell proliferation GO2000648',
#        'signal recognition particle binding GO0005047', 'HACD4', 'MDM4',
#        'NCBP3', 'POMGNT1', 'basolateral plasma membrane GO0016323',
#        'positive regulation of NLRP3 inflammasome complex assembly GO1900227',
#        'Cytosolic DNA-sensing pathway',
#        'AP-2 adaptor complex binding GO0035612',
#        'IDP phosphatase activity GO1990003',
#        'NAD-cap decapping GO0110155',
#        'RNA localization to chromatin GO1990280',
#        'RNA polymerase II C-terminal domain binding GO0099122',
#        'TFIIH-class transcription factor complex binding GO0001097',
#        'cobalt ion binding GO0050897', 'dITP catabolic process GO0035863',
#        'dITP diphosphatase activity GO0035870',
#        'inactive sex chromosome GO0098577',
#        'metalloexopeptidase activity GO0008235',
#        'negative regulation of rRNA processing GO2000233',
#        'negative regulation of stem cell differentiation GO2000737',
#        'phosphodiesterase decapping endonuclease activity GO1990174',
#        'polyC RNA binding GO0017130',
#        'positive regulation of cell cycle process GO0090068',
#        'protein localization to spindle microtubule GO1902889',
#        'snosRNA catabolic process GO0016077', 'HNRNPU', 'NUDT16',
#        'POLR2E', 'positive regulation of cell migration',
#        'Regulation of actin cytoskeleton', 'neurogenesis GO0022008'],
#       dtype=object)

# %%
gc['SuperPath Name'].unique()
# Out:
# array(['Signal Transduction', 'Metabolism of Proteins',
#        'Innate Immune System', 'Infectious Disease',
#        'Gene Expression (Transcription)',
#        'Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation',
#        'Cellular Responses to Stimuli',
#        'Processing of Capped Intron-Containing Pre-mRNA',
#        'Signaling By Rho GTPases', 'Cell Cycle, Mitotic',
#        'RNA Polymerase I Promoter Opening', 'Cellular Senescence',
#        'Cytokine Signaling in Immune System',
#        'Regulation of TP53 Activity', 'MAPK Family Signaling Cascades',
#        'Metabolism', 'Vesicle-mediated Transport',
#        'Class I MHC Mediated Antigen Processing and Presentation',
#        'Signaling By WNT', 'ERK Signaling', 'Gene Silencing By RNA',
#        'PIP3 Activates AKT Signaling', 'ESR-mediated Signaling',
#        'Nervous System Development', 'Prolactin Signaling',
#        'Chromatin Regulation / Acetylation', 'Pleural Mesothelioma',
#        'Signaling By Receptor Tyrosine Kinases',
#        'Apoptotic Pathways in Synovial Fibroblasts',
#        'SARS-CoV-2 Infection', 'Chromatin Organization',
#        'Oncogene Induced Senescence',
#        'Transport of The SLBP Independent Mature MRNA',
#        'Thromboxane Signalling Through TP Receptor',
#        'ADORA2B Mediated Anti-inflammatory Cytokines Production',
#        'Endometrial Cancer',
#        'Transcriptional Activity of SMAD2/SMAD3:SMAD4 Heterotrimer',
#        'MAP Kinase Activation', 'MAPK-Erk Pathway',
#        'Defective Binding of RB1 Mutants to E2F1,(E2F2, E2F3)',
#        'Translational Control', 'DNA Damage',
#        'PDGFR-beta Signaling Pathway',
#        'Pre-NOTCH Expression and Processing', 'Cell Cycle Checkpoints',
#        'Response to Elevated Platelet Cytosolic Ca2+', 'GPCR Pathway',
#        'Cytoskeletal Signaling', 'Semaphorin Interactions',
#        'Integrated Breast Cancer Pathway',
#        'Angiopoietin-like Protein 8 Regulatory Pathway',
#        'Sertoli-Sertoli Cell Junction Dynamics',
#        'Homology Directed Repair',
#        'Development Ligand-independent Activation of ESR1 and ESR2',
#        'Assembly of The Pre-replicative Complex',
#        'Signaling By ALK in Cancer', 'Deubiquitination',
#        'Mitotic G1 Phase and G1/S Transition',
#        'Signaling By TGFB Family Members',
#        'Chks in Checkpoint Regulation',
#        'Toll-like Receptor Signaling Pathway', 'MAP Kinase Signaling',
#        'Colorectal Cancer Metastasis', 'NFAT and Cardiac Hypertrophy',
#        'Transcription Ligand-dependent Activation of The ESR1/SP Pathway',
#        'Formation of HIV Elongation Complex in The Absence of HIV Tat',
#        'WNT Signaling', 'MiRNA Regulation of DNA Damage Response',
#        'Development Endothelin-1/EDNRA Transactivation of EGFR',
#        'Cell Cycle Regulation of G1/S Transition (part 1)',
#        'Autophagy Pathway', 'Clathrin-mediated Endocytosis',
#        'Influenza Infection', 'PKMTs Methylate Histone Lysines',
#        'Intrinsic Pathway For Apoptosis', 'Beta-Adrenergic Signaling',
#        'Signaling Downstream of RAS Mutants', 'HIV Life Cycle',
#        'Glycosaminoglycan Metabolism',
#        'Warburg Effect Modulated By Deubiquitinating Enzymes and Their Substrates',
#        'Inhibition of Ribosome Biogenesis By P14(ARF)', 'FMLP Pathway',
#        'Peptide Chain Elongation',
#        'Beta-2 Adrenergic-dependent CFTR Expression',
#        'DNA Damage Response (only ATM Dependent)',
#        'Glucose / Energy Metabolism',
#        'Smith-Magenis and Potocki-Lupski Syndrome Copy Number Variation',
#        'VEGFA-VEGFR2 Signaling', 'GDNF Signaling',
#        'Golgi-to-ER Retrograde Transport',
#        'Activated TAK1 Mediates P38 MAPK Activation', 'Cell Cycle',
#        'Translation Insulin Regulation of Translation', 'HCMV Infection',
#        'Signaling By PTK6', 'Circadian Clock', 'P70S6K Signaling',
#        'RND3 GTPase Cycle', 'EPH-Ephrin Signaling',
#        'EML4 and NUDC in Mitotic Spindle Formation',
#        'Breast Cancer Pathway', 'MAPK Signaling: Mitogens',
#        'CKAP4 Signaling Pathway Map', 'Packaging Of Telomere Ends',
#        'P53 Signaling', 'RAC2 GTPase Cycle',
#        'Immune Response_IFN Gamma Signaling Pathway', 'RAS Processing',
#        'TGF-beta Signaling Pathways', 'Integrin-mediated Cell Adhesion',
#        'TP53 Regulates Transcription of Cell Cycle Genes',
#        'NcRNAs Involved in Wnt Signaling in Hepatocellular Carcinoma',
#        'Signaling Events Mediated By HDAC Class I',
#        'Senescence and Autophagy in Cancer', 'Oncogenic MAPK Signaling',
#        'Activation of AMPK Downstream of NMDARs',
#        '16p11.2 Proximal Deletion Syndrome', 'Regulation of Telomerase',
#        'Transport of Inorganic Cations/anions and Amino Acids/oligopeptides',
#        'Ubiquitination Cascade', 'Integrins in Angiogenesis',
#        'Ebola Virus Infection in Host',
#        'Coregulation of Androgen Receptor Activity', 'TNFR1 Pathway',
#        'Regulation of Actin Dynamics For Phagocytic Cup Formation',
#        'Apoptosis and Survival BAD Phosphorylation',
#        'Activation of The Pre-replicative Complex',
#        'Nanog in Mammalian ESC Pluripotency',
#        'Pathways Affected in Adenoid Cystic Carcinoma',
#        'Signaling By Hedgehog',
#        'Regulation of Expression of SLITs and ROBOs',
#        'Separation of Sister Chromatids',
#        'MAPK Signaling: Oxidative Stress',
#        'Signaling Events Mediated By VEGFR1 and VEGFR2',
#        "Alzheimer's Disease and MiRNA Effects",
#        'Hepatocyte Growth Factor Receptor Signaling',
#        'Cellular Response to Heat Stress',
#        'Antiviral Mechanism By IFN-stimulated Genes',
#        'Transcription Androgen Receptor Nuclear Signaling',
#        'Nuclear Events Mediated By NFE2L2',
#        'B Cell Receptor Signaling Pathway', 'TGF-Beta Pathway',
#        'EphB-EphrinB Signaling', 'Wnt / Hedgehog / Notch',
#        'RHOD GTPase Cycle',
#        'WtCFTR and Delta508-CFTR Traffic / Generic Schema (norm and CF)',
#        'HIF-1-alpha Transcription Factor Network',
#        'RAB Geranylgeranylation', 'Retinoblastoma Gene in Cancer',
#        'Apoptosis and Survival FAS Signaling Cascades',
#        'G-protein Signaling RAC1 in Cellular Process',
#        'Orexin Receptor Pathway',
#        'Inhibition of Signaling By Overexpressed EGFR',
#        'VEGFR3 Signaling in Lymphatic Endothelium', 'Ras Signaling',
#        'MAPK Targets/ Nuclear Events Mediated By MAP Kinases',
#        'Focal Adhesion', 'Hedgehog Signaling Pathway',
#        'Deactivation of The Beta-catenin Transactivating Complex',
#        'Regulation of Nuclear SMAD2/3 Signaling',
#        'Development EGFR Signaling Via Small GTPases', 'NGF Pathway',
#        'Microtubule Cytoskeleton Regulation',
#        'E2F Transcription Factor Network', 'P53 Pathway',
#        'CCL18 Signaling Pathway',
#        'DYRK1A Involvement Regarding Cell Proliferation in Brain Development',
#        'HIF1Alpha Pathway',
#        'Androgen Receptor Network in Prostate Cancer',
#        'Nuclear Receptors Meta-pathway',
#        'MyD88 Dependent Cascade Initiated on Endosome',
#        'SARS-CoV-1-host Interactions',
#        'Transport of Mature Transcript to Cytoplasm',
#        'Tyrosine Kinases / Adaptors',
#        'Validated Targets of C-MYC Transcriptional Activation',
#        'MTOR Signaling', 'Signaling By FGFR2',
#        'Cytoskeleton Remodeling Regulation of Actin Cytoskeleton By Rho GTPases',
#        'TRNA Processing', 'Development Slit-Robo Signaling',
#        'Proteolysis Putative SUMO-1 Pathway', 'BRCA1 Pathway',
#        'DNA Damage_ATM/ATR Regulation of G1/S Checkpoint',
#        'Akt Signaling', 'Programmed Cell Death', 'MTOR Signaling Pathway',
#        'Guidance Cues and Growth Cone Motility',
#        'Netrin-UNC5B Signaling Pathway',
#        'Apoptosis-related Network Due to Altered Notch3 in Ovarian Cancer',
#        'Neuroscience', 'Head and Neck Squamous Cell Carcinoma',
#        'Metabolism of Water-soluble Vitamins and Cofactors',
#        'Regulation of TP53 Expression and Degradation',
#        'Calmodulin Induced Events', 'MET Promotes Cell Motility',
#        'Nuclear Events (kinase and Transcription Factor Activation)',
#        'Regulation of TP53 Activity Through Acetylation',
#        'HIF-2-alpha Transcription Factor Network',
#        'TP53 Regulates Metabolic Genes',
#        'Development Dopamine D2 Receptor Transactivation of EGFR',
#        'S-1P Stimulated Signaling', 'Death Receptor Signaling Pathway',
#        'CCR3 Pathway in Eosinophils',
#        'Regulation of RUNX1 Expression and Activity',
#        'Sphingolipid Metabolism', 'Signaling By NTRKs',
#        'Thyroid Stimulating Hormone (TSH) Signaling Pathway',
#        'Development EPO-induced Jak-STAT Pathway',
#        'Metabolic Reprogramming in Pancreatic Cancer',
#        'Transcription_P53 Signaling Pathway',
#        'Integrin-linked Kinase Signaling', '4-1BB Pathway',
#        'Glycolysis (REACTOME)', 'PAK Pathway',
#        'PI3K-Akt Signaling Pathway',
#        'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling',
#        'Gastrin Signaling Pathway', 'Calnexin/calreticulin Cycle',
#        'Sweet Taste Signaling',
#        'Clear Cell Renal Cell Carcinoma Pathways',
#        'DREAM Repression and Dynorphin Expression',
#        'Ovarian Tumor Domain Proteases',
#        'Development Angiotensin Activation of ERK',
#        'PDGFR-alpha Signaling Pathway',
#        'G-protein Signaling G-Protein Alpha-i Signaling Cascades',
#        'Immune Response CCR3 Signaling in Eosinophils',
#        'Processing of Capped Intronless Pre-mRNA',
#        'Neurophysiological Process Glutamate Regulation of Dopamine D1A Receptor Signaling',
#        'COPI-independent Golgi-to-ER Retrograde Traffic',
#        'RhoGDI Pathway',
#        'Transport to The Golgi and Subsequent Modification'], dtype=object)

# %%
overlap = miEAA.merge(gc, left_on='Subcategory', right_on='SuperPath Name')
overlap.head()
# Out:
#                Category          Subcategory Enrichment   P-value  P-adjusted  \
# 0  Reactome (miRPathDB)  Cellular Senescence   depleted  0.032122    0.032122
#
#     Q-value  Observed                                  miRNAs/precursors  \
# 0  0.474854         4  hsa-miR-4483; hsa-miR-5572; hsa-miR-320b; hsa-...
#
#        Score       SuperPath Name  # SuperPath Total Genes  \
# 0  43.396374  Cellular Senescence                      195
#
#    # SuperPath Matched Genes  \
# 0                         79
#
#                              Matched Genes (Symbols)  \
# 0  MAP2K3, MAP2K4, MAP2K7, CCNE1, CCNE2, MDM2, MD...
#
#                                         Evidence URL
# 0  https://pathcards.genecards.org/card/cellular_...
