# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
group_1 = pd.read_csv('./genes/d_group_1_genes.csv')
group_2 = pd.read_csv('./genes/d_group_2_genes.csv')
group_3 = pd.read_csv('./genes/d_group_3_genes.csv')
group_4 = pd.read_csv('./genes/d_group_4_genes.csv')
group_5 = pd.read_csv('./genes/d_group_5_genes.csv')

# %%
miRNA_clusters = pd.read_csv('miRNA_clusters.csv')

# %%
group_1.columns

print(f'Shape of group 1: {group_1.shape}')
print(f'Shape of group 2: {group_2.shape}')
print(f'Shape of group 3: {group_3.shape}')
print(f'Shape of group 4: {group_4.shape}')
# Out:
# Shape of group 1: (1065, 15)
# Shape of group 2: (206, 9)
# Shape of group 3: (431, 12)
# Shape of group 4: (527, 10)

# %%
group_1_genes = group_1['Gene Symbol'].tolist()
group_2_genes = group_2['Gene Symbol'].tolist()
group_3_genes = group_3['Gene Symbol'].tolist()
group_4_genes = group_4['Gene Symbol'].tolist()
group_5_genes = group_5['Gene Symbol'].tolist()

# %%
print("group_1 genes:", " ".join(group_1_genes), "\n")
print("group_2 genes:", " ".join(group_2_genes), "\n")
print("group_3 genes:", " ".join(group_3_genes), "\n")
print("group_4 genes:", " ".join(group_4_genes), "\n")
print("group_5 genes:", " ".join(group_5_genes), "\n")
# Out:
# group_1 genes: NPR1 CSK SBF1 HIST1H2BO PTPN9 ABHD12 DSG3 H2AFX HOXB8 IL10RB MRPL36 ZNF556 CLCN7 LRIT3 ABL1 ASB6 C3orf36 ERAP2 GTPBP10 HIST1H2BL NPW PHYKPL POU3F1 PTGR2 SF3B1 SIGLEC12 UBE2Q1 ZNF787 ZNF843 KIAA1614 AKR1D1 STMN3 ZSWIM1 NACC1 CDNF GRK5 SRCIN1 PMPCA ABHD17B BARHL1 CALR GNAI2 GPR20 HJURP LNX2 MAFK RPS27 TACC3 ZFP82 ARHGAP31 C11orf70 ERCC6L METTL14 SLC47A1 ADGRB2 ARHGAP39 CHRNE CRISPLD2 FAM212B GMDS NEUROD2 PDZD4 PRSS12 SINHCAF SP110 ZNF207 ORAI2 VOPP1 AKT1S1 AFG1L AMBRA1 AQP2 ARHGAP40 BBS1 C10orf95 CDC14B CKB COX6B1 CTTN CYP4A22 DIAPH1 DSCR3 DUSP14 ECSIT EMILIN2 F2 FSCN1 GDI1 GJA9 GTF3C6 HPCAL1 LETM2 LHFPL3 MAP1S MDFI MPP2 MYO5C NQO2 OAZ1 ORMDL2 PCSK4 PDE4C PIAS4 PLCD3 PNMA8A PTGES2 RNASEK RNF222 SCAMP4 SEMA3F SETD1B SLC43A2 SLC7A5 SNRPD1 SPRY4 SRD5A3 TAS2R5 TOMM40 TPCN2 TRIM59 VGF YPEL2 ZNF419 APTX CD276 CYP4A11 HIST1H3C TARS2 HIST2H2BE CBWD5 FAM162A GATC INO80E MPPED1 MRPS18A RTN4R SFN RAB11B ANP32B ATL2 DAB2IP DENND4B FBXO31 GSTCD HIST1H1E PKM PLCXD2 POLR2A SNRPA1 UGGT1 VSTM4 XPO6 ZBTB3 BAIAP2L1 BLOC1S3 BRD7 CBWD1 CTDNEP1 FAM120AOS GPT2 HIST1H2BE HOXA7 HRNR LRFN1 MARVELD2 MLLT1 MLX MPI NFIC NKX2-5 NMUR1 NRGN OTUB1 PCGF3 PRX PSMB2 RGS5 SCARF1 SDF4 SERPINA1 SLC15A1 SLC30A5 SLC35D2 SPTBN2 SRGAP1 TCF3 TMIGD2 TPM3 TSPAN14 TULP3 VPS18 ZNF639 IDE LRRTM2 NOTO UGGT2 NFIX PEX26 DNAH17 SLC2A5 CYP11A1 FFAR2 NLRP6 NUCB1 PAK1IP1 SETD3 SH3BGRL3 SIGLEC9 SPECC1L FBXW8 ADGRL1 BCL7B FKTN RNF125 THRB EPN2 MCFD2 NUBP1 RPS6KA1 MRPL44 SPIN4 AKNA ALDOA ARHGDIA ARHGEF18 CCNT1 CENPI DSN1 FANCM GRB2 HCFC1 IGSF8 KHSRP MALL PI4K2B PLEKHG2 PPP6R1 PRSS22 RAC3 SAA1 SELPLG SLC25A53 SLC2A4RG THSD4 TRMT2B VSIG1 GPAT4 ZNF451 RNASEH2B SLX4 UNC13A CACNA1A CAPN6 CASKIN2 FBXO45 LRTOMT MED7 PGAP1 MICAL2 SEMA3E SRD5A1 C10orf71 C20orf24 CRX KANSL3 LRRC58 PSMC4 SIPA1 ALPI CAVIN4 CCDC170 DPF1 FEM1B GATAD2A HIST1H2BG HOXD3 JUND KCTD20 MDK MMS22L MNT MRPS16 NANOG PRKAR2A RAD51L3-RFFL RXRA SGO1 TAF8 TMEM135 TMEM170A UBLCP1 ULK1 USP42 USP49 VPS8 ZNF91 HASPIN HIST1H2AG LIMS1 ANXA11 HIST3H3 HUS1 ILDR1 SHOX ZBTB8OS SLC10A7 ACOX1 ARIH2 B3GALNT2 BPNT1 CCDC36 CDCA4 CTPS1 DHTKD1 DIRAS1 ETFDH FAM102A FXN HAAO HAUS2 HIST1H2AE HIST1H3H KLLN KMT2A LLGL1 LRP10 NEK9 NUP62 OTUD5 PARP2 PBX2 REPIN1 SENP2 SLC46A1 SPIRE2 TMEM181 TRIM65 ZNF436 ZNF589 CARD10 CDKN1A GABRB2 KIAA0408 TRAF6 BTLA C16orf58 C3 CD3EAP LDLR MAK NDRG3 PATJ PHLDA3 PTAFR PTK6 RFFL SEC14L5 SWSAP1 TMPRSS4 TOR4A ZNF738 ADK BCKDK C12orf49 EIF2A HMGB1 HOXA5 HSP90AB1 INO80 KIAA1328 MESD MRPS30 OGFOD1 PLXNA2 PRPF4 PSD4 S100A16 SBK1 SLC36A2 SLC41A2 SYK TRUB2 ZNF251 ZNF516 ZNF573 JARID2 TRPM7 CKS1B CNNM4 EIF4G1 FRAT2 IVNS1ABP KNL1 MRI1 MRPL37 MTA3 NUBPL PRICKLE1 RAB1B ZDHHC6 AP5Z1 C10orf76 CENPO DCP1A KIAA0895 KLC2 KLK10 LHPP LYPLA2 MEIS3P1 OXA1L PCBP2 POLR2E PPIA QSER1 SH3GL1 SH3RF2 SLC7A1 TESPA1 TGFA TIMM8A ULBP3 UNC5B ZNF385A ABI2 AHDC1 ANKRD52 ARL8A ARPC3 ARSA ATG14 BTF3L4 CCDC174 CD1D CDC25B CTNS CXorf56 DNLZ DNMT1 FGD6 GRAP2 GTPBP2 HAUS5 HIST2H3A INSIG1 KDELC2 LARP1 MIOX MT1A NPHP3 NT5DC3 PAQR7 PLA2G4A PPIL4 PPP1R15A PSMG1 SDHAF1 SNX22 SUSD6 TCEANC2 THBS2 TMEM101 TP53 UQCR11 WARS WBP2 WDR5B YIPF4 ZBTB22 ZNF486 ZNF554 ZNF607 ZNF641 EXOSC2 MEF2D COL4A3BP HSPE1-MOB4 BTD CERS1 EXT1 GPRC5B PRR12 TNRC18P2 ZC3H11A HAUS3 TVP23C RABGAP1L WDR92 ZNF585B MOB4 PDLIM3 STEAP2 TERF2 TMEM59 VASP C22orf39 EZH2 HLA-B MYO6 POFUT2 SERTAD3 SLC30A6 THAP1 TMTC1 VN1R1 ZER1 ZNF561 ANG C11orf58 CASP8 FDXACB1 FUT2 IGFBP5 IPCEF1 KCNJ6 KCNK3 NDUFV3 PACS1 PDHB RABAC1 RCOR1 RHOA RHOB SGSM2 SLC35C2 SLC7A14 SLC7A2 SNAPC3 SOGA3 SPSB1 SPTLC3 SUB1 TNFSF14 TRAF1 UTP15 ZCCHC3 SAR1A C6orf141 EIF5A FOSL2 FPR1 LONRF1 LSG1 MARVELD1 PDXK PPM1D RABGAP1 SGPP2 SLC1A2 TNFRSF10A WFDC8 FAM83H NDUFAF3 NPLOC4 PIGW PRR23A STK17B TIMM29 TLE3 TUBB ZCCHC24 ADRM1 PTGES3L SOCS7 SYNRG UMPS ZC3H4 ZMYM1 BCL2L1 BCL2L12 CDH6 CYTH2 DTWD2 DTX3L ERN1 EVI5L IFFO2 MAPKAPK2 MIGA1 NCKAP1 PNMA2 RNF157 SLC27A1 TOB2 UFM1 ZSCAN22 ACBD7 APAF1 BTBD19 C2orf48 CCR6 CMTM6 CTXN1 ELK4 EP300 GALNT6 GEMIN6 GNL1 HIST1H3B HIST2H2AA3 JADE2 LIMK1 LRCH3 MID1IP1 MTMR10 NF2 PACS2 PACSIN1 PLCXD1 PLEKH ...
#
# group_2 genes: ABCG8 ACVRL1 AGO2 AGTRAP ALDOA APOL6 AS3MT ASB6 ASCC1 ATP13A4 ATP1B4 BACH1 BCL11B BHLHE40 BLOC1S4 BTBD3 C1orf220 C1orf50 C21orf58 C3 C5AR2 C6orf141 C9orf64 CACNG8 CASTOR2 CBX2 CDCP1 CENPN CERS4 CHAC1 CHEK1 CLDN1 CRK CRKL CTDSPL CYCS CYP20A1 DCTN5 DCTN6 DDX3X DGKE DNAJC10 DSN1 EIF2S3 FADS1 FAM109A FAM229B FAM3C FBXL18 FBXO48 FDFT1 FOXK1 FYTTD1 G3BP1 GABRB1 GET4 GFPT1 GOLIM4 GSG1 GTF3C1 HAUS3 HAVCR1 HEYL HMGN2 HRNR HS3ST1 HSPA6 HSPE1-MOB4 IFFO2 IRGQ ISPD ITPKB KCTD5 KIAA1551 KIAA1958 KLF2 KLHDC3 KMT2D KRT32 LCOR LINC00598 MACC1 MAP3K7 MARVELD2 MDK MLLT1 MMS22L MOB4 MOGAT1 MPLKIP MRPL12 MYC MYO5A MYOM2 N4BP1 NAPG NDUFB11 NFIC NLRP12 NOP14 NPR1 NQO2 NRXN3 NUCB1 NUDT3 NUP205 ORC4 PDE4C PHF1 PI4K2B PLEKHG2 PLXNA3 PNMA8B POLR2E PPIA PPIC PPIL4 PPM1L PPP1R15B PPP2R5C PPTC7 PRPF38A PSMG1 PTP4A1 PURB QPCTL QSOX1 RAB10 RAN RBL1 RBM38 RECK REL RHOA RNF115 RNF125 RNF149 RPL7L1 SCD SEC63 SELENON SETD5 SHOC2 SLC1A5 SLC24A4 SLC25A16 SLC35E2B SLC36A2 SNRPD3 SPRED1 SSBP2 STEAP2 STK40 SUSD1 SYNJ2BP SYT7 SZRD1 TANGO2 TCF23 TFDP2 THAP1 TIPIN TMEM170A TMEM189 TMEM189-UBE2V1 TMPPE TNFAIP8L1 TRAF1 TRAPPC2 TRIM39 TRMT10C TSC22D2 TSKU TXLNA UBE2V1 UGGT1 USP22 USP53 UTP15 WASF2 WHAMM WNT2B YIPF4 ZBTB7A ZBTB8B ZC3H4 ZMAT3 ZNF101 ZNF117 ZNF317 ZNF440 ZNF449 ZNF562 ZNF566 ZNF609 ZNF749 ZNF787 ZNRF3 ZSCAN29 YWHAZ TXNIP GDE1 IGF1R BTG2 CCND1 NUFIP2
#
# group_3 genes: CBX8 AP2S1 NKX6-2 MTA1 STMN3 DOT1L NEUROD2 RHOB G6PD GATAD2A MSC MUL1 PAX2 C10orf55 PBX2 LIMS2 PITX3 PPIB PPP1R14A RPS6KA4 RTN4RL2 SDK1 SHANK3 SUMO1 ARRB2 AFG1L KCNN3 MSI1 SNX11 ATL2 NFIC ADIRF SETD1B DDA1 OTUB1 PTPRF KCNK3 AP1S1 COLGALT1 CTXN1 DYNAP ENG GPRIN1 HDAC7 HEMK1 HIST1H2BE HIST1H2BL KCNE3 MAP2K3 MIDN PNMA8B RICTOR RNF40 SLITRK5 STRN4 THBS1 UNK VPS36 VPS72 WFIKKN2 ZNF764 SESTD1 LSP1 NKX2-2 TOLLIP BICDL1 CFL1 EN1 FAM43A MAPK8IP2 MCM5 NIPA2 POLD3 RHOXF2B RPTN RRAD RUNX3 SMYD5 SYNGR1 VPS51 ATG2A PEA15 CHTF8 ALDOA REPIN1 TRAF6 RAB2A C10orf111 EPN1 FXYD1 KDM6B ZNF677 DUS2 ZC3H7B ZNF516 CBARP HAAO ANKS1A ARL8A ARRB1 ASCL2 ASPH C19orf53 CACNB2 CARD10 CASP16P CASZ1 CD276 CHCHD4 CLCN7 CNKSR3 CSK CTDNEP1 E2F4 ECE1 FKBP4 FTSJ3 HPCAL1 IER2 IFITM3 IL21R ITPRIPL2 MEIS3P1 MFRP MIOX MMP17 MTHFR NDEL1 NLE1 PDE4A PFKFB2 POU3F1 PRELP PRSS8 RHBDD1 RHOA SCAMP3 SELENON SEPT9 SH3BP1 SLC29A2 SLC36A1 SOX12 SPART TEX261 TFAP2B THY1 VSIR ZBTB22 ZBTB47 ZC3H12D ZNF251 ZNF609 PKM ATG9A AHDC1 RNF185 ZNF787 NPLOC4 ANKRD13B ASNA1 CYP2B6 GPS1 LAT2 REXO1 SEPT14 TNRC18P2 TOB2 C22orf39 FAM234B HOXA7 NRGN NPTXR SPSB1 TCF3 TMEM81 NF2 PIGO APH1A CAPN15 LSG1 MYH11 PDE4C RXRB TMEM67 ZBTB46 ZKSCAN1 ZMIZ1 ZNF43 ANKRD42 ASB16 CCDC127 TACR3 CDH6 CIAPIN1 FUT1 NAB2 NDUFB11 RAI1 ABCC5 AGO2 AK2 ALG14 ANKRD45 APEX1 ARL4C ARL5C B3GALNT2 BAK1 BBC3 BCL9L C3orf36 CALM3 CALR CASKIN1 CBX6 CDCA4 CDKN1A CES2 CHST6 CLASP1 CNNM4 CPSF7 DDX39B DFFA DHTKD1 DPM2 DYRK2 EFHD2 EIF1 EIF5AL1 ENTPD5 EVI5L FAM129B FKBP8 FLVCR1 FSCN1 FXR1 FZD6 GIPC1 HOXB6 ICA1L IFNAR2 IGF2BP3 IKZF2 KHSRP KIF1C KLF13 KMT2A KPNA2 LAMC1 LASP1 LGALS3BP LIX1L LMBR1L LMNB2 LUZP1 LYRM4 MAPK8IP3 MARCKSL1 MARK2 MEF2D MEX3A MID1IP1 MINK1 MLLT1 MNT MRE11 MRPS23 MRPS27 MSANTD3 MTSS1L MYC NACC1 NANOS1 NARS NAV1 NCBP3 NCS1 NDRG1 NFIB NFIX NLRP9 NMNAT2 NSD1 NT5C2 NUP62 OLFML2A OLR1 P4HB PCGF3 PCP4L1 PEX26 PHACTR4 PHLDA3 PISD PLD3 PLEKHA3 POLL POLR2E PPP1R11 PPP1R16B PPP1R9B PPP6R1 PRKX PSMD11 PTPN14 QSOX2 RAB15 RAB1B RANGAP1 RBM23 RDH10 RFC2 RNF149 RNF187 RNPS1 RPL13A RRP36 SAMD4B SBF1 SBK1 SCAMP4 SECISBP2L SENP2 SFN SHMT1 SIT1 SKI SLC12A7 SLC16A9 SLC39A11 SLC47A1 SP110 SPATA2 SPCS3 STK35 STX4 SURF4 SYNGR2 TBC1D13 TERF2 TFAP4 TFPI THRA TIMM50 TLN1 TMBIM6 TMCO1 TMEM127 TMEM154 TMEM50A TMOD3 TMPPE TOR4A TP53 TPM3 TRIM28 TRIM72 TSPYL1 TTLL12 TXLNA UBE2Q1 UNC5B URM1 WIPF2 ZCCHC8 ZFP36 ZNF329 ZNF439 ZNF703 ZNF799 ZNF805 BCL2L11 ORAI2 TMED4 GXYLT2 KDELR1 YWHAE GLUL HMGA2 SESN3 TIMM8A ZNF385A NAA50 RBM28 ZNF708 GDE1 E2F3 LARP1 IP6K1 TNFRSF13C RREB1 SPRY4 ARHGDIA PRRC2B SP1 MRPS10 UBE2V1 TMEM189 TMEM189-UBE2V1 ZNF652 SOCS7 IFNLR1 BCL2L1 HMGA1 STK4 CASTOR2 SF3B3 SLC1A5 RPL7L1 UBXN2A MAPK1 UBN2 YIPF4 ABI2 TNRC6A CNBP MDM2 MED28 YWHAZ HDGF TXNIP FEM1A ZNF264 ZNF460 CCND1 GIGYF1 FOXK1 SLC7A5 NUFIP2
#
# group_4 genes: AK3 BRPF1 ESF1 FAM210B GK5 LRP3 MEAF6 MRPS23 PTPN2 ZNF281 GATAD2A KRI1 LRRC3C MAGT1 MFSD13A MYH11 POLD4 RAB15 TIGD6 TMEM40 VWC2 ACTR5 AKR7L ARHGEF5 BROX C4orf19 CHDH CSTF2 DNAJC8 EEF2K FBXO27 FFAR1 GTF2F1 IL2RA KAT7 KCMF1 MAFF MED7 MGAT1 MOGAT3 NFX1 ONECUT3 PGBD5 PIEZO1 PIGX POM121L7P SIGLEC6 SLC10A3 SSBP2 SUMO1 TDRD1 TMEM56 TOMM70 XKR4 ZC3H15 ZNF841 ZSCAN29 ADCY2 ARIH2OS FLG2 GRWD1 HACD4 HAND2 ISPD KRBA2 OSBPL10 PADI1 SPECC1 ST3GAL2 TJAP1 UROS VPS37D YME1L1 BMS1 COMMD9 NRF1 RHBDL2 RPTN VSIG1 NEURL4 PIK3R2 PKM TCF23 AGAP9 ATPAF1 CASTOR2 FAM151B FGFR4 MFSD14C MSRB1 NCBP3 NKPD1 OPTN PGBD4 PHC1 PRMT3 RNF170 SLFN12 SYAP1 TIMM10B TMEM250 TMEM54 XPO5 CAMK2A FADS6 LUC7L ST3GAL1 DDA1 LYRM4 CLK4 ODF4 SLC35C2 ZNF655 ACAA2 ALOX5AP BORCS7 CCDC115 DNPEP E2F4 EFNA3 FMN1 GPSM2 LINS1 MCAM MEX3A P3H2 PATZ1 RAB11FIP4 RAB5B RAP2B RNF157 SMTN SPIB STOML3 SUV39H1 TIMM29 TLN1 TMEM184B TSHZ2 WSB1 ZNF317 ZNF398 INO80 NDOR1 PKNOX2 FAM9B PLD6 TAS2R5 TEP1 TNKS1BP1 C8orf58 METTL27 MFSD4B QPRT SLC16A5 TGFBR3L HEBP2 MTHFR PPP1R3G PRELP PSAP SNX22 ZNF226 ZNF74 DMKN IBA57 KDELC2 TSPAN31 TSPYL4 FANCC AKAP5 ANKRD13B MYCBP STMN3 C3 C3orf62 CHAC1 CISD2 DYRK2 PHLDA3 SRARP UBE2G2 VEZT BAHD1 CDKL1 DOCK11 ANG ARSK MTAP SIK2 TIAL1 UBL5 ZNF573 C11orf58 DOT1L GRINA RAB2B TNFSF14 ZNF485 LRAT MAP4K2 STXBP2 ZNF638 GDE1 IDS WDR17 CNDP1 MPLKIP SPATA6 UBE2S BTN3A2 PTCD3 SLC4A2 CEP89 IYD KIAA1210 NAA50 OLA1 RNF216 ABCC6 DLGAP3 GALNT6 JPH2 KLHL7 LYN MEF2D RICTOR DUSP4 KCNA7 LIN52 LRCH3 MAPK8IP3 ZFP36 AP1S1 BACH2 ELK1 GP5 SEC23B SUPT7L TECPR1 PGPEP1 GEN1 RBL1 RPP25 CYP2W1 KLHL12 PIN1 PRRC2B RUNDC1 SIT1 THSD4 AKT1S1 HEATR5A MOCS3 SIX3 SSTR2 SAR1A ANAPC16 NTSR1 PLXDC2 GDI1 MOGAT1 DUSP28 LRRC47 MTO1 DNAJB13 PARVB POLD3 SEC14L4 SLC16A10 SLC4A1 TFPI ANKRD36 CTNND1 F2 NAGK SLC7A5 CENPM INMT SGO1 UTP4 WWC1 BICDL1 NACC1 NCOR2 PLEC WHAMM LIMS1 QSOX2 RGS9BP ZNF619 ESYT2 PKNOX1 PROSER2 PTGR2 STK38 YWHAB STK4 B3GALNT2 CALCOCO2 PHF7 SF3B3 AP2M1 ERC1 FOLR1 PNPLA6 CREB3L2 FURIN PLEKHM3 RAB4A SENP2 ZNF799 CCL22 EMC3 KMT2D PRRT2 ATL3 KIAA1143 NRIP3 PTK6 RFT1 ZNF695 CDC73 ACAP2 ALG1 RPS6KA4 SFN DCAF7 SLC1A5 MINOS1 BAMBI PSMB5 RPH3AL TFAP4 TMEM184C ZNF106 C6orf132 MRI1 ZBTB3 COX18 GRK2 MOB1B ANGPT4 CCDC77 CCS CTDNEP1 GRSF1 MAPK1 MCM8 MPRIP RDH10 SF3A1 UBE2Z YIPF4 ZBTB8A GMEB1 MRPL17 RGP1 SYNPO2L TUBD1 ZNF284 ZNF786 ABCF1 ALDOA DBT FOXK2 HEYL KIF6 MCF2L2 METTL14 RBBP4 TANGO2 TBXA2R TNRC6A ZNF641 PSME3 RPL18A ATXN7L3 ECE1 FHL2 FKBP5 FOSL1 TERF2 ZYG11B CNBP FYTTD1 MIER3 PTPRF TLCD2 ZNF701 ERGIC1 RBM43 ALG14 MLF2 SRF TMEM239 AR DFFA ETV3 FOSL2 GPR155 KCNK5 MKLN1 PLEKHA3 PPIC RNF40 RPS6KA5 SPTLC2 TIMM50 HDGF RAB5C RNF19B TRIM66 ZSCAN22 ABL2 CCNF ITGA3 MTMR10 NFE2L1 PIGO PLEKHM1 PRKAR2A PTBP1 RAB10 SLC25A33 SZRD1 TMED10 TTLL12 ZFP14 ACTB C16orf58 CALR CAPN15 CRY2 DDX6 GINM1 IFNAR2 LRIG2 MAFK MLXIP MNT NKAP PTPN14 RACGAP1 RRP36 SCO1 TRAPPC2 TRIM65 TSKU TXNDC16 UGGT1 VPS53 XIAP ZNF154 ZNF703 ACOT9 CEP97 DHODH HS3ST1 LAX1 MAZ MRNIP POTEG POTEM SERBP1 TFDP2 TMEM167A ZNF394 APOL6 GLUL HSD17B12 OCIAD2 SLC16A1 SPATA2 FBXL18 ZNF347 ARL5B SETD5 CNKSR3 EXOSC2 GAN HSPA4L KIAA1456 NFAT5 PEG10 RBM28 RBMS2 RREB1 SMG1 FAM71F2 TMEM189-UBE2V1 UBE2V1 HIC2 SBNO1 TMEM189 TRIM72 CRISPLD2 LCOR MLLT1 PRRG4 RBM23 RPRD2 TPM3 VAV3 ZBTB7A ZNF417 FAM241A SHOC2 MAPKAPK5 ARPP19 CYP20A1 UBXN2A COX6B1 KHSRP NUDT3 MED28 GATA6 SFT2D2 LINC00598 ORAI2 MIDN TXNIP FEM1A IGF1R FOXK1 KLHL15 CDKN1A
#
# group_5 genes: ASB6 ARMCX6 ELN GLRX MAX RPS6KA1 TMEM43 HIST3H3 MDK RBM5 ULK1 VPS13D C20orf196 HIST3H2BB CTRC INTS3 PPIA HIST2H3A YKT6 ACTBL2 ND2 FOXA2 FSCN1 MAF MLX PDCD11 SWAP70 TP73 ABCA2 AIMP1 ATXN2 C2CD2 CRLF1 HIST1H1B LRTOMT MAN2B2 MRPS18B SCAF4 SEC22C SF3A3 SLC10A3 SYNM UQCRH VPS45 PABPN1 TFPI ARL3 DDX39B INMT CYP11A1 COX10 EIF2B5 HIST2H2AB HIST2H3C MPP2 ACPP FAM208B FAM46B GAPDH HIST2H2AC HSP90AB1 MAPK10 NAA10 OPTN PCMTD1 PCSK1 PFN1 PNN PPP1R9B SETD1B SKI TAL1 UCK1 ANO8 EPN1 GINS3 SGMS2 ZNF747 MPRIP POMGNT1 ACADSB HSPA14 MUC17 APOBEC3C BAP1 GPSM2 HIST1H3H ORMDL2 STIM1 UBTF ZBTB7A EIF2A MTRNR2L6 MTRNR2L8 PQLC1 PROSER3 TXNRD3NB BRPF1 CHERP CKS1B GLI2 ITPRIPL1 MAK16 PRKCA SELENON BMP2 ITPA TESPA1 UNK ZNF321P ARL2 FBRS PKMYT1 FAM136A PYCARD MARCH9 RAB5B SETBP1 SIRPA TMED10 TMEM63C TRIP10 UBN2 USH1G POLDIP2 PTPN9 U2SURP ABHD12 CACNA1C IGF2 KMT2A LEAP2 PIM3 PLIN3 SCN2B TCF3 TPD52 VPS37C ZMIZ1 NCOA3 IDS KIAA0895L ZNF703 FBXL13 SPATA6 CDH6 COLGALT1 ESS2 HNRNPU PTP4A2 JPH2 SLC25A12 BCL7B RPS16 THRB ZFP36 ZNF148 ZNF267 CTXN1 ESF1 GLUL MID1IP1 PEX2 CYP2W1 FAM117B FBXO28 TIMM8A KDM6B MAPK1IP1L NAA50 SCAMP4 ADD1 CACUL1 HM13 IP6K1 MICAL2 PALM2-AKAP2 R3HDM4 REEP4 SEMA3E SRCAP ABL1 AKAP2 DNAJC8 DSN1 EPM2AIP1 GK5 HSPA4L LMNB2 MAGI3 NQO2 PRRC2B PTDSS2 RNPS1 SEMA7A SPRY4 THAP6 TRIM28 VDR ZNF581 ZNF689 CSTF2 ERC1 FOLR1 GXYLT1 MARK2 NPM3 PEA15 PLCG2 SF1 ZNF275 TM4SF1 TNRC6C YIPF6 EMC3 KLHDC8A NECAB3 PPP2CA PRRT2 SLC38A1 ULK2 MDM4 BCL7A RPS6KA4 SLC38A2 ZNF507 SEC24A ADM ANP32B CBX6 FOXRED2 PKM RPH3AL SMAD2 ARID5B SLC7A1 ARF1 CHAF1B NFIC RDH10 RBPJ GTPBP2 RIF1 ZBTB33 ZNF281 ATP5A1 COL4A3BP SECISBP2L TEX261 ZNF587 NCBP3 CDC5L FADS6 FOSL1 ITPRIPL2 SYNCRIP CABP4 RHOB ABI2 DNAJB9 MCL1 MKLN1 PPP1R11 RAB11FIP1 TMEM109 TOB2 TOR2A RAB5C SLC27A1 FUT11 NFE2L1 PLEKHM1 RAB10 SLC25A33 TET3 TMCO1 YOD1 CAPN15 SRSF7 CAPZA2 FXN RRP36 HDGF C5orf51 NPR1 PHLDA3 RORA ZNF107 FAM83F TAOK1 ZNF394 KDELR1 PTEN SESN3 VEGFA APOL6 PTMA ZNF385A FBXL18 SETD5 ARL10 SMCR8 ARHGDIA CCND1 SMG1 ZNF451 HIC2 SBNO1 CREBRF SOCS7 DCTN5 RNF11 NACC1 KLHL15 LDLR MLLT1 CRK KMT2D CYP20A1 MAPK1 TNRC6A CDKN1A SFT2D2 CELF1 YWHAZ GDE1 ZNF264 GIGYF1 FOXK1 SLC7A5 NUFIP2

# %% [markdown]
# # Genecards Pathway and Disease Analysis

# %%
group_1_gc = pd.ExcelFile('./gene_cards/d_group_1_gc.xlsx')
group_2_gc = pd.ExcelFile('./gene_cards/d_group_2_gc.xlsx')
group_3_gc = pd.ExcelFile('./gene_cards/d_group_3_gc.xlsx')
group_4_gc = pd.ExcelFile('./gene_cards/d_group_4_gc.xlsx')
group_5_gc = pd.ExcelFile('./gene_cards/d_group_5_gc.xlsx')

group_1_pathways = pd.read_excel(group_1_gc, 'Pathways', skiprows=18)
group_2_pathways = pd.read_excel(group_2_gc, 'Pathways', skiprows=18)
group_3_pathways = pd.read_excel(group_3_gc, 'Pathways', skiprows=18)
group_4_pathways = pd.read_excel(group_4_gc, 'Pathways', skiprows=18)
group_5_pathways = pd.read_excel(group_5_gc, 'Pathways', skiprows=18)

group_1_diseases = pd.read_excel(group_1_gc, 'Diseases', skiprows=18)
group_2_diseases = pd.read_excel(group_2_gc, 'Diseases', skiprows=18)
group_3_diseases = pd.read_excel(group_3_gc, 'Diseases', skiprows=18)
group_4_diseases = pd.read_excel(group_4_gc, 'Diseases', skiprows=18)
group_5_diseases = pd.read_excel(group_5_gc, 'Diseases', skiprows=18)

# %%
group_1_pathways.columns
# Out:
# Index(['Score', 'SuperPath Name', '# SuperPath Total Genes',
#        '# SuperPath Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL'],
#       dtype='object')

# %%
# Filter top 15 pathways by 'Score' for each group
top_group_1_pathways = group_1_pathways.nlargest(15, 'Score')
top_group_2_pathways = group_2_pathways.nlargest(15, 'Score')
top_group_3_pathways = group_3_pathways.nlargest(15, 'Score')
top_group_4_pathways = group_4_pathways.nlargest(15, 'Score')
top_group_5_pathways = group_5_pathways.nlargest(15, 'Score')

# Combine top pathways from all groups and drop duplicates
top_pathways = pd.concat([top_group_1_pathways, top_group_2_pathways, top_group_3_pathways, top_group_4_pathways, top_group_5_pathways]).drop_duplicates()

# Create a binary matrix to indicate the presence of top pathways in each group
top_pathway_presence = pd.DataFrame(index=top_pathways['SuperPath Name'].unique())
top_pathway_presence['Group 1'] = top_pathway_presence.index.isin(top_group_1_pathways['SuperPath Name']).astype(int)
top_pathway_presence['Group 2'] = top_pathway_presence.index.isin(top_group_2_pathways['SuperPath Name']).astype(int)
top_pathway_presence['Group 3'] = top_pathway_presence.index.isin(top_group_3_pathways['SuperPath Name']).astype(int)
top_pathway_presence['Group 4'] = top_pathway_presence.index.isin(top_group_4_pathways['SuperPath Name']).astype(int)
top_pathway_presence['Group 5'] = top_pathway_presence.index.isin(top_group_5_pathways['SuperPath Name']).astype(int)

# Plot heatmap with enhancements for top pathways by score across groups
plt.figure(figsize=(15, 15))
sns.heatmap(top_pathway_presence, cmap="YlGnBu", cbar_kws={'label': 'Presence'}, linewidths=.5)
plt.title('Top Pathway Presence Across Groups by Score', fontsize=16)
plt.xlabel('Groups', fontsize=14)
plt.ylabel('Pathways', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=10)
plt.show()

# Print top pathways for each group
print("Top pathways for Group 1:")
print('\n'.join(top_group_1_pathways['SuperPath Name'].tolist()), '\n')

print("Top pathways for Group 2:")
print('\n'.join(top_group_2_pathways['SuperPath Name'].tolist()), '\n')

print("Top pathways for Group 3:")
print('\n'.join(top_group_3_pathways['SuperPath Name'].tolist()), '\n')

print("Top pathways for Group 4:")
print('\n'.join(top_group_4_pathways['SuperPath Name'].tolist()), '\n')

print("Top pathways for Group 5:")
print('\n'.join(top_group_5_pathways['SuperPath Name'].tolist()), '\n')
# Out:
# Top pathways for Group 1:
# Gene Expression (Transcription)
# RNA Polymerase I Promoter Opening
# Signal Transduction
# Infectious Disease
# Cell Cycle, Mitotic
# Signaling By Rho GTPases
# Cellular Senescence
# Cellular Responses to Stimuli
# Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation
# Gene Silencing By RNA
# Innate Immune System
# Cytoskeletal Signaling
# Metabolism of Proteins
# Apoptotic Pathways in Synovial Fibroblasts
# Pre-NOTCH Expression and Processing
#
# Top pathways for Group 2:
# Innate Immune System
# Gene Expression (Transcription)
# IGF1 Pathway
# Infectious Disease
# Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation
# Cell Cycle
# DNA Damage Response (only ATM Dependent)
# E-cadherin Signaling in The Nascent Adherens Junction
# Apoptosis and Survival BAD Phosphorylation
# Signal Transduction
# DNA Damage_ATM/ATR Regulation of G1/S Checkpoint
# Signaling By TGFB Family Members
# Cell Cycle, Mitotic
# Transcriptional Activity of SMAD2/SMAD3:SMAD4 Heterotrimer
# TGF-beta Signaling Pathways
#
# Top pathways for Group 3:
# Gene Expression (Transcription)
# MAPK Signaling: Oxidative Stress
# Infectious Disease
# Cellular Senescence
# Apoptosis and Autophagy
# Cellular Responses to Stimuli
# Signal Transduction
# Intrinsic Pathway For Apoptosis
# Gastrin Signaling Pathway
# Endometrial Cancer
# MAPK Signaling: Mitogens
# Wnt / Hedgehog / Notch
# Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation
# Cell Cycle, Mitotic
# Bladder Cancer
#
# Top pathways for Group 4:
# Gene Expression (Transcription)
# MAP Kinase Signaling
# Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation
# Signal Transduction
# DYRK1A Involvement Regarding Cell Proliferation in Brain Development
# Infectious Disease
# Autophagy Pathway
# Regulation of TP53 Activity
# Cellular Responses to Stimuli
# Signaling By Receptor Tyrosine Kinases
# Defective Binding of RB1 Mutants to E2F1,(E2F2, E2F3)
# Signaling By NTRKs
# Pleural Mesothelioma
# Metabolism of Proteins
# Nuclear Events (kinase and Transcription Factor Activation)
#
# Top pathways for Group 5:
# Gene Expression (Transcription)
# Cellular Senescence
# Regulation of Activated PAK-2p34 By Proteasome Mediated Degradation
# Cellular Responses to Stimuli
# Assembly of The Pre-replicative Complex
# RNA Polymerase I Promoter Opening
# DNA Damage Response (only ATM Dependent)
# Response to Elevated Platelet Cytosolic Ca2+
# Development IGF-1 Receptor Signaling
# Apoptotic Pathways in Synovial Fibroblasts
# PKMTs Methylate Histone Lysines
# Cell Cycle, Mitotic
# Prolactin Signaling
# Processing of Capped Intron-Containing Pre-mRNA
# Integrated Breast Cancer Pathway

# %%
# Combine all diseases and drop duplicates
diseases = pd.concat([group_1_diseases, group_2_diseases, group_3_diseases, group_4_diseases, group_5_diseases], axis=0)
diseases = diseases.drop_duplicates()

# Create a binary matrix to indicate the presence of diseases in each group
disease_presence = pd.DataFrame(index=diseases['Name'].unique())
disease_presence['Group 1'] = disease_presence.index.isin(group_1_diseases['Name']).astype(int)
disease_presence['Group 2'] = disease_presence.index.isin(group_2_diseases['Name']).astype(int)
disease_presence['Group 3'] = disease_presence.index.isin(group_3_diseases['Name']).astype(int)
disease_presence['Group 4'] = disease_presence.index.isin(group_4_diseases['Name']).astype(int)
disease_presence['Group 5'] = disease_presence.index.isin(group_5_diseases['Name']).astype(int)


# Remove rows with all zeros to reduce sparsity
disease_presence = disease_presence[(disease_presence.T != 0).any()]

# Debugging statements
print("\nBinary matrix data types:")
print(disease_presence.dtypes)

print("\nBinary matrix head:")
print(disease_presence.head())

print("\nBinary matrix summary:")
print(disease_presence.describe())

# Ensure the matrix contains the expected values (0 and 1)
unique_values = disease_presence.values.flatten()
print("\nUnique values in the binary matrix:", set(unique_values))

# Plot a smaller subset of the data for debugging
subset_disease_presence = disease_presence.head(100)

plt.figure(figsize=(30, 120))  # Increase figure size significantly
sns.heatmap(disease_presence, cmap="YlGnBu", cbar_kws={'label': 'Presence'}, linewidths=.5, vmin=0, vmax=1)
plt.title('Disease Presence Across Groups', fontsize=16)
plt.xlabel('Groups', fontsize=14)
plt.ylabel('Diseases', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=8)  # Adjust font size for y-tick labels
plt.tight_layout()
plt.show()
# Out:
# Binary matrix data types:
# Group 1    int64
# Group 2    int64
# Group 3    int64
# Group 4    int64
# Group 5    int64
# dtype: object
#
# Binary matrix head:
#                       Group 1  Group 2  Group 3  Group 4  Group 5
# Breast Cancer               1        1        1        1        1
# Colorectal Cancer           1        1        1        1        1
# Retinitis Pigmentosa        1        1        1        1        1
# Ovarian Cancer              1        1        1        1        1
# Microcephaly                1        1        1        1        1
#
# Binary matrix summary:
#            Group 1      Group 2      Group 3      Group 4      Group 5
# count  7396.000000  7396.000000  7396.000000  7396.000000  7396.000000
# mean      0.759194     0.221065     0.454435     0.453488     0.365873
# std       0.427602     0.414993     0.497953     0.497866     0.481707
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     0.000000     0.000000     0.000000
# 50%       1.000000     0.000000     0.000000     0.000000     0.000000
# 75%       1.000000     0.000000     1.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
# Unique values in the binary matrix: {0, 1}

# %%
group_1_diseases.columns
# Out:
# Index(['Score', 'Name', 'Disease categories', '# Total Genes',
#        '# Matched Genes', 'Matched Genes (Symbols)', 'Evidence URL',
#        'Genetic Associations', 'Matched Genes for Genetic Associations',
#        'Diferentially Expressed Genes in Tissue Samples',
#        'Genes Matched to Differentially Expressed Genes'],
#       dtype='object')
